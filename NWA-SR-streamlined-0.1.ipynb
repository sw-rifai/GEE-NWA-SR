# %%
import ee

# Initialize the Earth Engine object, using the authentication credentials. 
ee.Initialize()

# %%
# %matplotlib inline
from __future__ import print_function # For py 2.7 compat

import datetime
import ee
import numpy as np
import os
import matplotlib.pyplot as plt
from pylab import figure
import matplotlib.dates as mdates

from IPython.html import widgets
from IPython.display import display
from IPython.utils import traitlets
from IPython.core.display import Javascript 

class GoogleMapsWidget(widgets.DOMWidget):
    _view_name = traitlets.Unicode('GoogleMapsView', sync=True)
    value = traitlets.Unicode(sync=True)
    description = traitlets.Unicode(sync=True)
    lat = traitlets.CFloat(0, help="Center latitude, -90 to 90", sync=True)
    lng = traitlets.CFloat(0, help="Center longitude, -180 to 180", sync=True)
    zoom = traitlets.CInt(0, help="Zoom level, 0 to ~25", sync=True)
    bounds = traitlets.List([], help="Visible bounds, [W, S, E, N]", sync=True)
    
    def __init__(self, lng=0.0, lat=0.0, zoom=2):
        self.lng = lng
        self.lat = lat
        self.zoom = zoom
        
    def addLayer(self, image, vis_params=None, name=None, visible=True):
        mapid = image.getMapId(vis_params)
        self.send({'command':'addLayer', 'mapid': mapid['mapid'], 'token': mapid['token'], 'name': name, 'visible': visible})
        
    def center(self, lng, lat, zoom=None):
        self.send({'command': 'center', 'lng': lng, 'lat': lat, 'zoom': zoom})

# %%
# %%javascript
#
# require(["widgets/js/widget"], function(WidgetManager){
#     var maps = [];
#
#     // Define the GoogleMapsView
#     var GoogleMapsView = IPython.DOMWidgetView.extend({
#
#         render: function() {
#             // Resize widget element to be 100% wide
#             this.$el.css('width', '100%');
#
#             // iframe source;  just enough to load Google Maps and let us poll whether initialization is complete
#             var src='<html style="height:100%"><head>' +
#                 '<scr'+'ipt src="http://maps.googleapis.com/maps/api/js?sensor=false"></scr'+'ipt>' +
#                 '<scr'+'ipt>google.maps.event.addDomListener(window,"load",function(){ready=true});</scr'+'ipt>' +
#                 '</head>' +
#                 '<body style="height:100%; margin:0px; padding:0px"></body></html>';
#
#             // Create the Google Maps container element.
#             this.$iframe = $('<iframe />')
#                 .css('width', '100%')
#                 .css('height', '500px')
#                 .attr('srcdoc', src)
#                 .appendTo(this.$el);
#
#             var self = this; // hold onto this for initMapWhenReady
#
#             // Wait until maps library has finished loading in iframe, then create map
#             function initMapWhenReady() {
#                 // Iframe document and window
#                 var doc = self.$iframe[0].contentDocument;
#                 var win = self.$iframe[0].contentWindow;
#                 if (!win || !win.ready) {
#                     // Maps library not yet loaded;  try again soon
#                     setTimeout(initMapWhenReady, 20);
#                     return;
#                 }
#
#                 // Maps library finished loading.  Build map now.
#                 var mapOptions = {
#                     center: new win.google.maps.LatLng(self.model.get('lat'), self.model.get('lng')),
#                     zoom: self.model.get('zoom')
#                 };
#                 var mapDiv = $('<div />')
#                     .css('width', '100%')
#                     .css('height', '100%')
#                     .appendTo($(doc.body));
#                 self.map = new win.google.maps.Map(mapDiv[0], mapOptions);
#
#
#                 // Add an event listeners for user panning, zooming, and resizing map
#                 // TODO(rsargent): Bind self across all methods, and save some plumbing here
#                 win.google.maps.event.addListener(self.map, 'bounds_changed', function () {
#                     self.handleBoundsChanged();
#                 });
#
#                 self.initializeLayersControl();
#             }
#             initMapWhenReady();
#         },
#
#         LayersControl: function(widget, controlDiv, map) {
#             var win = widget.$iframe[0].contentWindow;
#             var chicago = new win.google.maps.LatLng(41.850033, -87.6500523);
#
#             // Set CSS styles for the DIV containing the control
#             // Setting padding to 5 px will offset the control
#             // from the edge of the map.
#             controlDiv.style.padding = '5px';
#
#             // Set CSS for the control border.
#             var $controlUI = $('<div />')
#                 .css('backgroundColor', 'white')
#                 .css('borderStyle', 'solid')
#                 .css('borderWidth', '1px')
#                 .css('cursor', 'pointer')
#                 .css('textAlign', 'center')
#                 .appendTo($(controlDiv));
#
#             // Set CSS for the control interior.
#             var $controlContents = $('<div />')
#                 .css('fontFamily', 'Arial,sans-serif')
#                 .css('fontSize', '12px')
#                 .css('paddingLeft', '4px')
#                 .css('paddingRight', '4px')
#                 .css('paddingTop', '0px')
#                 .css('paddingBottom', '0px')
#                 .appendTo($controlUI);
#
#             this.$controlTable = $('<table />')
#                 .append($('<tr><td colspan=2>Layers</td></tr>'))
#                 .appendTo($controlContents);
#         },
#
#         initializeLayersControl: function() {
#             var doc = this.$iframe[0].contentDocument;
#             var win = this.$iframe[0].contentWindow;
#
#             // Create the DIV to hold the control and call the LayersControl() constructor
#             // passing in this DIV.
#
#             var layersControlDiv = document.createElement('div');
#             this.layersControl = new this.LayersControl(this, layersControlDiv, this.map);
#
#             layersControlDiv.index = 1;
#             this.map.controls[win.google.maps.ControlPosition.TOP_RIGHT].push(layersControlDiv);
#         },
#
#         // Map geometry changed (pan, zoom, resize)
#         handleBoundsChanged: function() {
#             this.model.set('lng', this.map.getCenter().lng());
#             this.model.set('lat', this.map.getCenter().lat());
#             this.model.set('zoom', this.map.getZoom());
#             var bounds = this.map.getBounds();
#             var playgroundCompatible = [bounds.getSouthWest().lng(), bounds.getSouthWest().lat(),
#                                         bounds.getNorthEast().lng(), bounds.getNorthEast().lat()];
#             this.model.set('bounds', playgroundCompatible);
#             this.touch();
#         },
#
#         // Receive custom messages from Python backend
#         on_msg: function(msg) {
#             var win = this.$iframe[0].contentWindow;
#             if (msg.command == 'addLayer') {
#                 this.addLayer(msg.mapid, msg.token, msg.name, msg.visible);
#             } else if (msg.command == 'center') {
#                 this.map.setCenter(new win.google.maps.LatLng(msg.lat, msg.lng));
#                 if (msg.zoom !== null) {
#                     this.map.setZoom(msg.zoom);
#                 }
#             }
#         },
#
#         // Add an Earth Engine layer
#         addLayer: function(mapid, token, name, visible) {
#             var win = this.$iframe[0].contentWindow;
#             var eeMapOptions = {
#                 getTileUrl: function(tile, zoom) {
#                     var url = ['https://earthengine.googleapis.com/map',
#                                mapid, zoom, tile.x, tile.y].join("/");
#                     url += '?token=' + token
#                     return url;
#                 },
#                 tileSize: new win.google.maps.Size(256, 256),
#                 opacity: visible ? 1.0 : 0.0,
#             };
#
#             // Create the overlay map type
#             var mapType = new win.google.maps.ImageMapType(eeMapOptions);
#
#             // Overlay the Earth Engine generated layer
#             this.map.overlayMapTypes.push(mapType);
#
#             // Update layer visibility control
#             var maxSlider = 100;
#
#             function updateOpacity() {
#                 mapType.setOpacity($checkbox[0].checked ? $slider[0].value / 100.0 : 0);
#             }
#
#             var $checkbox = $('<input type="checkbox">')
#                 .prop('checked', visible)
#                 .change(updateOpacity);
#
#             var $slider = $('<input type="range" />')
#                 .prop('min', 0)
#                 .prop('max', maxSlider)
#                 .prop('value', maxSlider)
#                 .css('width', '60px')
#                 .on('input', updateOpacity);
#
#             // If user doesn't specify a layer name, create a default
#             if (name === null) {
#                 name = 'Layer ' + this.map.overlayMapTypes.length;
#             }
#
#             var $row = $('<tr />');
#             $('<td align="left" />').append($checkbox).append(name).appendTo($row);
#             $('<td />').append($slider).appendTo($row);
#
#             this.layersControl.$controlTable.append($row);
#         }
#     });
#
#     // Register the GoogleMapsView with the widget manager.
#     WidgetManager.register_widget_view('GoogleMapsView', GoogleMapsView);
# });

# %%
def applyCSmask(image): 
    shadowMask = image.expression("b('B1')<200& b('B2')<400& b('B3')<300& b('B4')<2000& b('B5')<700& b('B7')<300").eq(0);
    shadowBuffer = shadowMask.reduceNeighborhood(ee.call('Reducer.allNonZero'),ee.call('Kernel.circle',0.5)).focal_min(5);
    cloudMask = image.expression("b('B1')>380& b('B2')>499 &b('B3')>375 & b('B4')>2850& b('B5')>1200& b('B7')>500").eq(0);
    cloudBuffer = cloudMask.reduceNeighborhood(ee.call('Reducer.allNonZero'),ee.call('Kernel.circle',0.5)).focal_min(5);
    combinedMask = shadowBuffer.And(cloudBuffer).neq(0);  
    image = image.mask(combinedMask)
    return image 

def applyHansenMask(image):
    hansenDataMask = ee.Image('UMD/hansen/global_forest_change_2013').select('datamask');
    hansenMaskSmooth = hansenDataMask.reduceNeighborhood('max',ee.call('Kernel.euclidean',3)).focal_max(iterations=1).focal_min(iterations=3).focal_max().eq(1);

    forestMask = ee.Image("MCD12Q1/MCD12Q1_005_2009_01_01").select('Land_Cover_Type_1').eq(2).focal_min(radius=3, iterations=2);
          
    ##necessary to combine masks, otherwise applying one mask will disregard previously applied masks
    combinedMask = image.mask().And(hansenMaskSmooth).And(forestMask);  
    image = image.mask(combinedMask);
    return image;

def applySoilMask(image):
    imageMasked = image.And(image.mask(image.select('B7').gte(1550).focal_min(5))); #remove soil dominated pixels
    soil = image.expression("b('B7')>1550").eq(0).focal_min(5);
    combinedMask = image.mask().And(soil);
    image = image.mask(combinedMask);
    return image;

def applyAnomPixelMask(image):
    imageMasked = image.mask().And(image.mask(image.select(['B5']).lte(4000).focal_min(20)));
    anoms = image.expression(" b('B5')>3000").eq(0);
    combinedMask = image.mask().And(anoms);
    image = image.mask(combinedMask);
    return image;

def applyWaterMask(image):
    water = image.expression(" b('B4')<1750").eq(0).focal_min(3);
    combinedMask = image.mask().And(water);
    image = image.mask(combinedMask);
    return image;

# %% [markdown]
# ## INPUTS!!!

# %%
import datetime
collection = 'LT5_L1T_SR' 
inYear = 2011
startDate = datetime.datetime(inYear, 7, 1); 
endDate = datetime.datetime(inYear,12,31);
path = 7
row = 62 
CC = 50
collectionSpec = ee.ImageCollection(collection)
collectionSpec = (collectionSpec
    .filterDate(startDate, endDate)
    .filterMetadata('default:WRS_PATH', 'EQUALS', path)
    .filterMetadata('default:WRS_ROW', 'EQUALS', row)
    .filterMetadata('CLOUD_COVER','less_than',CC)) 

imageLast = ee.Image(collectionSpec.sort('system:time_start',False).first())


visParamsSR =  {'min': '0, 0, 0', 'max': '3000, 4000, 1000', 'bands': 'B5,B4,B3'};#Add layers

# %%
masked = applyCSmask(imageLast);
masked = applyHansenMask(masked);
masked = applySoilMask(masked); 
masked = applyAnomPixelMask(masked);
masked = applyWaterMask(masked);

# anthroPoly = ee.FeatureCollection('ft:1rJT6SWmCN6hNJxhroEVYdbXv3NWX9nJk0stZR1Zh'); #old 
anthroPoly = ee.FeatureCollection('ft:1yyaTIO-AOstBgk1a8M5oaO9LLhwu6AT_gCrSz6bf'); 

#Start with a black image.
image1 = ee.Image(1).toByte();
#Fill and outline the polygons in two colors
image2 = image1.paint(anthroPoly, 0);
combinedMask = masked.mask().And(image2)
total = masked.mask(combinedMask);

# %%
##******* SMA ******************
toUnmix = total.select(['B1','B2','B3','B4','B5','B7']);
#Define Endmembers 
bdEM = [514, 803, 772, 2309, 2481, 1433]; 
soilEM = [484, 661, 775, 1720, 2664, 1880];
forestEM = [200, 445, 254, 3213, 1404, 464]; 
forestSecEM = [237, 481, 283, 4938, 1918, 637];
shadowEM = [296, 402, 307, 466, 68, 49];  
waterEM = [687, 1198, 1520, 1501, 68, 83]; 
forestHazeEM = [424, 648, 498, 3131, 1417, 606];
wetlandSoilEM = [293, 608, 470, 2611, 1783, 743];

## Apply SMA 
unmixBD = toUnmix.unmix([bdEM, forestEM, soilEM, forestHazeEM]);
unmixForest = toUnmix.unmix([bdEM, forestEM, forestSecEM]);
unmixSoils = toUnmix.unmix([bdEM, wetlandSoilEM, soilEM]);
unmixHaze = toUnmix.unmix([forestHazeEM,forestEM,forestSecEM]);

bdReal = unmixBD.select(['band_0']).gte(0.2).And(unmixHaze.select(['band_0']).lte(0.05)).And(unmixBD.select(['band_2']).lte(0.8)).And(unmixForest.select(['band_0']).gte(0.2)); 
bdRealSmooth = bdReal.focal_max(3).focal_mode(3).eq(1);
blank = ee.Image(0); 
blank = blank.And(bdRealSmooth.eq(1)); 

output = ee.Image(0).where(bdRealSmooth.eq(1),1)

# %%
region = total.geometry(50); 
bdVectors = output.eq(1).reduceToVectors(geometry=region, scale=30, geometryType='polygon',maxPixels=30000000,bestEffort= True,tileScale= 4); 


# Calc the area of each polygon in the feature collection
def getArea(f):
    return f.set({'area': f.convexHull(5).area(5)});
# map the function over each feature in the collection
bdVectors = bdVectors.map(getArea); 

# filtering out the too large and too small from the blowdown vectors 
bdVectorsFiltered = (bdVectors.filterMetadata('area', 'greater_than', 150000)
                        .filterMetadata('area', 'less_than', 50e6));

NPV = unmixBD.select(['band_0'],['NPV']);
mean_reducer = ee.call("Reducer.mean"); 
def getNPV(f):
  meanNPV = 0;
  #meanNPV = unmixBD.select(['band_0']).reduceRegion(mean_reducer, f.convexHull(5).geometry(),60);
  meanNPV = NPV.reduceRegion(mean_reducer, f.convexHull(5).geometry(),30);
  return f.set({'meanNPV': f.set(meanNPV).get('NPV')});
bdVectorsFiltered = bdVectorsFiltered.map(getNPV);
bdVectorsFiltered = bdVectorsFiltered.filterMetadata('meanNPV', 'greater_than', 0.03);

# %%
imageForest = unmixBD.select('band_1').gte(0.1)
pixNum = imageForest.multiply(ee.Image.pixelArea())
stats_raster = pixNum.reduceRegion(reducer=ee.call("Reducer.sum"),scale=30,maxPixels=1e10)
forest_area = stats_raster.getInfo()

# %%
landsat_id = imageLast.getInfo()['id']
landsat_id = landsat_id.split("/")[1] 
print(landsat_id)
# Out:
# LT50070622011258CUB00

# %%
def getLSID(f): 
    return f.set({'LS_ID':landsat_id}) 

bdVectorsFiltered = bdVectorsFiltered.map(getLSID)

# %%
forest_area_m2 = forest_area["band_1"]
#set the forest area into the shapefile
def getForArea(f): 
    return f.set({'scene_forest_area':forest_area_m2}) 
bdVectorsFiltered = bdVectorsFiltered.map(getForArea);

# %%
map = GoogleMapsWidget(lat=-2.93, lng=-75.32, zoom=13)
display(map) 
map.addLayer(image=bdRealSmooth, name="BD-on/off",visible=False)
map.addLayer(image=total, vis_params=visParamsSR, name="SR masked")
#map.addLayer(bdLab, name="BD-redToVec")
visBDvecParams =  {'color':'FF0000'}; 
map.addLayer(bdVectorsFiltered, vis_params=visBDvecParams, name="BD vectors - filtered",visible=True)

# %%
del(map); #remove the map object
bdVectorsFiltered.getInfo()['features'].__len__()
# Out:
# 3

# %%
#del(map) #need to delete the map object so as not to conflict with the 


from geopandas import GeoDataFrame
from shapely.geometry import shape

def fc2df(fc):
    # Convert a FeatureCollection into a pandas DataFrame
   
    # Features is a list of dict with the output
    features = fc.getInfo()['features']

    dictarr = []
      
    for f in features:
        # Store all attributes in a dict
        attr = f['properties']
        # and treat geometry separately
        attr['geometry'] = f['geometry']  # GeoJSON Feature!
        # attr['geometrytype'] = f['geometry']['type']
        dictarr.append(attr)
       
    df = GeoDataFrame(dictarr)
    # Convert GeoJSON features to shape
    df['geometry'] = map(lambda s: shape(s), df.geometry)    
    return df
# End fc2df

# %%
#del(map)
bdVec_df = fc2df(bdVectorsFiltered)

# %%
bdVec_df
# Out:
#                     LS_ID             area  count   forest_area  \
# 0   LT50070622011258CUB00    251917.687344    164  2.865316e+10
# 1   LT50070622011258CUB00    190955.700691    131  2.865316e+10
# 2   LT50070622011258CUB00    191626.428380    148  2.865316e+10
# 3   LT50070622011258CUB00    234329.084961    161  2.865316e+10
# 4   LT50070622011258CUB00    335534.884580    197  2.865316e+10
# 5   LT50070622011258CUB00    167567.122596    124  2.865316e+10
# 6   LT50070622011258CUB00    250740.781573    184  2.865316e+10
# 7   LT50070622011258CUB00    283308.286355    179  2.865316e+10
# 8   LT50070622011258CUB00    166768.870485    116  2.865316e+10
# 9   LT50070622011258CUB00    155900.496611    120  2.865316e+10
# 10  LT50070622011258CUB00    153514.521180    113  2.865316e+10
# 11  LT50070622011258CUB00    153523.198750    117  2.865316e+10
# 12  LT50070622011258CUB00    155941.909905    101  2.865316e+10
# 13  LT50070622011258CUB00   1196066.583353    849  2.865316e+10
# 14  LT50070622011258CUB00  19327293.529339   8853  2.865316e+10
# 15  LT50070622011258CUB00    386582.967372    239  2.865316e+10
# 16  LT50070622011258CUB00    948390.759748    579  2.865316e+10
# 17  LT50070622011258CUB00    217991.332111    198  2.865316e+10
#
#                                              geometry  label   meanNPV
# 0   POLYGON ((-73.73471118529987 -2.40489865164019...      1  0.358494
# 1   POLYGON ((-73.73408645516567 -2.98745950179073...      1  0.044664
# 2   POLYGON ((-73.74814288318538 -2.56951504200445...      1  0.130629
# 3   POLYGON ((-73.75064180372222 -2.98152456551574...      1  0.091455
# 4   POLYGON ((-73.77219499335246 -2.96590631216049...      1  0.096082
# 5   POLYGON ((-74.07831275911521 -2.20342318335757...      1  0.094542
# 6   POLYGON ((-74.28603552873993 -2.24403064208120...      1  0.121215
# 7   POLYGON ((-74.32258224159119 -2.14251199527212...      1  0.104939
# 8   POLYGON ((-74.37037409685823 -3.54003330549920...      1  0.084180
# 9   POLYGON ((-74.48313788608309 -3.72214213962132...      1  0.204552
# 10  POLYGON ((-74.63026183268947 -3.59875793811491...      1  0.279324
# 11  POLYGON ((-74.71428803574067 -3.54346932123735...      1  0.146922
# 12  POLYGON ((-74.74521217738405 -3.48005921261507...      1  0.119298
# 13  POLYGON ((-74.90732964721147 -3.22235803225357...      1  0.041132
# 14  POLYGON ((-75.29122631468331 -2.95903428068419...      1  0.064880
# 15  POLYGON ((-75.29653652082411 -3.38416313701388...      1  0.101991
# 16  POLYGON ((-75.34620256649377 -3.38135185140994...      1  0.099233
# 17  POLYGON ((-75.36463210545296 -3.33168580574027...      1  0.165526
#
# [18 rows x 7 columns]

# %%
#rawID = imageLast.getInfo()['id']
#bdVec_df.to_file(rawID)

# %%
import json
#test = json.loads(rawID)
#rawID.split()
rawID = imageLast.get('LANDSAT_SCENE_ID'); 
test = rawID.serialize() #convert to json
test = json.loads(test) #takes json string and converts to python data structure

# %%
"""
collection = 'LT5_L1T_SR' 
inYear = 2011
startDate = datetime.datetime(inYear, 7, 1); 
endDate = datetime.datetime(inYear,12,31);
path = 7
row = 62 
CC = 50
""" 
shapeID = collection+"_"+str(path)+"_"+ str(row)+"_"+ str(inYear)
shapeID
# Out:
# 'LT5_L1T_SR_7_62_1986'

# %%
bdVec_df.to_file(shapeID)

# %%
junk = bdVectorsFiltered.getInfo()['features'][1]

# %%
bdVec_df.to_file('bdVec.csv')
# Out:
# {u'area': 438364.01443051116,
#  u'count': 250,
#  u'label': 1,
#  u'meanNPV': 0.11965073812894571}

# %%
import fiona 
fiona.supported_drivers
# Out:
# {'ARCGEN': 'r',
#  'AeronavFAA': 'r',
#  'BNA': 'raw',
#  'DGN': 'raw',
#  'DXF': 'raw',
#  'ESRI Shapefile': 'raw',
#  'FileGDB': 'raw',
#  'GMT': 'raw',
#  'GPKG': 'rw',
#  'GPSTrackMaker': 'raw',
#  'GPX': 'raw',
#  'GeoJSON': 'rw',
#  'Idrisi': 'r',
#  'MapInfo File': 'raw',
#  'PCIDSK': 'r',
#  'PDS': 'r',
#  'SEGY': 'r',
#  'SUA': 'r'}

# %%
write_csv(bdVec_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-eba2aca9cf51> in <module>()
# ----> 1 write_csv(bdVec_df)
#
# NameError: name 'write_csv' is not defined

# %%
bdVec_df.to_csv("bdVec.csv")

# %%
imageForest = unmixBD.select('band_1').gte(0.1)
map = GoogleMapsWidget(lat=-2.93, lng=-75.32, zoom=13)
display(map) 
#map.addLayer(image=bdRealSmooth, name="BD-on/off",visible=False)
map.addLayer(image=total, vis_params=visParamsSR, name="SR masked")
map.addLayer(image=imageForest, name="Forest")
#map.addLayer(bdLab, name="BD-redToVec")
#visBDvecParams =  {'color':'FF0000'}; 
#map.addLayer(bdVectorsFiltered, vis_params=visBDvecParams, name="BD vectors - filtered",visible=True)

# %%
area = pixNum.reduceRegion(reducer=ee.call("Reducer.sum"))

# %%
test = stats_raster.get('band_1')

# %%
# Out:
# 28653158237.211376

# %%
type(test)
# Out:
# str

# %%
import json
test_py = json.loads(test) #takes json string and converts to python data structure

# %%
test_py
# Out:
# {u'scope': [[u'0',
#    {u'arguments': {},
#     u'functionName': u'Image.pixelArea',
#     u'type': u'Invocation'}],
#   [u'1',
#    {u'arguments': {u'value': 0.1},
#     u'functionName': u'Image.constant',
#     u'type': u'Invocation'}],
#   [u'2', [u'band_1']],
#   [u'3', [u'B1', u'B2', u'B3', u'B4', u'B5', u'B7']],
#   [u'4',
#    {u'arguments': {u'leftField': u'CLOUD_COVER', u'rightValue': 50},
#     u'functionName': u'Filter.lessThan',
#     u'type': u'Invocation'}],
#   [u'5',
#    {u'arguments': {u'leftField': u'default:WRS_ROW', u'rightValue': 62},
#     u'functionName': u'Filter.equals',
#     u'type': u'Invocation'}],
#   [u'6',
#    {u'arguments': {u'leftField': u'default:WRS_PATH', u'rightValue': 7},
#     u'functionName': u'Filter.equals',
#     u'type': u'Invocation'}],
#   [u'7',
#    {u'arguments': {u'end': {u'arguments': {u'value': 1325289600000.0},
#       u'functionName': u'Date',
#       u'type': u'Invocation'},
#      u'start': {u'arguments': {u'value': 1309478400000.0},
#       u'functionName': u'Date',
#       u'type': u'Invocation'}},
#     u'functionName': u'DateRange',
#     u'type': u'Invocation'}],
#   [u'8',
#    {u'arguments': {u'leftValue': {u'type': u'ValueRef', u'value': u'7'},
#      u'rightField': u'system:time_start'},
#     u'functionName': u'Filter.dateRangeContains',
#     u'type': u'Invocation'}],
#   [u'9',
#    {u'arguments': {u'id': u'LT5_L1T_SR'},
#     u'functionName': u'ImageCollection.load',
#     u'type': u'Invocation'}],
#   [u'10',
#    {u'arguments': {u'collection': {u'type': u'ValueRef', u'value': u'9'},
#      u'filter': {u'type': u'ValueRef', u'value': u'8'}},
#     u'functionName': u'Collection.filter',
#     u'type': u'Invocation'}],
#   [u'11',
#    {u'arguments': {u'collection': {u'type': u'ValueRef', u'value': u'10'},
#      u'filter': {u'type': u'ValueRef', u'value': u'6'}},
#     u'functionName': u'Collection.filter',
#     u'type': u'Invocation'}],
#   [u'12',
#    {u'arguments': {u'collection': {u'type': u'ValueRef', u'value': u'11'},
#      u'filter': {u'type': u'ValueRef', u'value': u'5'}},
#     u'functionName': u'Collection.filter',
#     u'type': u'Invocation'}],
#   [u'13',
#    {u'arguments': {u'collection': {u'type': u'ValueRef', u'value': u'12'},
#      u'filter': {u'type': u'ValueRef', u'value': u'4'}},
#     u'functionName': u'Collection.filter',
#     u'type': u'Invocation'}],
#   [u'14',
#    {u'arguments': {u'ascending': False,
#      u'collection': {u'type': u'ValueRef', u'value': u'13'},
#      u'key': u'system:time_start'},
#     u'functionName': u'Collection.limit',
#     u'type': u'Invocation'}],
#   [u'15',
#    {u'arguments': {u'collection': {u'type': u'ValueRef', u'value': u'14'}},
#     u'functionName': u'Collection.first',
#     u'type': u'Invocation'}],
#   [u'16',
#    {u'arguments': {u'value': 0},
#     u'functionName': u'Image.constant',
#     u'type': u'Invocation'}],
#   [u'17',
#    {u'arguments': {u'radius': 0.5},
#     u'functionName': u'Kernel.circle',
#     u'type': u'Invocation'}],
#   [u'18',
#    {u'arguments': {u'argName': u'DEFAULT_EXPRESSION_IMAGE',
#      u'expression': u"b('B1')>380& b('B2')>499 &b('B3')>375 & b('B4')>2850& b('B5')>1200& b('B7')>500"},
#     u'functionName': u'Image.parseExpression',
#     u'type': u'Invocation'}],
#   [u'19',
#    {u'arguments': {u'DEFAULT_EXPRESSION_IMAGE': {u'type': u'ValueRef',
#       u'value': u'15'}},
#     u'function': {u'type': u'ValueRef', u'value': u'18'},
#     u'type': u'Invocation'}],
#   [u'20',
#    {u'arguments': {u'image1': {u'type': u'ValueRef', u'value': u'19'},
#      u'image2': {u'type': u'ValueRef', u'value': u'16'}},
#     u'functionName': u'Image.eq',
#     u'type': u'Invocation'}],
#   [u'21',
#    {u'arguments': {},
#     u'functionName': u'Reducer.allNonZero',
#     u'type': u'Invocation'}],
#   [u'22',
#    {u'arguments': {u'image': {u'type': u'ValueRef', u'value': u'20'},
#      u'kernel': {u'type': u'ValueRef', u'value': u'17'},
#      u'reducer': {u'type': u'ValueRef', u'value': u'21'}},
#     u'functionName': u'Image.reduceNeighborhood',
#     u'type': u'Invocation'}],
#   [u'23',
#    {u'arguments': {u'image': {u'type': u'ValueRef', u'value': u'22'},
#      u'radius': 5},
#     u'functionName': u'Window.min',
#     u'type': u'Invocation'}],
#   [u'24',
#    {u'arguments': {u'argName': u'DEFAULT_EXPRESSION_IMAGE',
#      u'expression': u"b('B1')<200& b('B2')<400& b('B3')<300& b('B4')<2000& b('B5')<700& b('B7')<300"},
#     u'functionName': u'Image.parseExpression',
#     u'type': u'Invocation'}],
#   [u'25',
#    {u'arguments': {u'DEFAULT_EXPRESSION_IMAGE': {u'type': u'ValueRef',
#       u'value': u'15'}},
#     u'function': {u'type': u'ValueRef', u'value': u'24'},
#     u'type': u'Invocation'}],
#   [u'26',
#    {u'arguments': {u'image1': {u'type': u'ValueRef', u'value': u'25'},
#      u'image2': {u'type': u'ValueRef', u'value': u'16'}},
#     u'functionName': u'Image.eq',
#     u'type': u'Invocation'}],
#   [u'27',
#    {u'arguments': {u'image': {u'type': u'ValueRef', u'value': u'26'},
#      u'kernel': {u'type': u'ValueRef', u'value': u'17'},
#      u'reducer': {u'type': u'ValueRef', u'value': u'21'}},
#     u'functionName': u'Image.reduceNeighborhood',
#     u'type': u'Invocation'}],
#   [u'28',
#    {u'arguments': {u'image': {u'type': u'ValueRef', u'value': u'27'},
#      u'radius': 5},
#     u'functionName': u'Window.min',
#     u'type': u'Invocation'}],
#   [u'29',
#    {u'arguments': {u'image1': {u'type': u'ValueRef', u'value': u'28'},
#      u'image2': {u'type': u'ValueRef', u'value': u'23'}},
#     u'functionName': u'Image.and',
#     u'type': u'Invocation'}],
#   [u'30',
#    {u'arguments': {u'image1': {u'type': u'ValueRef', u'value': u'29'},
#      u'image2': {u'type': u'ValueRef', u'value': u'16'}},
#     u'functionName': u'Image.neq',
#     u'type': u'Invocation'}],
#   [u'31',
#    {u'arguments': {u'image': {u'type': u'ValueRef', u'value': u'15'},
#      u'mask': {u'type': u'ValueRef', u'value': u'30'}},
#     u'functionName': u'Image.mask',
#     u'type': u'Invocation'}],
#   [u'32',
#    {u'arguments': {u'value': 2},
#     u'functionName': u'Image.constant',
#     u'type': u'Invocation'}],
#   [u'33', [u'Land_Cover_Type_1']],
#   [u'34',
#    {u'arguments': {u'id': u'MCD12Q1/MCD12Q1_005_2009_01_01'},
#     u'functionName': u'Image.load',
#     u'type': u'Invocation'}],
#   [u'35',
#    {u'arguments': {u'bandSelectors': {u'type': u'ValueRef', u'value': u'33'},
#      u'input': {u'type': u'ValueRef', u'value': u'34'}},
#     u'functionName': u'Image.select',
#     u'type': u'Invocation'}],
#   [u'36',
#    {u'arguments': {u'image1': {u'type': u'ValueRef', u'value': u'35'},
#      u'image2': {u'type': u'ValueRef', u'value': u'32'}},
#     u'functionName': u'Image.eq',
#     u'type': u'Invocation'}],
#   [u'37',
#    {u'arguments': {u'image': {u'type': u'ValueRef', u'value': u'36'},
#      u'iterations': 2,
#      u'radius': 3},
#     u'functionName': u'Window.min',
#     u'type': u'Invocation'}],
#   [u'38',
#    {u'arguments': {u'value': 1},
#     u'functionName': u'Image.constant',
#     u'type': u'Invocation'}],
#   [u'39',
#    {u'arguments': {u'radius': 3},
#     u'functionName': u'Kernel.euclidean',
#     u'type': u'Invocation'}],
#   [u'40', [u'datamask']],
#   [u'41',
#    {u'arguments': {u'id': u'UMD/hansen/global_forest_change_2013'},
#     u'functionName': u'Image.load',
#     u'type': u'Invocation'}],
#   [u'42',
#    {u'arguments': {u'bandSelectors': {u'type': u'ValueRef', u'value': u'40'},
#      u'input': {u'type': u'ValueRef', u'value': u'41'}},
#     u'functionName': u'Image.select',
#     u'type': u'Invocation'}],
#   [u'43',
#    {u'arguments': {},
#     u'functionName': u'Reducer.max',
#     u'type': u'Invocation'}],
#   [u'44',
#    {u'arguments': {u'image': {u'type': u'ValueRef', u'value': u'42'},
#      u'kernel': {u'type': u'ValueRef', u'value': u'39'},
#      u'reducer': {u'type': u'ValueRef', u'value': u'43'}},
#     u'functionName': u'Image.reduceNeighborhood',
#     u'type': u'Invocation'}],
#   [u'45',
#    {u'arguments': {u'image': {u'type': u'ValueRef', u'value': u'44'},
#      u'iterations': 1},
#     u'functionName': u'Window.max',
#     u'type': u'Invocation'}],
#   [u'46',
#    {u'arguments': {u'image': {u'type': u'ValueRef', u'value': u'45'},
#      u'iterations': 3},
#     u'functionName': u'Window.min',
#     u'type': u'Invocation'}],
#   [u'47',
#    {u'arguments': {u'image': {u'type': u'ValueRef', u'value': u'46'}},
#     u'functionName': u'Window.max',
#     u'type': u'Invocation'}],
#   [u'48',
#    {u'arguments': {u'image1': {u'type': u'ValueRef', u'value': u'47'},
#      u'image2': {u'type': u'ValueRef', u'value': u'38'}},
#     u'functionName': u'Image.eq',
#     u'type': u'Invocation'}],
#   [u'49',
#    {u'arguments': {u'image': {u'type': u'ValueRef', u'value': u'31'}},
#     u'functionName': u'Image.mask',
#     u'type': u'Invocation'}],
#   [u'50',
#    {u'arguments': {u'image1': {u'type': u'ValueRef', u'value': u'49'},
#      u'image2': {u'type': u'ValueRef', u'value': u'48'}},
#     u'functionName': u'Image.and',
#     u'type': u'Invocation'}],
#   [u'51',
#    {u'arguments': {u'image1': {u'type': u'ValueRef', u'value': u'50'},
#      u'image2': {u'type': u'ValueRef', u'value': u'37'}},
#     u'functionName': u'Image.and',
#     u'type': u'Invocation'}],
#   [u'52',
#    {u'arguments': {u'image': {u'type': u'ValueRef', u'value': u'31'},
#      u'mask': {u'type': u'ValueRef', u'value': u'51'}},
#     u'functionName': u'Image.mask',
#     u'type': u'Invocation'}],
#   [u'53',
#    {u'arguments': {u'argName': u'DEFAULT_EXPRESSION_IMAGE',
#      u'expression': u"b('B7')>1550"},
#     u'functionName': u'Image.parseExpression',
#     u'type': u'Invocation'}],
#   [u'54',
#    {u'arguments': {u'DEFAULT_EXPRESSION_IMAGE': {u'type': u'ValueRef',
#       u'value': u'52'}},
#     u'function': {u'type': u'ValueRef', u'value': u'53'},
#     u'type': u'Invocation'}],
#   [u'55',
#    {u'arguments': {u'image1': {u'type': u'ValueRef', u'value': u'54'},
#      u'image2': {u'type': u'ValueRef', u'value': u'16'}},
#     u'functionName': u'Image.eq',
#     u'type': u'Invocation'}],
#   [u'56',
#    {u'arguments': {u'image': {u'type': u'ValueRef', u'value': u'55'},
#      u'radius': 5},
#     u'functionName': u'Window.min',
#     u'type': u'Invocation'}],
#   [u'57',
#    {u'arguments': {u'image': {u'type': u'ValueRef', u'value': u'52'}},
#     u'functionName': u'Image.mask',
#     u'type': u'Invocation'}],
#   [u'58',
#    {u'arguments': {u'image1': {u'type': u'ValueRef', u'value': u'57'},
#      u'image2': {u'type': u'ValueRef', u'value': u'56'}},
#     u'functionName': u'Image.and',
#     u'type': u'Invocation'}],
#   [u'59',
#    {u'arguments': {u'image': {u'type': u'ValueRef', u'value': u'52'},
#      u'mask': {u'type': u'ValueRef', u'value': u'58'}},
#     u'functionName': u'Image.mask',
#     u'type': u'Invocation'}],
#   [u'60',
#    {u'arguments': {u'argName': u'DEFAULT_EXPRESSION_IMAGE',
#      u'expression': u" b('B5')>3000"},
#     u'functionName': u'Image.parseExpression',
#     u'type': u'Invocation'}],
#   [u'61',
#    {u'arguments': {u'DEFAULT_EXPRESSION_IMAGE': {u'type': u'ValueRef',
#       u'value': u'59'}},
#     u'function': {u'type': u'ValueRef', u'value': u'60'},
#     u'type': u'Invocation'}],
#   [u'62',
#    {u'arguments': {u'image1': {u'type': u'ValueRef', u'value': u'61'},
#      u'image2': {u'type': u'ValueRef', u'value': u'16'}},
#     u'functionName': u'Image.eq',
#     u'type': u'Invocation'}],
#   [u'63',
#    {u'arguments': {u'image': {u'type': u'ValueRef', u'value': u'59'}},
#     u'functionName': u'Image.mask',
#     u'type': u'Invocation'}],
#   [u'64',
#    {u'arguments': {u'image1': {u'type': u'ValueRef', u'value': u'63'},
#      u'image2': {u'type': u'ValueRef', u'value': u'62'}},
#     u'functionName': u'Image.and',
#     u'type': u'Invocation'}],
#   [u'65',
#    {u'arguments': {u'image': {u'type': u'ValueRef', u'value': u'59'},
#      u'mask': {u'type': u'ValueRef', u'value': u'64'}},
#     u'functionName': u'Image.mask',
#     u'type': u'Invocation'}],
#   [u'66',
#    {u'arguments': {u'argName': u'DEFAULT_EXPRESSION_IMAGE',
#      u'expression': u" b('B4')<1750"},
#     u'functionName': u'Image.parseExpression',
#     u'type': u'Invocation'}],
#   [u'67',
#    {u'arguments': {u'DEFAULT_EXPRESSION_IMAGE': {u'type': u'ValueRef',
#       u'value': u'65'}},
#     u'function': {u'type': u'ValueRef', u'value': u'66'},
#     u'type': u'Invocation'}],
#   [u'68',
#    {u'arguments': {u'image1': {u'type': u'ValueRef', u'value': u'67'},
#      u'image2': {u'type': u'ValueRef', u'value': u'16'}},
#     u'functionName': u'Image.eq',
#     u'type': u'Invocation'}],
#   [u'69',
#    {u'arguments': {u'image': {u'type': u'ValueRef', u'value': u'68'},
#      u'radius': 3},
#     u'functionName': u'Window.min',
#     u'type': u'Invocation'}],
#   [u'70',
#    {u'arguments': {u'image': {u'type': u'ValueRef', u'value': u'65'}},
#     u'functionName': u'Image.mask',
#     u'type': u'Invocation'}],
#   [u'71',
#    {u'arguments': {u'image1': {u'type': u'ValueRef', u'value': u'70'},
#      u'image2': {u'type': u'ValueRef', u'value': u'69'}},
#     u'functionName': u'Image.and',
#     u'type': u'Invocation'}],
#   [u'72',
#    {u'arguments': {u'image': {u'type': u'ValueRef', u'value': u'65'},
#      u'mask': {u'type': u'ValueRef', u'value': u'71'}},
#     u'functionName': u'Image.mask',
#     u'type': u'Invocation'}],
#   [u'73',
#    {u'arguments': {u'value': {u'type': u'ValueRef', u'value': u'38'}},
#     u'functionName': u'Image.toByte',
#     u'type': u'Invocation'}],
#   [u'74',
#    {u'arguments': {u'tableId': u'ft:1yyaTIO-AOstBgk1a8M5oaO9LLhwu6AT_gCrSz6bf'},
#     u'functionName': u'Collection.loadTable',
#     u'type': u'Invocation'}],
#   [u'75',
#    {u'arguments': {u'color': 0,
#      u'featureCollection': {u'type': u'ValueRef', u'value': u'74'},
#      u'image': {u'type': u'ValueRef', u'value': u'73'}},
#     u'functionName': u'Image.paint',
#     u'type': u'Invocation'}],
#   [u'76',
#    {u'arguments': {u'image': {u'type': u'ValueRef', u'value': u'72'}},
#     u'functionName': u'Image.mask',
#     u'type': u'Invocation'}],
#   [u'77',
#    {u'arguments': {u'image1': {u'type': u'ValueRef', u'value': u'76'},
#      u'image2': {u'type': u'ValueRef', u'value': u'75'}},
#     u'functionName': u'Image.and',
#     u'type': u'Invocation'}],
#   [u'78',
#    {u'arguments': {u'image': {u'type': u'ValueRef', u'value': u'72'},
#      u'mask': {u'type': u'ValueRef', u'value': u'77'}},
#     u'functionName': u'Image.mask',
#     u'type': u'Invocation'}],
#   [u'79',
#    {u'arguments': {u'bandSelectors': {u'type': u'ValueRef', u'value': u'3'},
#      u'input': {u'type': u'ValueRef', u'value': u'78'}},
#     u'functionName': u'Image.select',
#     u'type': u'Invocation'}],
#   [u'80', [514, 803, 772, 2309, 2481, 1433]],
#   [u'81', [200, 445, 254, 3213, 1404, 464]],
#   [u'82', [484, 661, 775, 1720, 2664, 1880]],
#   [u'83', [424, 648, 498, 3131, 1417, 606]],
#   [u'84',
#    [{u'type': u'ValueRef', u'value': u'80'},
#     {u'type': u'ValueRef', u'value': u'81'},
#     {u'type': u'ValueRef', u'value': u'82'},
#     {u'type': u'ValueRef', u'value': u'83'}]],
#   [u'85',
#    {u'arguments': {u'endmembers': {u'type': u'ValueRef', u'value': u'84'},
#      u'image': {u'type': u'ValueRef', u'value': u'79'}},
#     u'functionName': u'Image.unmix',
#     u'type': u'Invocation'}],
#   [u'86',
#    {u'arguments': {u'bandSelectors': {u'type': u'ValueRef', u'value': u'2'},
#      u'input': {u'type': u'ValueRef', u'value': u'85'}},
#     u'functionName': u'Image.select',
#     u'type': u'Invocation'}],
#   [u'87',
#    {u'arguments': {u'image1': {u'type': u'ValueRef', u'value': u'86'},
#      u'image2': {u'type': u'ValueRef', u'value': u'1'}},
#     u'functionName': u'Image.gte',
#     u'type': u'Invocation'}],
#   [u'88',
#    {u'arguments': {u'image1': {u'type': u'ValueRef', u'value': u'87'},
#      u'image2': {u'type': u'ValueRef', u'value': u'0'}},
#     u'functionName': u'Image.multiply',
#     u'type': u'Invocation'}],
#   [u'89',
#    {u'arguments': {},
#     u'functionName': u'Reducer.sum',
#     u'type': u'Invocation'}],
#   [u'90',
#    {u'arguments': {u'image': {u'type': u'ValueRef', u'value': u'88'},
#      u'maxPixels': 10000000000.0,
#      u'reducer': {u'type': u'ValueRef', u'value': u'89'},
#      u'scale': 30},
#     u'functionName': u'Image.reduceRegion',
#     u'type': u'Invocation'}],
#   [u'91',
#    {u'arguments': {u'dictionary': {u'type': u'ValueRef', u'value': u'90'},
#      u'key': u'band_1'},
#     u'functionName': u'Dictionary.get',
#     u'type': u'Invocation'}]],
#  u'type': u'CompoundValue',
#  u'value': {u'type': u'ValueRef', u'value': u'91'}}

# %%
test_py['value']
# Out:
# {u'type': u'ValueRef', u'value': u'91'}

# %%
test_py[']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-166-4844bb8340b6> in <module>()
# ----> 1 json.dumps(test).get('system:time_start')
#
# AttributeError: 'str' object has no attribute 'get'
