# %% [markdown]
# ## Initialize Earth Engine and credentials

# %%
import ee

# Initialize the Earth Engine object, using authentication credentials
# that are saved on the server.
MY_SERVICE_ACCOUNT = "114451163354-f92f1kjpu1qnuarjoah2sta4tmesq1l4@developer.gserviceaccount.com"  
MY_PRIVATE_KEY_FILE = "/home/sami/srifai@gmail.com/Work/Research Files/Python scripts/API Project-77c2012c5687.p12"
ee.Initialize(ee.ServiceAccountCredentials(MY_SERVICE_ACCOUNT, MY_PRIVATE_KEY_FILE))

# %% [markdown]
# ### Necessary imports

# %%
# %matplotlib inline
from __future__ import print_function # For py 2.7 compat

import datetime
import ee
import numpy as np
import os
import matplotlib.pyplot as plt
from pylab import figure
import matplotlib.dates as mdates

from IPython.html import widgets
from IPython.display import display
from IPython.utils import traitlets
from IPython.core.display import Javascript

# %% [markdown]
# ## Create a Google Maps widget

# %%
class GoogleMapsWidget(widgets.DOMWidget):
    _view_name = traitlets.Unicode('GoogleMapsView', sync=True)
    value = traitlets.Unicode(sync=True)
    description = traitlets.Unicode(sync=True)
    lat = traitlets.CFloat(0, help="Center latitude, -90 to 90", sync=True)
    lng = traitlets.CFloat(0, help="Center longitude, -180 to 180", sync=True)
    zoom = traitlets.CInt(0, help="Zoom level, 0 to ~25", sync=True)
    bounds = traitlets.List([], help="Visible bounds, [W, S, E, N]", sync=True)
    
    def __init__(self, lng=0.0, lat=0.0, zoom=2):
        self.lng = lng
        self.lat = lat
        self.zoom = zoom
        
    def addLayer(self, image, vis_params=None, name=None, visible=True):
        mapid = image.getMapId(vis_params)
        self.send({'command':'addLayer', 'mapid': mapid['mapid'], 'token': mapid['token'], 'name': name, 'visible': visible})
        
    def center(self, lng, lat, zoom=None):
        self.send({'command': 'center', 'lng': lng, 'lat': lat, 'zoom': zoom})

# %%
# %%javascript
#
# require(["widgets/js/widget"], function(WidgetManager){
#     var maps = [];
#
#     // Define the GoogleMapsView
#     var GoogleMapsView = IPython.DOMWidgetView.extend({
#
#         render: function() {
#             // Resize widget element to be 100% wide
#             this.$el.css('width', '100%');
#
#             // iframe source;  just enough to load Google Maps and let us poll whether initialization is complete
#             var src='<html style="height:100%"><head>' +
#                 '<scr'+'ipt src="http://maps.googleapis.com/maps/api/js?sensor=false"></scr'+'ipt>' +
#                 '<scr'+'ipt>google.maps.event.addDomListener(window,"load",function(){ready=true});</scr'+'ipt>' +
#                 '</head>' +
#                 '<body style="height:100%; margin:0px; padding:0px"></body></html>';
#
#             // Create the Google Maps container element.
#             this.$iframe = $('<iframe />')
#                 .css('width', '100%')
#                 .css('height', '500px')
#                 .attr('srcdoc', src)
#                 .appendTo(this.$el);
#
#             var self = this; // hold onto this for initMapWhenReady
#
#             // Wait until maps library has finished loading in iframe, then create map
#             function initMapWhenReady() {
#                 // Iframe document and window
#                 var doc = self.$iframe[0].contentDocument;
#                 var win = self.$iframe[0].contentWindow;
#                 if (!win || !win.ready) {
#                     // Maps library not yet loaded;  try again soon
#                     setTimeout(initMapWhenReady, 20);
#                     return;
#                 }
#
#                 // Maps library finished loading.  Build map now.
#                 var mapOptions = {
#                     center: new win.google.maps.LatLng(self.model.get('lat'), self.model.get('lng')),
#                     zoom: self.model.get('zoom')
#                 };
#                 var mapDiv = $('<div />')
#                     .css('width', '100%')
#                     .css('height', '100%')
#                     .appendTo($(doc.body));
#                 self.map = new win.google.maps.Map(mapDiv[0], mapOptions);
#
#
#                 // Add an event listeners for user panning, zooming, and resizing map
#                 // TODO(rsargent): Bind self across all methods, and save some plumbing here
#                 win.google.maps.event.addListener(self.map, 'bounds_changed', function () {
#                     self.handleBoundsChanged();
#                 });
#
#                 self.initializeLayersControl();
#             }
#             initMapWhenReady();
#         },
#
#         LayersControl: function(widget, controlDiv, map) {
#             var win = widget.$iframe[0].contentWindow;
#             var chicago = new win.google.maps.LatLng(41.850033, -87.6500523);
#
#             // Set CSS styles for the DIV containing the control
#             // Setting padding to 5 px will offset the control
#             // from the edge of the map.
#             controlDiv.style.padding = '5px';
#
#             // Set CSS for the control border.
#             var $controlUI = $('<div />')
#                 .css('backgroundColor', 'white')
#                 .css('borderStyle', 'solid')
#                 .css('borderWidth', '1px')
#                 .css('cursor', 'pointer')
#                 .css('textAlign', 'center')
#                 .appendTo($(controlDiv));
#
#             // Set CSS for the control interior.
#             var $controlContents = $('<div />')
#                 .css('fontFamily', 'Arial,sans-serif')
#                 .css('fontSize', '12px')
#                 .css('paddingLeft', '4px')
#                 .css('paddingRight', '4px')
#                 .css('paddingTop', '0px')
#                 .css('paddingBottom', '0px')
#                 .appendTo($controlUI);
#
#             this.$controlTable = $('<table />')
#                 .append($('<tr><td colspan=2>Layers</td></tr>'))
#                 .appendTo($controlContents);
#         },
#
#         initializeLayersControl: function() {
#             var doc = this.$iframe[0].contentDocument;
#             var win = this.$iframe[0].contentWindow;
#
#             // Create the DIV to hold the control and call the LayersControl() constructor
#             // passing in this DIV.
#
#             var layersControlDiv = document.createElement('div');
#             this.layersControl = new this.LayersControl(this, layersControlDiv, this.map);
#
#             layersControlDiv.index = 1;
#             this.map.controls[win.google.maps.ControlPosition.TOP_RIGHT].push(layersControlDiv);
#         },
#
#         // Map geometry changed (pan, zoom, resize)
#         handleBoundsChanged: function() {
#             this.model.set('lng', this.map.getCenter().lng());
#             this.model.set('lat', this.map.getCenter().lat());
#             this.model.set('zoom', this.map.getZoom());
#             var bounds = this.map.getBounds();
#             var playgroundCompatible = [bounds.getSouthWest().lng(), bounds.getSouthWest().lat(),
#                                         bounds.getNorthEast().lng(), bounds.getNorthEast().lat()];
#             this.model.set('bounds', playgroundCompatible);
#             this.touch();
#         },
#
#         // Receive custom messages from Python backend
#         on_msg: function(msg) {
#             var win = this.$iframe[0].contentWindow;
#             if (msg.command == 'addLayer') {
#                 this.addLayer(msg.mapid, msg.token, msg.name, msg.visible);
#             } else if (msg.command == 'center') {
#                 this.map.setCenter(new win.google.maps.LatLng(msg.lat, msg.lng));
#                 if (msg.zoom !== null) {
#                     this.map.setZoom(msg.zoom);
#                 }
#             }
#         },
#
#         // Add an Earth Engine layer
#         addLayer: function(mapid, token, name, visible) {
#             var win = this.$iframe[0].contentWindow;
#             var eeMapOptions = {
#                 getTileUrl: function(tile, zoom) {
#                     var url = ['https://earthengine.googleapis.com/map',
#                                mapid, zoom, tile.x, tile.y].join("/");
#                     url += '?token=' + token
#                     return url;
#                 },
#                 tileSize: new win.google.maps.Size(256, 256),
#                 opacity: visible ? 1.0 : 0.0,
#             };
#
#             // Create the overlay map type
#             var mapType = new win.google.maps.ImageMapType(eeMapOptions);
#
#             // Overlay the Earth Engine generated layer
#             this.map.overlayMapTypes.push(mapType);
#
#             // Update layer visibility control
#             var maxSlider = 100;
#
#             function updateOpacity() {
#                 mapType.setOpacity($checkbox[0].checked ? $slider[0].value / 100.0 : 0);
#             }
#
#             var $checkbox = $('<input type="checkbox">')
#                 .prop('checked', visible)
#                 .change(updateOpacity);
#
#             var $slider = $('<input type="range" />')
#                 .prop('min', 0)
#                 .prop('max', maxSlider)
#                 .prop('value', maxSlider)
#                 .css('width', '60px')
#                 .on('input', updateOpacity);
#
#             // If user doesn't specify a layer name, create a default
#             if (name === null) {
#                 name = 'Layer ' + this.map.overlayMapTypes.length;
#             }
#
#             var $row = $('<tr />');
#             $('<td align="left" />').append($checkbox).append(name).appendTo($row);
#             $('<td />').append($slider).appendTo($row);
#
#             this.layersControl.$controlTable.append($row);
#         }
#     });
#
#     // Register the GoogleMapsView with the widget manager.
#     WidgetManager.register_widget_view('GoogleMapsView', GoogleMapsView);
# });

# %% [markdown]
# ## Filter the Landsat 5 Collection

# %%
import datetime
collection = 'LT5_L1T_SR' 
inYear = 2009
startDate = datetime.datetime(inYear, 7, 1); 
endDate = datetime.datetime(inYear,12,31);
path = 6
row = 63 
CC = 1
collectionSpec = ee.ImageCollection(collection)
collectionSpec = (collectionSpec
    .filterDate(startDate, endDate)
    .filterMetadata('default:WRS_PATH', 'EQUALS', path)
    .filterMetadata('default:WRS_ROW', 'EQUALS', row)
    .filterMetadata('CLOUD_COVER','less_than',CC)) 

imageBest = ee.Image(collectionSpec.sort('CLOUD_COVER').first())
imageWorst = ee.Image(collectionSpec.sort('CLOUD_COVER',False).first())

# %%
map = GoogleMapsWidget(lat=-3.75, lng=-73.5, zoom=9)
display(map) 

visParamsSR =  {'min': '0, 0, 0', 'max': '3000, 4000, 1000', 'bands': 'B5,B4,B3'};#Add layers 
map.addLayer(image=collectionSpec, vis_params=visParamsSR, name="CollectionSpec")
map.addLayer(image=imageBest, vis_params=visParamsSR, name="Best")
map.addLayer(image=imageWorst, vis_params=visParamsSR, name="Worst")

# %% [markdown]
# ## Inspect the metadata of the filtered collection

# %%
import datetime
collection = 'LT5_L1T_SR' 
inYear = 2009
startDate = datetime.datetime(inYear, 7, 1); 
endDate = datetime.datetime(inYear,12,31);
path = 6
row = 63 
CC = 1
collectionSpec = ee.ImageCollection(collection)
collectionSpec = (collectionSpec
    .filterDate(startDate, endDate)
    .filterMetadata('default:WRS_PATH', 'EQUALS', path)
    .filterMetadata('default:WRS_ROW', 'EQUALS', row)
    .filterMetadata('CLOUD_COVER','less_than',CC)) 

imageFirst = ee.Image(collectionSpec.sort('system:time_start').first())
imageLast = ee.Image(collectionSpec.sort('system:time_start',False).first())

map = GoogleMapsWidget(lat=-3.75, lng=-73.5, zoom=9)
display(map) 

visParamsSR =  {'min': '0, 0, 0', 'max': '3000, 4000, 1000', 'bands': 'B5,B4,B3'};#Add layers 
map.addLayer(image=imageFirst, vis_params=visParamsSR, name="First")
map.addLayer(image=imageLast, vis_params=visParamsSR, name="Last")

# %%
##image_object = ee.ImageCollection(collection)
##[method for method in dir(image_object) if not method.startswith('_')]

# %%
imageLast.getInfo()

# %% [markdown]
# ## testing the cloud and shadow thresholds

# %%
"""shadowMask = imageLast.expression(
  "b('B1')<200& b('B2')<400& b('B3')<300& b('B4')<2000& b('B5')<700& b('B7')<300"
  ).eq(0);
shadowBuffer = shadowMask.reduceNeighborhood(ee.call('Reducer.allNonZero'),ee.call('Kernel.circle',0.5)).focal_min(5);
cloudMask = imageLast.expression(
  "b('B1')>380& b('B2')>499 &b('B3')>375 & b('B4')>2850& b('B5')>1200& b('B7')>500"
  ).eq(0);
cloudBuffer = cloudMask.reduceNeighborhood(ee.call('Reducer.allNonZero'),ee.call('Kernel.circle',0.5)).focal_min(5);
combinedMask = shadowBuffer.And(cloudBuffer).neq(0);  
imageLast = imageLast.mask(combinedMask)"""

# %% [markdown]
# ## Define the Cloud & Shadow mask function

# %%
def applyCSmask(image): 
    shadowMask = image.expression("b('B1')<200& b('B2')<400& b('B3')<300& b('B4')<2000& b('B5')<700& b('B7')<300").eq(0);
    shadowBuffer = shadowMask.reduceNeighborhood(ee.call('Reducer.allNonZero'),ee.call('Kernel.circle',0.5)).focal_min(5);
    cloudMask = image.expression("b('B1')>380& b('B2')>499 &b('B3')>375 & b('B4')>2850& b('B5')>1200& b('B7')>500").eq(0);
    cloudBuffer = cloudMask.reduceNeighborhood(ee.call('Reducer.allNonZero'),ee.call('Kernel.circle',0.5)).focal_min(5);
    combinedMask = shadowBuffer.And(cloudBuffer).neq(0);  
    image = image.mask(combinedMask)
    return image

# %% [markdown]
# ## Define a Smoothed Version of the Hansen No-data mask [TESTING]

# %%
def applyHansenMask(image):
    hansenDataMask = ee.Image('UMD/hansen/global_forest_change_2013').select('datamask');
    hansenMaskSmooth = hansenDataMask.reduceNeighborhood('max',ee.call('Kernel.euclidean',3)).focal_max(iterations=1).focal_min(iterations=3).focal_max().eq(1);

    forestMask = ee.Image("MCD12Q1/MCD12Q1_005_2009_01_01").select('Land_Cover_Type_1').eq(2).focal_min(radius=3, iterations=2);
          
    ##necessary to combine masks, otherwise applying one mask will disregard previously applied masks
    combinedMask = image.mask().And(hansenMaskSmooth).And(forestMask);  
    image = image.mask(combinedMask);

    return image;

# %% [markdown]
# ## Define the Soil Mask - testing

# %%
def applySoilMask(image):
    imageMasked = image.And(image.mask(image.select('B7').gte(1550).focal_min(5))); #remove soil dominated pixels
    soil = image.expression("b('B7')>1550").eq(0).focal_min(5);
    combinedMask = image.mask().And(soil);
    image = image.mask(combinedMask);
    return image;

# %% [markdown]
# ## Define the Anomalous Pixel Mask - testing

# %%
def applyAnomPixelMask(image):
    imageMasked = image.mask().And(image.mask(image.select(['B5']).lte(4000).focal_min(20)));
    anoms = image.expression(" b('B5')>3000").eq(0);
    combinedMask = image.mask().And(anoms);
    image = image.mask(combinedMask);
    return image;

# %% [markdown]
# ## Define the Apply Water Mask - testing

# %%
def applyWaterMask(image):
    water = image.expression(" b('B4')<1750").eq(0).focal_min(3);
    combinedMask = image.mask().And(water);
    image = image.mask(combinedMask);
    return image;

# %%
masked = applyCSmask(imageLast);
masked = applyHansenMask(masked);
masked = applySoilMask(masked); 
masked = applyAnomPixelMask(masked);
masked = applyWaterMask(masked);

# %%
map = GoogleMapsWidget(lat=-3.75, lng=-73.5, zoom=9)
display(map) 
#imageFirst = csMask(imageFirst);
#imageLast = csMask(imageLast);
visParamsSR =  {'min': '0, 0, 0', 'max': '3000, 4000, 1000', 'bands': 'B5,B4,B3'};#Add layers 
map.addLayer(image=imageLast, vis_params=visParamsSR, name="Last", visible=False)
map.addLayer(image=imageFirst, vis_params=visParamsSR, name="First", visible=False)
map.addLayer(image=masked, vis_params=visParamsSR, name="masked", visible=True)

# %% [markdown]
# ## Apply the anthro mask

# %%
# anthroPoly = ee.FeatureCollection('ft:1rJT6SWmCN6hNJxhroEVYdbXv3NWX9nJk0stZR1Zh'); #old 
anthroPoly = ee.FeatureCollection('ft:1hi1BbXYlFceof3MbQEZwnSTLThADQbSGw68dCmJa'); #old 

#Start with a black image.
image1 = ee.Image(1).toByte();
#Fill and outline the polygons in two colors
image2 = image1.paint(anthroPoly, 0);
combinedMask = masked.mask().And(image2)
total = masked.mask(combinedMask);
##total = masked.And(masked.mask(image2.neq(2)));

map = GoogleMapsWidget(lat=-3.75, lng=-73.5, zoom=9)
display(map) 
map.addLayer(image=anthroPoly, name="anthro mask")
visParamsSR =  {'min': '0, 0, 0', 'max': '3000, 4000, 1000', 'bands': 'B5,B4,B3'};#Add layers 
map.addLayer(image=masked, vis_params=visParamsSR, name="TM", visible=False)
map.addLayer(image=total,  vis_params=visParamsSR, name="TM w/anthroMask")

# %% [markdown]
# ## Apply the SMA

# %%
##******* SMA ******************
toUnmix = total.select(['B1','B2','B3','B4','B5','B7']);
#Define Endmembers 
bdEM = [514, 803, 772, 2309, 2481, 1433]; 
soilEM = [484, 661, 775, 1720, 2664, 1880];
forestEM = [200, 445, 254, 3213, 1404, 464]; 
forestSecEM = [237, 481, 283, 4938, 1918, 637];
shadowEM = [296, 402, 307, 466, 68, 49];  
waterEM = [687, 1198, 1520, 1501, 68, 83]; 
forestHazeEM = [424, 648, 498, 3131, 1417, 606];
wetlandSoilEM = [293, 608, 470, 2611, 1783, 743];

## Apply SMA 
unmixBD = toUnmix.unmix([bdEM, forestEM, soilEM, forestHazeEM]);
unmixForest = toUnmix.unmix([bdEM, forestEM, forestSecEM]);
unmixSoils = toUnmix.unmix([bdEM, wetlandSoilEM, soilEM]);
unmixHaze = toUnmix.unmix([forestHazeEM,forestEM,forestSecEM]);

# %% [markdown]
# ## Decision tree of SMA's

# %%
bdReal = unmixBD.select(['band_0']).gte(0.2).And(unmixHaze.select(['band_0']).lte(0.05)).And(unmixBD.select(['band_2']).lte(0.8)).And(unmixForest.select(['band_0']).gte(0.2)); 
bdRealSmooth = bdReal.focal_max(2).focal_mode(2).eq(1);
blank = ee.Image(0); 
blank = blank.And(bdRealSmooth.eq(1)); 

output = ee.Image(0).where(bdRealSmooth.eq(1),1)

# %%
map = GoogleMapsWidget(lat=-3.75, lng=-73.5, zoom=9)
display(map) 
visParamsSMA =  {'bands': 'band_0,band_1,band_2'};#Add layers 
map.addLayer(image=unmixBD, vis_params=visParamsSMA, name="SMA-BD", visible=False)
map.addLayer(image=bdRealSmooth, name="BD-on/off", visible=True)
map.addLayer(image=total, vis_params=visParamsSR, name="SR masked", visible=True)
map.addLayer(image=output, name='Output');

# %% [markdown]
# ## Converting the Blowdown layer to vectors

# %%
#defining a region to limit the number of polygons returned; otherwise errors occur
region = ee.Geometry.Rectangle(-74.0698, -3.4284, -72.6251, -4.5025);

#Arguments(image, reducer, geometry, scale, geometryType, eightConnected, labelProperty, crs, 
#       crsTransform, bestEffort, maxPixels, tileScale, geometryInNativeProjection);
bdLab = ee.Image.reduceToVectors(output, geometry=region, maxPixels=30000000, eightConnected=True, scale=90)

# %%
map = GoogleMapsWidget(lat=-3.75, lng=-73.5, zoom=9)
display(map) 
map.addLayer(image=bdRealSmooth, name="BD-on/off")
map.addLayer(image=total, vis_params=visParamsSR, name="SR masked")
map.addLayer(bdLab, name="BD-redToVec")

# %%
##image_object = ee.Image(bdRealSmooth)
##[method for method in dir(image_object) if not method.startswith('_')]

# %%
bdLab.getInfo()
# Out:
# {u'columns': {u'count': u'Long',
#   u'geometry': u'Geometry',
#   u'label': u'Byte',
#   u'system:index': u'String'},
#  u'features': [{u'geometry': {u'coordinates': [[[-73.48963506455507,
#        -3.918004110404753],
#       [-73.48963944333408, -3.9155623044680956],
#       [-73.48720823435315, -3.9155579044518345],
#       [-73.48720384853222, -3.9179997076363446],
#       [-73.48963506455507, -3.918004110404753]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'+1021+636',
#    u'properties': {u'count': 9, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.48477543378853, -4.343681803582497],
#       [-73.48477705809852, -4.342867878842688],
#       [-73.48558789342106, -4.34286950875183],
#       [-73.48558951655549, -4.342055583687283],
#       [-73.48640035131693, -4.34205721241836],
#       [-73.48640197327617, -4.3412432870292434],
#       [-73.4872128074765, -4.341244914582583],
#       [-73.48721442826087, -4.340430988869064],
#       [-73.4888360958459, -4.340434240749775],
#       [-73.48883771458799, -4.339620314406084],
#       [-73.49127021566035, -4.339625184776713],
#       [-73.49127183149321, -4.338811257498065],
#       [-73.49289349866972, -4.338814499446481],
#       [-73.49289511246175, -4.338000571539313],
#       [-73.49532761291613, -4.338005427016364],
#       [-73.49532922380071, -4.33719149817671],
#       [-73.49776172439957, -4.337196344904862],
#       [-73.49776333237767, -4.336382415134205],
#       [-73.49938499923289, -4.336385641325991],
#       [-73.49938660517246, -4.335571710929457],
#       [-73.50019743818969, -4.335573322416188],
#       [-73.50019904295813, -4.334759391697916],
#       [-73.50100987541272, -4.334761002010985],
#       [-73.5010114790104, -4.333947070971139],
#       [-73.50344397559756, -4.333951895780761],
#       [-73.50344557629187, -4.333137963813384],
#       [-73.50425640822833, -4.3331395700407125],
#       [-73.50425480840049, -4.3339535023109095],
#       [-73.50506564150676, -4.333955107971192],
#       [-73.50506724046812, -4.333141175398341],
#       [-73.50587807301108, -4.333142779886265],
#       [-73.50587967080298, -4.332328846992835],
#       [-73.50669050278263, -4.332330450308729],
#       [-73.50669209940538, -4.331516517094893],
#       [-73.50750293082172, -4.331518119239081],
#       [-73.50750452627565, -4.330704185705006],
#       [-73.50831535712868, -4.330705786677817],
#       [-73.50831695141413, -4.329891852823673],
#       [-73.50912778170385, -4.329893452625433],
#       [-73.50912937482116, -4.329079518451388],
#       [-73.50994020454755, -4.329081117082423],
#       [-73.5099386122959, -4.329895051558138],
#       [-73.51237110588444, -4.329899843141908],
#       [-73.51236951592809, -4.33071377850358],
#       [-73.51399118156078, -4.330716969149318],
#       [-73.51399276978546, -4.329903033185783],
#       [-73.51642526789672, -4.329907811733609],
#       [-73.51642685322307, -4.329093874850444],
#       [-73.51885935144504, -4.329098644676558],
#       [-73.51885776871573, -4.32991258245981],
#       [-73.5204794374305, -4.329915758598577],
#       [-73.52048101842847, -4.329101820216086],
#       [-73.52129185237031, -4.3291034066824805],
#       [-73.52129343220273, -4.328289467982563],
#       [-73.52210426557892, -4.328291053280833],
#       [-73.52210584424611, -4.3274771142636554],
#       [-73.52291667705666, -4.327478698394129],
#       [-73.52291825455896, -4.326664759059859],
#       [-73.52372908680385, -4.326666342022864],
#       [-73.5237306631416, -4.325852402371671],
#       [-73.52291983176173, -4.325850819707546],
#       [-73.52292928868809, -4.320967183214933],
#       [-73.52211846279447, -4.32096560147679],
#       [-73.52212003876437, -4.320151662297305],
#       [-73.52130921403429, -4.320150079991088],
#       [-73.52131079056822, -4.319336141092788],
#       [-73.52049996700171, -4.319334558218826],
#       [-73.52050154409933, -4.318520619601875],
#       [-73.51969072169638, -4.318519036160498],
#       [-73.51969229935737, -4.3177050978250655],
#       [-73.51888147811798, -4.317703513816601],
#       [-73.51888305634199, -4.3168895757628505],
#       [-73.51726141649078, -4.316886405745954],
#       [-73.51725983654035, -4.31770034319983],
#       [-73.51644901620247, -4.317698756591526],
#       [-73.51645059701613, -4.316884819437836],
#       [-73.51563977784228, -4.31688323226327],
#       [-73.51564294029299, -4.315255358502562],
#       [-73.51483212314605, -4.315253771062576],
#       [-73.51483370478263, -4.314439834455728],
#       [-73.51402288879957, -4.314438246450299],
#       [-73.51402447099753, -4.3136243101261265],
#       [-73.51321365617834, -4.3136227215555865],
#       [-73.51321523893735, -4.312808785514252],
#       [-73.51240442528201, -4.31280719637893],
#       [-73.51240600860176, -4.311993260620604],
#       [-73.51078438392061, -4.311990080355598],
#       [-73.51078279887645, -4.312804015511431],
#       [-73.5083503615333, -4.3127992377180755],
#       [-73.50834877360005, -4.313613171950945],
#       [-73.50753796089468, -4.313611577319953],
#       [-73.50753637179642, -4.314425511232836],
#       [-73.50672555853116, -4.314423915433921],
#       [-73.50672396826756, -4.31523784902665],
#       [-73.50591315444241, -4.315236252059487],
#       [-73.50591156301316, -4.316050185331893],
#       [-73.50510074862812, -4.316048587196154],
#       [-73.5050991560329, -4.316862520148067],
#       [-73.50428834108796, -4.3168609208434265],
#       [-73.5042867473264, -4.317674853474681],
#       [-73.50266511662024, -4.317671651660357],
#       [-73.5026635208287, -4.318485583667807],
#       [-73.50185270506765, -4.318483981157633],
#       [-73.50185430172252, -4.3176700494533184],
#       [-73.50104348712858, -4.3176684463797],
#       [-73.50104188961038, -4.3184823777807155],
#       [-73.49942025960786, -4.3184791684266495],
#       [-73.49942185885276, -4.317665237632726],
#       [-73.49861104517117, -4.317663631959373],
#       [-73.4986142444743, -4.316035770925035],
#       [-73.49942505642971, -4.316037375990805],
#       [-73.49942825278951, -4.314409514276814],
#       [-73.50023906332368, -4.314411117869086],
#       [-73.50024066018464, -4.313597186681447],
#       [-73.50186228044008, -4.313600390661463],
#       [-73.50186387527224, -4.312786458849061],
#       [-73.50267468499337, -4.312788059237295],
#       [-73.50267627865954, -4.311974127103762],
#       [-73.5034870878221, -4.311975726323429],
#       [-73.50348868032263, -4.311161793868927],
#       [-73.50429948892659, -4.311163391920356],
#       [-73.50430108026181, -4.3103494591450575],
#       [-73.5051118883072, -4.310351056028574],
#       [-73.50511506834452, -4.3087231898187355],
#       [-73.50592587496979, -4.308724785232192],
#       [-73.5059274636724, -4.307910851797823],
#       [-73.50673826973924, -4.307912446044184],
#       [-73.50674303144623, -4.305470644726297],
#       [-73.50593222796256, -4.305469051386858],
#       [-73.50593381545337, -4.304655117880594],
#       [-73.50512301313337, -4.304653523979495],
#       [-73.5051246011818, -4.303839590757735],
#       [-73.50431380002546, -4.303837996295306],
#       [-73.50431538863117, -4.303024063358217],
#       [-73.50350458863848, -4.303022468334786],
#       [-73.5035077666604, -4.301394603012324],
#       [-73.50269696869142, -4.301393007731179],
#       [-73.50269855810713, -4.300579075345974],
#       [-73.50188776130165, -4.300577479504648],
#       [-73.50188935127348, -4.299763547404615],
#       [-73.50107855563148, -4.299761951003439],
#       [-73.50108014615913, -4.298948019188742],
#       [-73.50026935168061, -4.298946422228043],
#       [-73.50027094276373, -4.298132490698849],
#       [-73.49216302332412, -4.298116476681238],
#       [-73.49216142364712, -4.298930405166923],
#       [-73.48486431455186, -4.298915916043234],
#       [-73.4848627068333, -4.299729841757788],
#       [-73.48161955177747, -4.299723378487101],
#       [-73.48161794031294, -4.300537302955792],
#       [-73.48080715145855, -4.300535684673396],
#       [-73.4808055388263, -4.301349608816737],
#       [-73.47999474942009, -4.301347989363695],
#       [-73.4799931356198, -4.302161913181512],
#       [-73.47918234566175, -4.302160292557498],
#       [-73.4791807306931, -4.302974216049625],
#       [-73.47836994018326, -4.302972594254311],
#       [-73.4783683240459, -4.30378651742058],
#       [-73.47917911541609, -4.303788139523773],
#       [-73.47917749983071, -4.304602062979939],
#       [-73.47998829236975, -4.304603684527099],
#       [-73.47998667733668, -4.305417608272997],
#       [-73.48079747104461, -4.305419229263795],
#       [-73.48079424177567, -4.307047077316724],
#       [-73.48160503751348, -4.307048698058223],
#       [-73.4815953474831, -4.311932243629383],
#       [-73.47754134602896, -4.31192412204623],
#       [-73.47753972563558, -4.312738044706448],
#       [-73.47429652657947, -4.312731530629145],
#       [-73.47429490242814, -4.313545452037501],
#       [-73.47348410257483, -4.313543821045444],
#       [-73.47348247725168, -4.314357742126901],
#       [-73.47267167684544, -4.314356109960105],
#       [-73.4726700503501, -4.315170030714494],
#       [-73.47185924939093, -4.315168397372631],
#       [-73.47185762172313, -4.3159823177997865],
#       [-73.47104682021103, -4.315980683282532],
#       [-73.47104519137041, -4.316794603382282],
#       [-73.47185599374546, -4.316796238208903],
#       [-73.47185110795326, -4.319237999327984],
#       [-73.47266191322802, -4.3192396342158546],
#       [-73.47265865621124, -4.320867475490059],
#       [-73.47346946352309, -4.320869110129157],
#       [-73.47346457826741, -4.323310872832142],
#       [-73.47427538848113, -4.323312507530693],
#       [-73.47427213182527, -4.324940349860105],
#       [-73.47508294407743, -4.324941984308411],
#       [-73.4750796879137, -4.3265698271829605],
#       [-73.47589050220479, -4.326571461380368],
#       [-73.47588561823575, -4.329013226482241],
#       [-73.47669643543168, -4.329014860736486],
#       [-73.47669317963832, -4.330642704664074],
#       [-73.47750399887451, -4.330644338665948],
#       [-73.47749911546589, -4.333086105346291],
#       [-73.47830993760908, -4.333087739403205],
#       [-73.47830668219258, -4.334715584382378],
#       [-73.47911750637735, -4.334717218185447],
#       [-73.4791126235389, -4.337158986442075],
#       [-73.47992345063282, -4.337160620298389],
#       [-73.47992019559969, -4.33878846632769],
#       [-73.48073102473654, -4.338790099928686],
#       [-73.48072777020563, -4.34041794650064],
#       [-73.48153860138588, -4.340419579845665],
#       [-73.48153697452616, -4.34123350341186],
#       [-73.48234780688226, -4.341235136193005],
#       [-73.48234618058265, -4.342049060048315],
#       [-73.4831570141146, -4.342050692265253],
#       [-73.48315538837547, -4.342864616409515],
#       [-73.48396622308326, -4.342866248061916],
#       [-73.48396459790489, -4.343680172494963],
#       [-73.48477543378853, -4.343681803582497]],
#      [[-73.51643635886313, -4.324210253172348],
#       [-73.51644110762169, -4.321768442089736],
#       [-73.51968440805064, -4.321774789322076],
#       [-73.51967966966436, -4.324216604003997],
#       [-73.51643635886313, -4.324210253172348]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'+1024+1159',
#    u'properties': {u'count': 2000, u'label': 0},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.47919617967628, -3.864265479219486],
#       [-73.47919762943751, -3.8634515468359547],
#       [-73.48000797933273, -3.8634530024646523],
#       [-73.48000942801464, -3.8626390697574107],
#       [-73.48081977744582, -3.8626405243036093],
#       [-73.48082122504874, -3.8618265912728234],
#       [-73.48163157401584, -3.8618280447368507],
#       [-73.48163302054012, -3.8610141113826866],
#       [-73.48244336904312, -3.861015563764868],
#       [-73.4824448144891, -3.860201630087498],
#       [-73.48163446675721, -3.860200178012383],
#       [-73.4816359126671, -3.8593862446259384],
#       [-73.48082556601337, -3.8593847920835995],
#       [-73.48082701238687, -3.8585708589882475],
#       [-73.48001666681128, -3.8585694059790145],
#       [-73.48001811364803, -3.8577554731749215],
#       [-73.4792077691506, -3.8577540196991227],
#       [-73.4792092164503, -3.8569400871864548],
#       [-73.478398873031, -3.8569386332444164],
#       [-73.47839742496085, -3.857752565449367],
#       [-73.47758708107897, -3.857751110425656],
#       [-73.47758563193034, -3.8585650423065907],
#       [-73.47677528758584, -3.8585635862008814],
#       [-73.47677383735842, -3.859377517757636],
#       [-73.4759634925513, -3.8593760605695997],
#       [-73.47596204124477, -3.8601899918020037],
#       [-73.47515169597507, -3.8601885335313137],
#       [-73.47515024358907, -3.8610024644391983],
#       [-73.47596058962988, -3.861003923018263],
#       [-73.47595913770664, -3.861817854218379],
#       [-73.47676948482709, -3.8618193123310514],
#       [-73.47676803336694, -3.8626332438232276],
#       [-73.477578381567, -3.8626347014691795],
#       [-73.47757693057028, -3.863448633253254],
#       [-73.47838727984995, -3.8634500904321554],
#       [-73.47838582931698, -3.8642640225079634],
#       [-73.47919617967628, -3.864265479219486]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'+1032+570',
#    u'properties': {u'count': 41, u'label': 0},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.47906887242544, -3.9350775343641318],
#       [-73.4790718251903, -3.9334496724173547],
#       [-73.4798822420566, -3.9334511544981945],
#       [-73.47988666653863, -3.9310093605318785],
#       [-73.48069708135598, -3.9310108409012003],
#       [-73.48070150071402, -3.9285690458646525],
#       [-73.47827026425044, -3.9285646051590395],
#       [-73.47826583782705, -3.931006397427144],
#       [-73.47745542393315, -3.931004914691733],
#       [-73.47745394705736, -3.9318188451069678],
#       [-73.47664353268624, -3.931817361274767],
#       [-73.47663761895849, -3.9350730815388806],
#       [-73.47906887242544, -3.9350775343641318]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'+1034+657',
#    u'properties': {u'count': 26, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.4749368474275, -4.3973809218574695],
#       [-73.47493850257315, -4.3965670020148515],
#       [-73.47574939186293, -4.396568662750155],
#       [-73.47575104582013, -4.3957547425805625],
#       [-73.47656193454006, -4.395756402124988],
#       [-73.47656358730916, -4.394942481628584],
#       [-73.47737447545921, -4.394944139982459],
#       [-73.47737612704054, -4.394130219159417],
#       [-73.47818701462074, -4.39413187632307],
#       [-73.4781903150998, -4.3925040340056825],
#       [-73.47737942927658, -4.392502377458257],
#       [-73.47738107993128, -4.391688456580147],
#       [-73.47657019529517, -4.39168679945938],
#       [-73.47657184651911, -4.390872878871196],
#       [-73.47738273027713, -4.390874535683689],
#       [-73.47739097737335, -4.386804930926289],
#       [-73.47658009800325, -4.386803275655165],
#       [-73.4765899895865, -4.381919751191107],
#       [-73.47577911578551, -4.38191809689012],
#       [-73.47578900149844, -4.377034573617531],
#       [-73.47497813326078, -4.3770329202886264],
#       [-73.4749880130919, -4.372149398209176],
#       [-73.4741771504118, -4.372147745854299],
#       [-73.47418866892279, -4.366450304758318],
#       [-73.47337781266762, -4.3664486536883285],
#       [-73.47338439135633, -4.363192973896199],
#       [-73.47257353890171, -4.363191323186147],
#       [-73.47257682813276, -4.361563483798812],
#       [-73.4717659777324, -4.361561832831527],
#       [-73.47176926746808, -4.359933993989756],
#       [-73.4709584191215, -4.359932342765897],
#       [-73.47096170936051, -4.358304504470035],
#       [-73.4701508630672, -4.3583028529902546],
#       [-73.47015415380824, -4.356675015240653],
#       [-73.46934330956769, -4.356673363505607],
#       [-73.46934660080946, -4.355045526302615],
#       [-73.46853575862119, -4.355043874312957],
#       [-73.46853740464708, -4.354229955994041],
#       [-73.46772656364008, -4.354228303440378],
#       [-73.46772821022587, -4.353414385413312],
#       [-73.46691737040013, -4.353412732295971],
#       [-73.4669190175455, -4.3525988145609205],
#       [-73.46610817890102, -4.352597160880231],
#       [-73.46610982660563, -4.351783243437362],
#       [-73.46529898914241, -4.351781589193654],
#       [-73.46529734056764, -4.352595506325983],
#       [-73.46448650254551, -4.352593850898176],
#       [-73.46448485278913, -4.3534077677016025],
#       [-73.4636740142081, -4.35340611108937],
#       [-73.46367236326982, -4.354220027563728],
#       [-73.46286152412986, -4.354218369766745],
#       [-73.46285987200933, -4.355032285911864],
#       [-73.46204903231049, -4.3550306269298025],
#       [-73.46204737900739, -4.355844542745514],
#       [-73.46285821957707, -4.355846202038776],
#       [-73.46285160673044, -4.359101866364274],
#       [-73.46366245109678, -4.359103526027472],
#       [-73.46365583674954, -4.362359191305526],
#       [-73.46446668491504, -4.362360851337357],
#       [-73.46445841433307, -4.366430434078937],
#       [-73.46526926717317, -4.366432094788815],
#       [-73.46526264859504, -4.369687761896392],
#       [-73.46607350523992, -4.369689422972135],
#       [-73.46606688517728, -4.372945091029663],
#       [-73.46687774562942, -4.372946752469969],
#       [-73.4668694679245, -4.377016338682529],
#       [-73.46768033306145, -4.377018000796326],
#       [-73.46767370880204, -4.380273670677998],
#       [-73.46848457775185, -4.380275333153591],
#       [-73.46847795202405, -4.383531003982607],
#       [-73.4692888247892, -4.383532666818692],
#       [-73.46928219759813, -4.386788338594199],
#       [-73.4700930741811, -4.386790001789472],
#       [-73.47008478759383, -4.390859592645048],
#       [-73.47089566887502, -4.390861256507795],
#       [-73.47089401150458, -4.391675174933458],
#       [-73.471704893974, -4.391676838224351],
#       [-73.47170323717164, -4.392490756941084],
#       [-73.47089235382397, -4.392489093340767],
#       [-73.4708890375322, -4.394116930100313],
#       [-73.47169992263682, -4.394118594319479],
#       [-73.47169826490438, -4.394932512981132],
#       [-73.47250915119774, -4.394934176627626],
#       [-73.47250749403416, -4.395748095580178],
#       [-73.47331838151628, -4.395749758653673],
#       [-73.47331672492189, -4.396563677896952],
#       [-73.47412761359276, -4.3965653403971166],
#       [-73.47412595756789, -4.397379259930962],
#       [-73.4749368474275, -4.3973809218574695]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'+1036+1225',
#    u'properties': {u'count': 497, u'label': 0},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.46364857140225, -3.9472580874977],
#       [-73.46365305887363, -3.9448163129216085],
#       [-73.46122179472135, -3.9448118038970503],
#       [-73.46121730015538, -3.9472535756736367],
#       [-73.46364857140225, -3.9472580874977]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'+1053+672',
#    u'properties': {u'count': 9, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.45381274942251, -4.006656192943666],
#       [-73.45381427786626, -4.0058422730579055],
#       [-73.45462475569309, -4.005843807434148],
#       [-73.45462628302357, -4.005029887218886],
#       [-73.45543676036304, -4.005031420478835],
#       [-73.45543828658057, -4.0042174999342395],
#       [-73.45624876343267, -4.004219032078221],
#       [-73.45625028853759, -4.003405111204461],
#       [-73.45706076490231, -4.003406642232801],
#       [-73.45706228889493, -4.002592721030045],
#       [-73.45787276477229, -4.002594250943072],
#       [-73.45787428765296, -4.001780329411488],
#       [-73.45868476304292, -4.001781858209527],
#       [-73.45868780626894, -4.000154014472301],
#       [-73.45949828037227, -4.000155541843928],
#       [-73.45949980071812, -3.999341619638459],
#       [-73.46031027433423, -3.9993431458959163],
#       [-73.46031179356926, -3.998529223362128],
#       [-73.46112226669815, -3.9985307485057424],
#       [-73.46112378482269, -3.997716825643804],
#       [-73.46193425746436, -3.9977183496739035],
#       [-73.46193577447875, -3.996904426483984],
#       [-73.46274624663317, -3.996905949400893],
#       [-73.46274927813107, -3.9952781023487067],
#       [-73.46355974899998, -3.9952796238418258],
#       [-73.463561263484, -3.994465699979733],
#       [-73.46437173386583, -3.9944672203604785],
#       [-73.46437324724083, -3.9936532961709132],
#       [-73.4651837171356, -3.9936548154396148],
#       [-73.46518522940191, -3.9928408909227455],
#       [-73.46599569880959, -3.9928424090797288],
#       [-73.46599720996757, -3.9920284842357234],
#       [-73.46680767888817, -3.992030001281315],
#       [-73.4668091889381, -3.9912160761103417],
#       [-73.46761965737163, -3.9912175920448676],
#       [-73.46762267494589, -3.9895897410326326],
#       [-73.46843314209517, -3.9895912555464794],
#       [-73.46843464962, -3.9887773297053903],
#       [-73.46924511628232, -3.9887788431089897],
#       [-73.46924662270027, -3.9879649169414417],
#       [-73.47005708887569, -3.9879664292351205],
#       [-73.4700585941871, -3.9871525027412837],
#       [-73.47086905987555, -3.9871540139253683],
#       [-73.47087056408074, -3.986340087105407],
#       [-73.47168102928228, -3.9863415971802256],
#       [-73.47168403517145, -3.984713742871732],
#       [-73.47249449908988, -3.9847152515284914],
#       [-73.47249600077437, -3.9839013240401298],
#       [-73.473306464206, -3.9839028315884404],
#       [-73.47330796478543, -3.983088903774465],
#       [-73.47411842773029, -3.983090410214653],
#       [-73.47411992720497, -3.9822764820752345],
#       [-73.47493038966303, -3.9822779874076253],
#       [-73.4749318880333, -3.9814640589429304],
#       [-73.47574235000457, -3.9814655631678533],
#       [-73.47574534422836, -3.9798377055716028],
#       [-73.47655580491764, -3.9798392083810867],
#       [-73.47655730077166, -3.9790252792497047],
#       [-73.47736776097432, -3.9790267809525375],
#       [-73.47736925572507, -3.978212851496388],
#       [-73.47817971544107, -3.9782143520928956],
#       [-73.4781812090889, -3.977400422312148],
#       [-73.47899166831826, -3.9774019218026573],
#       [-73.47899316086345, -3.976587991697479],
#       [-73.47980361960619, -3.9765894900823167],
#       [-73.4798051110491, -3.975775559652878],
#       [-73.48061556930517, -3.9757770569323707],
#       [-73.48061854967953, -3.9741491954086854],
#       [-73.4814290066549, -3.9741506912758524],
#       [-73.48143049558685, -3.9733367601817817],
#       [-73.48224095207573, -3.973338254944422],
#       [-73.48224243990651, -3.9725243235265957],
#       [-73.4830528959089, -3.9725258171850357],
#       [-73.4830543826389, -3.9717118854436264],
#       [-73.48386483815477, -3.9717133779981926],
#       [-73.4838663237843, -3.970899445933367],
#       [-73.4846767788137, -3.9709009373843864],
#       [-73.48467974756566, -3.9692730725916454],
#       [-73.48549020131547, -3.9692745626329584],
#       [-73.48549168443843, -3.968460629905216],
#       [-73.48630213770188, -3.9684621188437994],
#       [-73.48630361972553, -3.9676481857931485],
#       [-73.48711407250265, -3.9676496736293303],
#       [-73.48711555342727, -3.966835740255941],
#       [-73.48792600571804, -3.9668372269900476],
#       [-73.48792748554399, -3.966023293294088],
#       [-73.4887379373484, -3.9660247789264456],
#       [-73.48873941607603, -3.965210844908083],
#       [-73.48954986739408, -3.9652123294390185],
#       [-73.4895528223475, -3.9635844607412603],
#       [-73.49036327238727, -3.963585943865599],
#       [-73.49036474861359, -3.962772009186376],
#       [-73.49117519816714, -3.962773491210112],
#       [-73.49117667329627, -3.961959556208994],
#       [-73.49198712236362, -3.961961037132453],
#       [-73.49198859639588, -3.961147101809609],
#       [-73.49279904497703, -3.961148581633117],
#       [-73.49280051791273, -3.9603346459887185],
#       [-73.49361096600768, -3.9603361247126005],
#       [-73.49361390938175, -3.9587082527644823],
#       [-73.49442435619952, -3.958709730084392],
#       [-73.49442582663838, -3.9578957937808448],
#       [-73.49523627297009, -3.957897270001947],
#       [-73.49523774231355, -3.957083333377353],
#       [-73.49604818815922, -3.9570848084999755],
#       [-73.4960496564076, -3.9562708715545014],
#       [-73.49686010176721, -3.956272345578971],
#       [-73.49686156892088, -3.9554584083127855],
#       [-73.49767201379441, -3.9554598812394297],
#       [-73.49767347985366, -3.954645943652701],
#       [-73.49848392424114, -3.954647415481845],
#       [-73.49848685386755, -3.953019539651125],
#       [-73.49929729697914, -3.953021010079406],
#       [-73.49929876054678, -3.9522070718355855],
#       [-73.50010920317246, -3.952208541167185],
#       [-73.50011066564686, -3.9513946026033295],
#       [-73.50092110778662, -3.951396070838574],
#       [-73.50092256916808, -3.9505821319548535],
#       [-73.50173301082195, -3.95058359909407],
#       [-73.50173447111081, -3.9497696598906535],
#       [-73.50254491227875, -3.9497711259341677],
#       [-73.50254637147532, -3.9489571864112207],
#       [-73.50173593109639, -3.948955720670739],
#       [-73.50173739077871, -3.948141781434331],
#       [-73.50092695149189, -3.9481403152047028],
#       [-73.50092841165964, -3.947326376254999],
#       [-73.50011797346494, -3.9473249095365532],
#       [-73.50011943411776, -3.94651097087372],
#       [-73.49930899701518, -3.946509503666785],
#       [-73.49931045815279, -3.9456955652909884],
#       [-73.4985000221423, -3.945694097595893],
#       [-73.49850148376436, -3.9448801595072993],
#       [-73.49607017992152, -3.9448757525839726],
#       [-73.49607164360374, -3.9440618153909366],
#       [-73.49526121038608, -3.944060345137808],
#       [-73.49526267455174, -3.9432464082326297],
#       [-73.49607310698157, -3.943247878181421],
#       [-73.49607457005499, -3.9424339409554325],
#       [-73.49769543425226, -3.9424368778712746],
#       [-73.49769689544624, -3.9416229400206326],
#       [-73.49850732721352, -3.941624406988173],
#       [-73.49850878731604, -3.940810468817219],
#       [-73.49931921859987, -3.940811934690217],
#       [-73.49932067761128, -3.939997996199121],
#       [-73.50013110841165, -3.9399994609779023],
#       [-73.50013256633228, -3.9391855221668313],
#       [-73.50094299664917, -3.939186985851723],
#       [-73.50094445347935, -3.9383730467208453],
#       [-73.50175488331277, -3.938374509312175],
#       [-73.50175342726946, -3.939188448746241],
#       [-73.50418472094913, -3.939192832687535],
#       [-73.50418326696374, -3.9400067730137334],
#       [-73.50499369958305, -3.940008233049274],
#       [-73.50499224608213, -3.9408221736615507],
#       [-73.50580267979127, -3.940823633208917],
#       [-73.50580413250498, -3.9400096922942685],
#       [-73.50661456572934, -3.940011150748717],
#       [-73.50661311380284, -3.940825091965572],
#       [-73.50904441765047, -3.940829463491259],
#       [-73.50904586721529, -3.9400155213687675],
#       [-73.50985630164772, -3.9400169766610142],
#       [-73.50985775012371, -3.9392030342205193],
#       [-73.51066818407067, -3.939204488420825],
#       [-73.51066963145814, -3.938390545662497],
#       [-73.51148006491964, -3.9383919987711886],
#       [-73.51148151121896, -3.937578055695194],
#       [-73.512291944195, -3.9375795077125972],
#       [-73.51229338940647, -3.9367655643191064],
#       [-73.51310382189703, -3.9367670152455485],
#       [-73.51310526602099, -3.935953071534728],
#       [-73.51391569802607, -3.9359545213705354],
#       [-73.51391714106283, -3.9351405773425547],
#       [-73.51472757258246, -3.9351420260880547],
#       [-73.51472901453235, -3.934328081743082],
#       [-73.51553944556649, -3.9343295293986014],
#       [-73.51554088642985, -3.933515584736804],
#       [-73.51635131697851, -3.9335170313026695],
#       [-73.51635419623251, -3.931889141329347],
#       [-73.51716462551012, -3.931890586505814],
#       [-73.51716606390124, -3.93107664119446],
#       [-73.51797649269352, -3.93107808528209],
#       [-73.51797792999928, -3.9302641396544225],
#       [-73.51878835830622, -3.9302655826535426],
#       [-73.51878979452692, -3.929451636709728],
#       [-73.51960022234854, -3.9294530786206656],
#       [-73.5196016574845, -3.9286391323608725],
#       [-73.52041208482079, -3.9286405731839547],
#       [-73.52041495262445, -3.9270126800163534],
#       [-73.52122537869079, -3.927014119452657],
#       [-73.52122681135897, -3.9262001725450206],
#       [-73.52203723694014, -3.9262016108942857],
#       [-73.52203866852473, -3.9253876636711804],
#       [-73.52284909362074, -3.9253891009337334],
#       [-73.52285195432447, -3.9237612058405436],
#       [-73.52204153079656, -3.9237597691758292],
#       [-73.52204725175082, -3.9205039799886556],
#       [-73.52123683165628, -3.9205025437329706],
#       [-73.52124112158022, -3.9180607025680243],
#       [-73.5220515393258, -3.9180621379264715],
#       [-73.52205296791924, -3.9172481905397025],
#       [-73.52286338518124, -3.917249624813081],
#       [-73.52286481269307, -3.9164356771110507],
#       [-73.52367522947155, -3.9164371102996873],
#       [-73.52367665590211, -3.9156231622825612],
#       [-73.52448707219702, -3.9156245943867836],
#       [-73.52448849754661, -3.914810646054734],
#       [-73.52529891335797, -3.9148120770748687],
#       [-73.52530033762696, -3.913998128428061],
#       [-73.52611075295474, -3.913999558364435],
#       [-73.52611217614344, -3.9131856094030377],
#       [-73.52854342157029, -3.9131898936063196],
#       [-73.52854484211565, -3.912375943734807],
#       [-73.5334073363151, -3.912384489158281],
#       [-73.53340875187351, -3.911570537487298],
#       [-73.53421916783167, -3.9115719586803426],
#       [-73.53422058231187, -3.910758006696428],
#       [-73.5350309977853, -3.9107594268081542],
#       [-73.53503241118769, -3.909945474511472],
#       [-73.53584282617636, -3.9099468935422093],
#       [-73.53584423850123, -3.9091329409329307],
#       [-73.53665465300519, -3.9091343588830028],
#       [-73.53665606425285, -3.9083204059612946],
#       [-73.53746647827207, -3.90832182283103],
#       [-73.53746788844288, -3.9075078695970626],
#       [-73.53827830197734, -3.9075092853867868],
#       [-73.53828111987008, -3.9058813782783726],
#       [-73.53909153213941, -3.9058827926927826],
#       [-73.53909293986185, -3.905068838818509],
#       [-73.53990335164659, -3.9050702521537266],
#       [-73.53990475829329, -3.9042562979677],
#       [-73.54071516959344, -3.904257710224052],
#       [-73.54071657516478, -3.903443755726443],
#       [-73.54152698598034, -3.9034451669042562],
#       [-73.5415283904766, -3.9026312120952302],
#       [-73.54233880080758, -3.9026326221948304],
#       [-73.54234020422912, -3.901818667074558],
#       [-73.54315061407549, -3.901820076096273],
#       [-73.54315341847493, -3.9001921652173053],
#       [-73.54396382705745, -3.9001935728668173],
#       [-73.54396522803586, -3.899379617108294],
#       [-73.54477563613393, -3.899381023680738],
#       [-73.54477703603875, -3.8985670676114754],
#       [-73.5455874436524, -3.8985684731071784],
#       [-73.54558884248395, -3.8977545167273475],
#       [-73.54639924961315, -3.8977559211466355],
#       [-73.54640064737178, -3.8969419644564005],
#       [-73.54721105401653, -3.896943367799602],
#       [-73.54721245070257, -3.8961294107991353],
#       [-73.55612693459926, -3.8961447927430988],
#       [-73.55612832243017, -3.8953308325033524],
#       [-73.57395737894726, -3.8953613062132595],
#       [-73.57395874936675, -3.8945473395706838],
#       [-73.59178792843801, -3.8945774286517487],
#       [-73.59178928145265, -3.8937634556856575],
#       [-73.59422054153562, -3.89376752858146],
#       [-73.5942218919317, -3.8929535547452216],
#       [-73.59503231175067, -3.8929549105301127],
#       [-73.59503366108456, -3.892140936393358],
#       [-73.59584408041015, -3.8921422911128944],
#       [-73.59584542868218, -3.891328316675791],
#       [-73.59665584751437, -3.8913296703302978],
#       [-73.59665719472487, -3.8905156955930136],
#       [-73.59746761306369, -3.8905170481828195],
#       [-73.59746895921296, -3.889703073145522],
#       [-73.59665854165138, -3.889701720839542],
#       [-73.59665988829391, -3.8888877460698863],
#       [-73.59584947179336, -3.8888863932673474],
#       [-73.5958508189288, -3.8880724187655],
#       [-73.59504040348926, -3.8880710654667316],
#       [-73.59504175111728, -3.887257091232858],
#       [-73.59423133673879, -3.887255737438188],
#       [-73.59423268485905, -3.886441763472456],
#       [-73.59018062111974, -3.886434984222386],
#       [-73.59018197283747, -3.8856210116645133],
#       [-73.58856115089041, -3.885618295076065],
#       [-73.58856385657457, -3.8839903510533227],
#       [-73.58775344758165, -3.8839889921607744],
#       [-73.5877548007712, -3.8831750204107776],
#       [-73.58694439283992, -3.8831736610246312],
#       [-73.58694574651943, -3.882359689544258],
#       [-73.58775615367496, -3.8823610486446176],
#       [-73.58775750629295, -3.8815470768622995],
#       [-73.58856791295868, -3.881548434897977],
#       [-73.58857196677232, -3.8791065185972355],
#       [-73.58776156243228, -3.879105161418421],
#       [-73.5877629139072, -3.8782911895714984],
#       [-73.58695251062784, -3.8782898319000663],
#       [-73.58695386259173, -3.8774758603227863],
#       [-73.58614346037304, -3.8774745021590635],
#       [-73.58614481282557, -3.8766605308515913],
#       [-73.58533441166756, -3.8766591721959065],
#       [-73.5853357646084, -3.8758452011584086],
#       [-73.58452536451107, -3.8758438420110903],
#       [-73.5845240107958, -3.876657812762315],
#       [-73.58371361021048, -3.8766564525508174],
#       [-73.58371225543422, -3.877470422999465],
#       [-73.58290185436093, -3.87746906172346],
#       [-73.58290049852334, -3.8782830318693633],
#       [-73.58209009696205, -3.8782816695285236],
#       [-73.58208874006282, -3.879095639371516],
#       [-73.58127833801355, -3.879094275965516],
#       [-73.58127698005234, -3.8799082455054266],
#       [-73.58046657751508, -3.8799068810339397],
#       [-73.58046521849157, -3.8807208502706],
#       [-73.58127562180405, -3.880722215029184],
#       [-73.58127426326868, -3.8815361845367837],
#       [-73.58208466764364, -3.88153754880358],
#       [-73.58208195126292, -3.8831654883441638],
#       [-73.5812715453367, -3.883164123503501],
#       [-73.58127018594008, -3.883978092962611],
#       [-73.58045977952507, -3.883976727055639],
#       [-73.58045841906531, -3.8847906962114807],
#       [-73.57883760554513, -3.884787961484728],
#       [-73.5788362432457, -3.885601930049706],
#       [-73.57559461655282, -3.88559645009045],
#       [-73.57559598195704, -3.884782482676817],
#       [-73.56830234576168, -3.884770109756691],
#       [-73.56830097337173, -3.8855840745702146],
#       [-73.56668016695859, -3.885581315878083],
#       [-73.56667879272625, -3.8863952800958157],
#       [-73.5658683891783, -3.886393899290184],
#       [-73.56586701387938, -3.8872078632016795],
#       [-73.56343580264794, -3.887203715234619],
#       [-73.56343442472881, -3.8880176782587896],
#       [-73.55695120136772, -3.8880065803631747],
#       [-73.55695258550016, -3.8871926196692277],
#       [-73.5545213838834, -3.8871884459623494],
#       [-73.55452415593068, -3.8855605262789292],
#       [-73.55371375752935, -3.8855591340683433],
#       [-73.5537151438904, -3.884745174494844],
#       [-73.55290474655791, -3.884743781797271],
#       [-73.5529089062126, -3.8823019038576394],
#       [-73.5520985115004, -3.88230051125907],
#       [-73.5521040567082, -3.879044674951016],
#       [-73.55129366539002, -3.879043282745421],
#       [-73.55129505173437, -3.878229323920967],
#       [-73.55048466148418, -3.878227931230188],
#       [-73.55048604831006, -3.8774139726827257],
#       [-73.54967565912786, -3.877412579507089],
#       [-73.54967704643495, -3.8765986212367807],
#       [-73.54886665832072, -3.876597227576616],
#       [-73.5488680461087, -3.875783269583629],
#       [-73.54805765906247, -3.875781875439264],
#       [-73.54805627050014, -3.8765958331386052],
#       [-73.5464354957405, -3.876593041929053],
#       [-73.54643688585152, -3.875779084817495],
#       [-73.54481611381706, -3.875776291085015],
#       [-73.54481472215735, -3.876590247608135],
#       [-73.54400433580737, -3.8765888492809175],
#       [-73.5440029430787, -3.8774028054934107],
#       [-73.54319255624884, -3.877401406093727],
#       [-73.54319116245088, -3.878215361995422],
#       [-73.54238077514113, -3.878213961522946],
#       [-73.54237938027356, -3.8790279171136763],
#       [-73.54156899248392, -3.8790265155680808],
#       [-73.54156620031382, -3.880654426111095],
#       [-73.54075581126912, -3.88065302319693],
#       [-73.54075301636777, -3.8822809330849672],
#       [-73.5391322360628, -3.882278123739211],
#       [-73.53913083661791, -3.8830920780682074],
#       [-73.53507888715323, -3.8830850395920593],
#       [-73.53508029047632, -3.882271086742778],
#       [-73.53183873934182, -3.8822654431241936],
#       [-73.53184014547035, -3.8814514914454383],
#       [-73.52940898756464, -3.8814472514441456],
#       [-73.52941039572201, -3.880633300640954],
#       [-73.52778962682304, -3.880630470674773],
#       [-73.5277910362331, -3.8798165204507136],
#       [-73.52698065300551, -3.879815104597588],
#       [-73.52698488177273, -3.8773732547220083],
#       [-73.52617450116762, -3.8773718389846286],
#       [-73.52617591093505, -3.8765578892918087],
#       [-73.52536553140263, -3.8765564730746904],
#       [-73.52536694164615, -3.875742523663927],
#       [-73.52455656318642, -3.8757411069674004],
#       [-73.52455797390571, -3.874927157838857],
#       [-73.52374759651867, -3.8749257406632496],
#       [-73.5237490077134, -3.8741117918170946],
#       [-73.52293863139903, -3.874110374162735],
#       [-73.52293721943033, -3.874924322710168],
#       [-73.52131646615041, -3.8749214844715865],
#       [-73.52131505233454, -3.8757354324049107],
#       [-73.51888392233666, -3.8757311683178823],
#       [-73.5188825058987, -3.876545115336895],
#       [-73.5180721290576, -3.876543692119584],
#       [-73.51807354626986, -3.8757297454002777],
#       [-73.51564241986924, -3.8757254719817014],
#       [-73.51564383910403, -3.874911526146315],
#       [-73.51321271772889, -3.874907246630695],
#       [-73.51321413898523, -3.8740933016807038],
#       [-73.51240376656894, -3.874091873921435],
#       [-73.51240518829822, -3.873277929256118],
#       [-73.50916370473983, -3.8732722116511904],
#       [-73.50916227991536, -3.8740861551114665],
#       [-73.50754153839786, -3.874083291042767],
#       [-73.50754296476988, -3.873269348185994],
#       [-73.5067325952378, -3.8732679152877174],
#       [-73.50673116809197, -3.874081857842493],
#       [-73.50592079808825, -3.8740804238649384],
#       [-73.50591936986633, -3.8748943661013713],
#       [-73.50510899939098, -3.874892931044212],
#       [-73.50510757009263, -3.8757068729621365],
#       [-73.50267645815973, -3.875702562218054],
#       [-73.5026750262361, -3.8765165032118274],
#       [-73.49943354480413, -3.8765107434537334],
#       [-73.49943497982483, -3.875696803672869],
#       [-73.49781424247844, -3.8756939197346982],
#       [-73.49781280590923, -3.876507858908125],
#       [-73.49700243691763, -3.8765064154686866],
#       [-73.49700099927003, -3.877320354321953],
#       [-73.49619062980813, -3.8773189098006307],
#       [-73.49618919108184, -3.8781328483335686],
#       [-73.49537882114961, -3.878131402730036],
#       [-73.49537738134428, -3.878945340942479],
#       [-73.49456701094178, -3.878943894256409],
#       [-73.49456557005709, -3.879757832148186],
#       [-73.49375519918428, -3.8797563843792533],
#       [-73.49375231495075, -3.881384259504924],
#       [-73.49294194283242, -3.8813828103480135],
#       [-73.4929404994831, -3.8821967475817365],
#       [-73.4921301268943, -3.8821952973411453],
#       [-73.49212868246447, -3.8830092342536937],
#       [-73.49293905582883, -3.883010684799236],
#       [-73.49293761186962, -3.8838246220005104],
#       [-73.49374798631466, -3.8838260720717837],
#       [-73.49374654282639, -3.884640009561617],
#       [-73.49455691835209, -3.884641459158293],
#       [-73.49455403201347, -3.886269334698511],
#       [-73.49536440939609, -3.8862707841247226],
#       [-73.49536296654622, -3.88708472217494],
#       [-73.49617334500968, -3.8870861711257327],
#       [-73.49617190263191, -3.8879001094640078],
#       [-73.49698228217623, -3.8879015579390543],
#       [-73.49698084027087, -3.8887154965652226],
#       [-73.49779122089602, -3.8887169445641945],
#       [-73.49778833772683, -3.890344822375735],
#       [-73.49859872020988, -3.890346270202113],
#       [-73.49859727894653, -3.891160209387315],
#       [-73.49940766251062, -3.891161656736798],
#       [-73.49940622172083, -3.891975596209393],
#       [-73.50021660636595, -3.8919770430816523],
#       [-73.50021516605005, -3.8927909828414724],
#       [-73.5010255517762, -3.89279242923618],
#       [-73.5010226717895, -3.8944203093136758],
#       [-73.50183305937455, -3.894421755533659],
#       [-73.50183161970423, -3.895235695851165],
#       [-73.5026420083705, -3.895237141592777],
#       [-73.50264056917523, -3.896051082197008],
#       [-73.50345095892267, -3.896052527459919],
#       [-73.50344952020276, -3.896866468350708],
#       [-73.50425991103143, -3.8968679131345896],
#       [-73.5042584727872, -3.897681854311773],
#       [-73.50506886469707, -3.8976832986162964],
#       [-73.50506598885816, -3.899311181526831],
#       [-73.5058763826281, -3.899312625654011],
#       [-73.5058749450339, -3.9001265673871948],
#       [-73.50668533988521, -3.9001280110341967],
#       [-73.50668246534828, -3.9017558950560565],
#       [-73.50506167283092, -3.901753005770486],
#       [-73.50506023355014, -3.902566947152452],
#       [-73.50424983696564, -3.902565501032888],
#       [-73.50424839660265, -3.9033794420960466],
#       [-73.50343799954116, -3.903377994890801],
#       [-73.50343655809563, -3.9041919356349832],
#       [-73.50262616055716, -3.904190487343729],
#       [-73.50262471802878, -3.90500442776877],
#       [-73.50181432001332, -3.9050029783911815],
#       [-73.50181287640176, -3.9058169184969076],
#       [-73.50100247790931, -3.9058154680326576],
#       [-73.50100103321424, -3.9066294078189037],
#       [-73.50019063424482, -3.906627956267665],
#       [-73.50018774238347, -3.9082558351845385],
#       [-73.50099814291403, -3.908257287342438],
#       [-73.5009966973089, -3.9090712270797203],
#       [-73.50018629599751, -3.909069774618489],
#       [-73.50018484930806, -3.90988371403611],
#       [-73.4993744475192, -3.90988226048707],
#       [-73.49937589498964, -3.909068321372945],
#       [-73.49694469378878, -3.9090639569304573],
#       [-73.49694614329799, -3.908250018711471],
#       [-73.49532534557962, -3.908247105770076],
#       [-73.49532389450879, -3.9090610433805972],
#       [-73.49451349532546, -3.909059585429212],
#       [-73.49451204316917, -3.909873522718921],
#       [-73.49208084510492, -3.9098691432445403],
#       [-73.49208375379818, -3.908241270477622],
#       [-73.49127335661531, -3.9082398096941713],
#       [-73.49127481128485, -3.907425873591347],
#       [-73.49046441518793, -3.9074244123290596],
#       [-73.49046732517184, -3.90579654068502],
#       [-73.48965693094118, -3.9057950792496845],
#       [-73.48965838625507, -3.904981143708639],
#       [-73.4888479931102, -3.9049796817952878],
#       [-73.48885090438084, -3.903351811275483],
#       [-73.48804051310155, -3.903350349190229],
#       [-73.48804196905783, -3.9025364142116397],
#       [-73.48723157886417, -3.9025349516491907],
#       [-73.48723449141762, -3.90090708225498],
#       [-73.48642410308888, -3.9009056195217746],
#       [-73.48642555968557, -3.9000916851063208],
#       [-73.48561517244228, -3.900090221896741],
#       [-73.48561808627463, -3.8984623536294807],
#       [-73.4848077008956, -3.898460890250291],
#       [-73.48480915813077, -3.897646956398652],
#       [-73.48399877383702, -3.8976454925439072],
#       [-73.48400314603784, -3.8952036918110475],
#       [-73.48319276438585, -3.895202228094601],
#       [-73.48319713615928, -3.892760428135479],
#       [-73.48238675714774, -3.89275896455831],
#       [-73.48239258499102, -3.8895032322793637],
#       [-73.48158220939563, -3.889501769149536],
#       [-73.48158366636558, -3.888687836346226],
#       [-73.48320441630976, -3.8886907612115253],
#       [-73.48320587141909, -3.8878768277779523],
#       [-73.48482662103756, -3.8878797489091546],
#       [-73.48482807428691, -3.8870658148459794],
#       [-73.48563844877958, -3.8870672739351133],
#       [-73.48563990094597, -3.886253339549261],
#       [-73.4864502749687, -3.8862547975522674],
#       [-73.48645172605247, -3.885440862843908],
#       [-73.48726209960525, -3.885442319761112],
#       [-73.48726354960671, -3.884628384730411],
#       [-73.48807392268955, -3.8846298405621407],
#       [-73.48807682022257, -3.883001969840163],
#       [-73.48726644869132, -3.883000514620304],
#       [-73.48726789777449, -3.8821865795409045],
#       [-73.48645752732489, -3.882185123848095],
#       [-73.48645897687736, -3.881371189058567],
#       [-73.48564860750939, -3.881369732893137],
#       [-73.48565005753083, -3.8805557983936447],
#       [-73.48483968924451, -3.8805543417559227],
#       [-73.484844039795, -3.878112539079406],
#       [-73.48403367413994, -3.878111082582892],
#       [-73.48403947367915, -3.8748553466802735],
#       [-73.48484983623695, -3.874856801950446],
#       [-73.48485418034942, -3.872414998933637],
#       [-73.48566454089254, -3.872416452507147],
#       [-73.48566743388803, -3.8707885831354965],
#       [-73.48485707489158, -3.8707871301748225],
#       [-73.4848585217028, -3.8699731957711436],
#       [-73.48404816378601, -3.869971742340465],
#       [-73.48404961106361, -3.8691578082271874],
#       [-73.48323925422646, -3.8691563543268312],
#       [-73.48324070197009, -3.8683424205041224],
#       [-73.48243034621261, -3.8683409661344172],
#       [-73.48243179442194, -3.867527032602445],
#       [-73.48081108537345, -3.8675241221490677],
#       [-73.4808096356189, -3.8683380550667352],
#       [-73.4783785720341, -3.868333682644556],
#       [-73.47837711965393, -3.8691476146233637],
#       [-73.47513570276078, -3.869141772629417],
#       [-73.47513715823196, -3.8683278418831515],
#       [-73.47189574936617, -3.8683219887045026],
#       [-73.47189720761914, -3.8675080591772217],
#       [-73.46946615653333, -3.867503662072563],
#       [-73.46946761679435, -3.8666897334571946],
#       [-73.46865726782393, -3.8666882665135227],
#       [-73.46865872854752, -3.8658743381916687],
#       [-73.46784838065919, -3.8658728707821113],
#       [-73.46784984184502, -3.865058942753939],
#       [-73.46541880235685, -3.8650545368023757],
#       [-73.46542026554843, -3.8642406096885744],
#       [-73.46298923117033, -3.8642361976903765],
#       [-73.46299069636666, -3.863422271492419],
#       [-73.46218035296744, -3.8634207995868755],
#       [-73.46217888699935, -3.8642347254738354],
#       [-73.46136854313951, -3.8642332524820584],
#       [-73.46136707608842, -3.8650471780416846],
#       [-73.46055673176798, -3.865045703963347],
#       [-73.46055526363351, -3.8658596291954734],
#       [-73.45974491885248, -3.8658581540302484],
#       [-73.45974344963432, -3.866672078934707],
#       [-73.45893310439268, -3.866670602682269],
#       [-73.45893163409049, -3.86748452725889],
#       [-73.45812128838827, -3.867483049918912],
#       [-73.45811981700173, -3.8682969741675284],
#       [-73.45730947083892, -3.8682954957396833],
#       [-73.45730652558437, -3.8699233435643765],
#       [-73.45649617818809, -3.8699218637361894],
#       [-73.45649470431958, -3.8707357873120927],
#       [-73.45730505248889, -3.870737267452429],
#       [-73.45730357908128, -3.8715511913242833],
#       [-73.45811392833593, -3.871552671000069],
#       [-73.45811245538955, -3.872366595167705],
#       [-73.45892280572954, -3.872368074378611],
#       [-73.45892133324473, -3.873181998841864],
#       [-73.45973168467007, -3.8731834775875624],
#       [-73.45973021264716, -3.873997402346269],
#       [-73.46135091798, -3.8740003581293943],
#       [-73.4613523884555, -3.8731864327478593],
#       [-73.46459379976085, -3.8731923337440146],
#       [-73.46459526683087, -3.8723784071025835],
#       [-73.46540561966073, -3.87237988009851],
#       [-73.46540415336425, -3.8731938070504537],
#       [-73.46783521603678, -3.8731982223075088],
#       [-73.46783375175094, -3.874012150173808],
#       [-73.46864410736909, -3.8740136206819265],
#       [-73.4686426435471, -3.874827548841877],
#       [-73.47026335726049, -3.8748304881457005],
#       [-73.47026189467678, -3.875644416908671],
#       [-73.47107225277188, -3.875645885703884],
#       [-73.47107079065286, -3.8764598147600116],
#       [-73.47188114983152, -3.8764612830868845],
#       [-73.47187676394192, -3.878903071085592],
# ...
#       [-73.51948953414636, -4.421075121183982],
#       [-73.52030046664946, -4.421076742370921],
#       [-73.52029562101194, -4.423518551277084],
#       [-73.5211065564685, -4.423520172474911],
#       [-73.5211049415403, -4.424334109039521],
#       [-73.520294005199, -4.424332487542249],
#       [-73.52028915595882, -4.4267742962270304],
#       [-73.51947821726255, -4.4267726729428265],
#       [-73.51946364535502, -4.434098095303438],
#       [-73.5202745920258, -4.434099721284171],
#       [-73.52027297230981, -4.434913657309225],
#       [-73.5210839201677, -4.434915282699342],
#       [-73.52108230103853, -4.435729219005355],
#       [-73.52189325008354, -4.435730843804529],
#       [-73.5218916315415, -4.436544780391337],
#       [-73.52270258177363, -4.436546404599238],
#       [-73.52270096381905, -4.4373603414666745],
#       [-73.53162144588141, -4.437378152255545],
#       [-73.53161983739011, -4.4381920923840585],
#       [-73.5324307929834, -4.438193706499396],
#       [-73.53242918508187, -4.439007646906574],
#       [-73.53324014186067, -4.439009260427994],
#       [-73.53323692694018, -4.440637141780837],
#       [-73.53404788579255, -4.440638755004846],
#       [-73.53404627877408, -4.441452695950341],
#       [-73.53485723881214, -4.441454308579614],
#       [-73.53485402565975, -4.443082191008414],
#       [-73.53566498777205, -4.443083803339128],
#       [-73.53566338163863, -4.443897744822263],
#       [-73.53647434493678, -4.443899356557418],
#       [-73.53647113355643, -4.445527240060818],
#       [-73.53728209892948, -4.445528851496266],
#       [-73.53728049368306, -4.446342793516362],
#       [-73.53809146024214, -4.446344404355431],
#       [-73.53808825063777, -4.447972288932073],
#       [-73.53889921927241, -4.447973899470286],
#       [-73.53889761491497, -4.448787842026665],
#       [-73.5397085847358, -4.448789451967677],
#       [-73.53970537691136, -4.450417337616204],
#       [-73.54051634880844, -4.450418947255215],
#       [-73.54051474534192, -4.451232890347193],
#       [-73.54132571842538, -4.451234499388181],
#       [-73.54132251238474, -4.452862386107236],
#       [-73.54213348754512, -4.452863994845074],
#       [-73.54213188497151, -4.453677938471977],
#       [-73.54294286131842, -4.45367954661097],
#       [-73.54293965706555, -4.455307434399193],
#       [-73.54375063549006, -4.455309042233888],
#       [-73.54374743183699, -4.4569369305376245],
#       [-73.54293645162994, -4.456935322113174],
#       [-73.54293324501158, -4.458563209752886],
#       [-73.54212226331698, -4.4585615998436445],
#       [-73.54211905373202, -4.460189486818974],
#       [-73.5413080705494, -4.460187875424285],
#       [-73.5413048579965, -4.46181576173487],
#       [-73.54049387332536, -4.461814148854077],
#       [-73.5404890495978, -4.464255977294408],
#       [-73.53967806254484, -4.464254362631314],
#       [-73.53967484345932, -4.465882247574129],
#       [-73.53886385491657, -4.46588063142345],
#       [-73.53886063285881, -4.467508515700428],
#       [-73.53967162318838, -4.467510132442518],
#       [-73.53967001260837, -4.468324074848795],
#       [-73.54048100412797, -4.468325690989595],
#       [-73.5404793941454, -4.469139633672797],
#       [-73.54129038685502, -4.46914124921198],
#       [-73.54128877747024, -4.469955192171944],
#       [-73.5420997713699, -4.469956807109178],
#       [-73.54209816258324, -4.470770750345734],
#       [-73.54290915767292, -4.470772364680695],
#       [-73.54290754948471, -4.47158630819368],
#       [-73.54371854576442, -4.471587921926035],
#       [-73.543716938175, -4.47240186571528],
#       [-73.54452793564474, -4.472403478844701],
#       [-73.5445263286544, -4.473217422910043],
#       [-73.54533732731419, -4.473219035436199],
#       [-73.54533572092329, -4.474032979777471],
#       [-73.54614672077312, -4.474034591700034],
#       [-73.54614511498198, -4.474848536317068],
#       [-73.54695611602187, -4.474850147635711],
#       [-73.54695451083082, -4.475664092528342],
#       [-73.54776551306075, -4.4756657032427345],
#       [-73.54776390847012, -4.4764796484107965],
#       [-73.5485749118901, -4.476481258520608],
#       [-73.54857330790021, -4.477295203963936],
#       [-73.54938431251026, -4.47729681346884],
#       [-73.54938270912145, -4.478110759187265],
#       [-73.55100472101591, -4.478113976087612],
#       [-73.55100311912432, -4.478927922374388],
#       [-73.55181412640859, -4.478929529769336],
#       [-73.55181252511889, -4.479743476330716],
#       [-73.55262353359304, -4.479745083119603],
#       [-73.55262193290558, -4.480559029955417],
#       [-73.55343294256964, -4.4805606361379136],
#       [-73.55343134248473, -4.481374583248],
#       [-73.55424235333871, -4.481376188823776],
#       [-73.55424075385669, -4.482190136207969],
#       [-73.55586277823774, -4.482193345245608],
#       [-73.55586118025558, -4.483007293196173],
#       [-73.55748320760235, -4.483010499218929]],
#      [[-73.5040998123824, -4.412090915534049],
#       [-73.50410306998884, -4.410463054478933],
#       [-73.50329215500443, -4.410461419480942],
#       [-73.50329378423433, -4.409647489228654],
#       [-73.50410469833683, -4.409649123923768],
#       [-73.50410958155993, -4.407207332147871],
#       [-73.50492049332115, -4.407208965049729],
#       [-73.50492211957398, -4.406395034118262],
#       [-73.504111208694, -4.406393401519115],
#       [-73.50411283552461, -4.405579470871974],
#       [-73.50330192582919, -4.405577837691244],
#       [-73.50330680714245, -4.403136046548144],
#       [-73.50249590039297, -4.403134413392234],
#       [-73.50249915484434, -4.401506553144357],
#       [-73.50331005983313, -4.401508185694194],
#       [-73.50331493659192, -4.399066394275512],
#       [-73.5041258392445, -4.399068025033262],
#       [-73.50412908713984, -4.397440163389938],
#       [-73.50493998833683, -4.3974417926592935],
#       [-73.50494161095003, -4.396627861507396],
#       [-73.50575251157103, -4.396629489591555],
#       [-73.50575413300182, -4.395815558118773],
#       [-73.50656503304683, -4.395817185018061],
#       [-73.50656665329552, -4.395003253224559],
#       [-73.50737755276451, -4.395004878939304],
#       [-73.50737917183146, -4.394190946825254],
#       [-73.50819007072447, -4.394192571355783],
#       [-73.50819168860998, -4.39337863892135],
#       [-73.50900258692697, -4.393380262267988],
#       [-73.50900420363138, -4.392566329513342],
#       [-73.50981510137237, -4.392567951676418],
#       [-73.50981671689603, -4.3917540186017305],
#       [-73.5114385115281, -4.391757259679892],
#       [-73.51144012499316, -4.3909433259839385],
#       [-73.51306191907679, -4.390946562933728],
#       [-73.51306353048392, -4.390132628617174],
#       [-73.51387442710028, -4.390134245469132],
#       [-73.51387603732795, -4.389320310833368],
#       [-73.51468693336795, -4.389321926503396],
#       [-73.51468854241651, -4.388507991548593],
#       [-73.51631033364494, -4.3885112196445695],
#       [-73.51631194063718, -4.387697284070492],
#       [-73.51793373131453, -4.387700508042655],
#       [-73.5179321260773, -4.388514444217044],
#       [-73.5195539197122, -4.388517665266003],
#       [-73.51955071184679, -4.390145538759182],
#       [-73.52036161087032, -4.390147148561504],
#       [-73.52036000736514, -4.390961085580215],
#       [-73.51954910746362, -4.390959475478309],
#       [-73.51954750278013, -4.391773412179125],
#       [-73.51873660230075, -4.391771800896096],
#       [-73.5187349964386, -4.3925857372788455],
#       [-73.51792409538139, -4.392584124814368],
#       [-73.51792248834026, -4.393398060878885],
#       [-73.51711158670521, -4.3933964472326315],
#       [-73.51710997848478, -4.3942103829787476],
#       [-73.5162990762719, -4.39420876815039],
#       [-73.51629746687182, -4.395022703577934],
#       [-73.51548656408112, -4.395021087567146],
#       [-73.51548495350107, -4.395835022675953],
#       [-73.51467405013254, -4.395833405482407],
#       [-73.51466598831766, -4.399903079248466],
#       [-73.51547689608354, -4.399904697944878],
#       [-73.5154720580191, -4.402346502886028],
#       [-73.51466114761283, -4.402344883287889],
#       [-73.5146595334419, -4.403158817930975],
#       [-73.51303771177263, -4.403155575482073],
#       [-73.51303609553912, -4.403969509505146],
#       [-73.51222518427628, -4.403967886653892],
#       [-73.51222356686033, -4.404781820357522],
#       [-73.51141265501853, -4.404780196321051],
#       [-73.51141103641982, -4.405594129705071],
#       [-73.51060012399907, -4.405592504483056],
#       [-73.51059850421726, -4.406406437547297],
#       [-73.50978759121756, -4.40640481113941],
#       [-73.50978597025232, -4.407218743883704],
#       [-73.50897505667368, -4.407217116289619],
#       [-73.50897343452469, -4.408031048713797],
#       [-73.50816252036711, -4.408029419933186],
#       [-73.50816089703402, -4.408843352037079],
#       [-73.50734998229751, -4.4088417220696146],
#       [-73.50734835778002, -4.409655653853055],
#       [-73.50653744246456, -4.409654022698413],
#       [-73.50653581676232, -4.41046795416123],
#       [-73.50572490086796, -4.410466321819079],
#       [-73.50572327398065, -4.411280252961108],
#       [-73.50491235750735, -4.411278619431124],
#       [-73.50491072943463, -4.412092550252193],
#       [-73.5040998123824, -4.412090915534049]],
#      [[-73.50490910105859, -4.412906481054851],
#       [-73.50491072943463, -4.412092550252193],
#       [-73.50572164679018, -4.412094184084728],
#       [-73.50572001929655, -4.412908115189938],
#       [-73.50490910105859, -4.412906481054851]],
#      [[-73.50571839149976, -4.4137220462767335],
#       [-73.50572001929655, -4.412908115189938],
#       [-73.50653093783765, -4.412909748439252],
#       [-73.50652931092344, -4.413723679828436],
#       [-73.50571839149976, -4.4137220462767335]],
#      [[-73.5721695427304, -4.437457751966563],
#       [-73.57217423332631, -4.435015887499071],
#       [-73.57460713438954, -4.435020590063885],
#       [-73.57460245177943, -4.437462457130516],
#       [-73.5721695427304, -4.437457751966563]],
#      [[-73.56484406593934, -4.451280772874225],
#       [-73.56484564269897, -4.450466820992635],
#       [-73.56403466198846, -4.450465238155979],
#       [-73.56403623934693, -4.449651286546473],
#       [-73.56484721916735, -4.449652869092522],
#       [-73.5648487953445, -4.448838917173888],
#       [-73.56647075407905, -4.448842079005444],
#       [-73.56646917968175, -4.449656031504801],
#       [-73.56728016037538, -4.449657611371028],
#       [-73.56727858657727, -4.450471564141981],
#       [-73.56646760499353, -4.450469983985639],
#       [-73.56646603001444, -4.451283936447952],
#       [-73.56484406593934, -4.451280772874225]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'+935+1330',
#    u'properties': {u'count': 7838, u'label': 0},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.54410350271431, -4.272171140481834],
#       [-73.54410810662557, -4.269729295618197],
#       [-73.54167576894545, -4.26972467119115],
#       [-73.54167115734916, -4.272166513400658],
#       [-73.54410350271431, -4.272171140481834]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'+953+1071',
#    u'properties': {u'count': 9, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.54158014936007, -3.872514872749254],
#       [-73.54158154264165, -3.871700917324196],
#       [-73.54239192346373, -3.8717023162151927],
#       [-73.54239331567683, -3.8708883604790345],
#       [-73.5432036960205, -3.870889758298391],
#       [-73.54320508716549, -3.8700758022513044],
#       [-73.54401546703072, -3.8700771989993474],
#       [-73.54401685710792, -3.8692632426414977],
#       [-73.54482723649473, -3.8692646383185543],
#       [-73.54482862550445, -3.86845068165011],
#       [-73.5456390044128, -3.8684520762565056],
#       [-73.54564178000372, -3.8668241622826436],
#       [-73.54483140264058, -3.8668227682648384],
#       [-73.54483279076702, -3.866008811548016],
#       [-73.54402241447069, -3.8660074170487952],
#       [-73.5440238030749, -3.8651934606103096],
#       [-73.5432134278454, -3.8651920656300036],
#       [-73.54321481692705, -3.864378109470022],
#       [-73.54240444276435, -3.8643767140089573],
#       [-73.54240583232313, -3.8635627581276446],
#       [-73.5407850864264, -3.863559965469444],
#       [-73.54078647723371, -3.862746010162081],
#       [-73.53997610549983, -3.862744612965438],
#       [-73.53997471392084, -3.8635585679775266],
#       [-73.53916434171066, -3.8635571697103996],
#       [-73.53916294906436, -3.8643711244109378],
#       [-73.53835257637789, -3.8643697250729994],
#       [-73.53835118266399, -3.865183679461816],
#       [-73.53754080950122, -3.8651822790527404],
#       [-73.53753941471936, -3.865996233129668],
#       [-73.5367290410803, -3.865994831649127],
#       [-73.536726249084, -3.8676227391627407],
#       [-73.53753662426794, -3.8676241412351464],
#       [-73.53753383263289, -3.8692520492761],
#       [-73.53834420965829, -3.8692534511640204],
#       [-73.53834281416992, -3.870067405456062],
#       [-73.5391531922641, -3.870068806863237],
#       [-73.53915179725315, -3.8708827614347436],
#       [-73.53996217641611, -3.8708841623608436],
#       [-73.53996078188294, -3.871698117211652],
#       [-73.54077116211465, -3.871699517656348],
#       [-73.54076976805958, -3.87251347278629],
#       [-73.54158014936007, -3.872514872749254]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'+955+580',
#    u'properties': {u'count': 75, u'label': 0},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.54165576614362, -4.280305986274577],
#       [-73.54166038660976, -4.277864144599544],
#       [-73.53922802595656, -4.2778595035977185],
#       [-73.53922339779065, -4.280301342614142],
#       [-73.54165576614362, -4.280305986274577]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'+956+1081',
#    u'properties': {u'count': 9, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.5323028511535, -4.50249494139791],
#       [-73.53230448228727, -4.501681002443938],
#       [-73.53149345695779, -4.5016793651482185],
#       [-73.53149182492348, -4.502493303804981],
#       [-73.5323028511535, -4.50249494139791]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'+965+1354',
#    u'properties': {u'count': 1, u'label': 0},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.53562684683497, -3.5509909704914504],
#       [-73.53563069343225, -3.5485490929192065],
#       [-73.53320044228073, -3.5485452260562185],
#       [-73.53319658930526, -3.550987100960991],
#       [-73.53562684683497, -3.5509909704914504]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'+965+185',
#    u'properties': {u'count': 9, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.52259515371902, -4.4902661980091425],
#       [-73.52259679116115, -4.4894522623513415],
#       [-73.52178578290766, -4.489450618698862],
#       [-73.52178414456746, -4.490264554057495],
#       [-73.52259515371902, -4.4902661980091425]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'+977+1339',
#    u'properties': {u'count': 1, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.52339797595458, -4.49433752056256],
#       [-73.5234028891832, -4.4918957129168495],
#       [-73.52259187793516, -4.491894069268582],
#       [-73.52259351597702, -4.491080133648225],
#       [-73.52178250592723, -4.491078489397409],
#       [-73.52178086698699, -4.491892424718596],
#       [-73.52096985633885, -4.491890779266893],
#       [-73.52096493502174, -4.494332584220067],
#       [-73.52339797595458, -4.49433752056256]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'+978+1344',
#    u'properties': {u'count': 10, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.51967966966436, -4.324216604003997],
#       [-73.51968440805064, -4.321774789322076],
#       [-73.51644110762169, -4.321768442089736],
#       [-73.51643635886313, -4.324210253172348],
#       [-73.51967966966436, -4.324216604003997]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'+984+1135',
#    u'properties': {u'count': 12, u'label': 1},
#    u'type': u'Feature'}],
#  u'geo_column': u'geometry',
#  u'type': u'FeatureCollection'}
