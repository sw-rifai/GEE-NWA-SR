# %% [markdown]
# ## Initialize Earth Engine and credentials

# %%
import ee

# Initialize the Earth Engine object, using the authentication credentials. 
ee.Initialize()

# %% [markdown]
# ### Necessary imports

# %%
# %matplotlib inline
from __future__ import print_function # For py 2.7 compat

import datetime
import ee
import numpy as np
import os
import matplotlib.pyplot as plt
from pylab import figure
import matplotlib.dates as mdates

from IPython.html import widgets
from IPython.display import display
from IPython.utils import traitlets
from IPython.core.display import Javascript

# %% [markdown]
# ## Create a Google Maps widget

# %%
class GoogleMapsWidget(widgets.DOMWidget):
    _view_name = traitlets.Unicode('GoogleMapsView', sync=True)
    value = traitlets.Unicode(sync=True)
    description = traitlets.Unicode(sync=True)
    lat = traitlets.CFloat(0, help="Center latitude, -90 to 90", sync=True)
    lng = traitlets.CFloat(0, help="Center longitude, -180 to 180", sync=True)
    zoom = traitlets.CInt(0, help="Zoom level, 0 to ~25", sync=True)
    bounds = traitlets.List([], help="Visible bounds, [W, S, E, N]", sync=True)
    
    def __init__(self, lng=0.0, lat=0.0, zoom=2):
        self.lng = lng
        self.lat = lat
        self.zoom = zoom
        
    def addLayer(self, image, vis_params=None, name=None, visible=True):
        mapid = image.getMapId(vis_params)
        self.send({'command':'addLayer', 'mapid': mapid['mapid'], 'token': mapid['token'], 'name': name, 'visible': visible})
        
    def center(self, lng, lat, zoom=None):
        self.send({'command': 'center', 'lng': lng, 'lat': lat, 'zoom': zoom})

# %%
# %%javascript
#
# require(["widgets/js/widget"], function(WidgetManager){
#     var maps = [];
#
#     // Define the GoogleMapsView
#     var GoogleMapsView = IPython.DOMWidgetView.extend({
#
#         render: function() {
#             // Resize widget element to be 100% wide
#             this.$el.css('width', '100%');
#
#             // iframe source;  just enough to load Google Maps and let us poll whether initialization is complete
#             var src='<html style="height:100%"><head>' +
#                 '<scr'+'ipt src="http://maps.googleapis.com/maps/api/js?sensor=false"></scr'+'ipt>' +
#                 '<scr'+'ipt>google.maps.event.addDomListener(window,"load",function(){ready=true});</scr'+'ipt>' +
#                 '</head>' +
#                 '<body style="height:100%; margin:0px; padding:0px"></body></html>';
#
#             // Create the Google Maps container element.
#             this.$iframe = $('<iframe />')
#                 .css('width', '100%')
#                 .css('height', '500px')
#                 .attr('srcdoc', src)
#                 .appendTo(this.$el);
#
#             var self = this; // hold onto this for initMapWhenReady
#
#             // Wait until maps library has finished loading in iframe, then create map
#             function initMapWhenReady() {
#                 // Iframe document and window
#                 var doc = self.$iframe[0].contentDocument;
#                 var win = self.$iframe[0].contentWindow;
#                 if (!win || !win.ready) {
#                     // Maps library not yet loaded;  try again soon
#                     setTimeout(initMapWhenReady, 20);
#                     return;
#                 }
#
#                 // Maps library finished loading.  Build map now.
#                 var mapOptions = {
#                     center: new win.google.maps.LatLng(self.model.get('lat'), self.model.get('lng')),
#                     zoom: self.model.get('zoom')
#                 };
#                 var mapDiv = $('<div />')
#                     .css('width', '100%')
#                     .css('height', '100%')
#                     .appendTo($(doc.body));
#                 self.map = new win.google.maps.Map(mapDiv[0], mapOptions);
#
#
#                 // Add an event listeners for user panning, zooming, and resizing map
#                 // TODO(rsargent): Bind self across all methods, and save some plumbing here
#                 win.google.maps.event.addListener(self.map, 'bounds_changed', function () {
#                     self.handleBoundsChanged();
#                 });
#
#                 self.initializeLayersControl();
#             }
#             initMapWhenReady();
#         },
#
#         LayersControl: function(widget, controlDiv, map) {
#             var win = widget.$iframe[0].contentWindow;
#             var chicago = new win.google.maps.LatLng(41.850033, -87.6500523);
#
#             // Set CSS styles for the DIV containing the control
#             // Setting padding to 5 px will offset the control
#             // from the edge of the map.
#             controlDiv.style.padding = '5px';
#
#             // Set CSS for the control border.
#             var $controlUI = $('<div />')
#                 .css('backgroundColor', 'white')
#                 .css('borderStyle', 'solid')
#                 .css('borderWidth', '1px')
#                 .css('cursor', 'pointer')
#                 .css('textAlign', 'center')
#                 .appendTo($(controlDiv));
#
#             // Set CSS for the control interior.
#             var $controlContents = $('<div />')
#                 .css('fontFamily', 'Arial,sans-serif')
#                 .css('fontSize', '12px')
#                 .css('paddingLeft', '4px')
#                 .css('paddingRight', '4px')
#                 .css('paddingTop', '0px')
#                 .css('paddingBottom', '0px')
#                 .appendTo($controlUI);
#
#             this.$controlTable = $('<table />')
#                 .append($('<tr><td colspan=2>Layers</td></tr>'))
#                 .appendTo($controlContents);
#         },
#
#         initializeLayersControl: function() {
#             var doc = this.$iframe[0].contentDocument;
#             var win = this.$iframe[0].contentWindow;
#
#             // Create the DIV to hold the control and call the LayersControl() constructor
#             // passing in this DIV.
#
#             var layersControlDiv = document.createElement('div');
#             this.layersControl = new this.LayersControl(this, layersControlDiv, this.map);
#
#             layersControlDiv.index = 1;
#             this.map.controls[win.google.maps.ControlPosition.TOP_RIGHT].push(layersControlDiv);
#         },
#
#         // Map geometry changed (pan, zoom, resize)
#         handleBoundsChanged: function() {
#             this.model.set('lng', this.map.getCenter().lng());
#             this.model.set('lat', this.map.getCenter().lat());
#             this.model.set('zoom', this.map.getZoom());
#             var bounds = this.map.getBounds();
#             var playgroundCompatible = [bounds.getSouthWest().lng(), bounds.getSouthWest().lat(),
#                                         bounds.getNorthEast().lng(), bounds.getNorthEast().lat()];
#             this.model.set('bounds', playgroundCompatible);
#             this.touch();
#         },
#
#         // Receive custom messages from Python backend
#         on_msg: function(msg) {
#             var win = this.$iframe[0].contentWindow;
#             if (msg.command == 'addLayer') {
#                 this.addLayer(msg.mapid, msg.token, msg.name, msg.visible);
#             } else if (msg.command == 'center') {
#                 this.map.setCenter(new win.google.maps.LatLng(msg.lat, msg.lng));
#                 if (msg.zoom !== null) {
#                     this.map.setZoom(msg.zoom);
#                 }
#             }
#         },
#
#         // Add an Earth Engine layer
#         addLayer: function(mapid, token, name, visible) {
#             var win = this.$iframe[0].contentWindow;
#             var eeMapOptions = {
#                 getTileUrl: function(tile, zoom) {
#                     var url = ['https://earthengine.googleapis.com/map',
#                                mapid, zoom, tile.x, tile.y].join("/");
#                     url += '?token=' + token
#                     return url;
#                 },
#                 tileSize: new win.google.maps.Size(256, 256),
#                 opacity: visible ? 1.0 : 0.0,
#             };
#
#             // Create the overlay map type
#             var mapType = new win.google.maps.ImageMapType(eeMapOptions);
#
#             // Overlay the Earth Engine generated layer
#             this.map.overlayMapTypes.push(mapType);
#
#             // Update layer visibility control
#             var maxSlider = 100;
#
#             function updateOpacity() {
#                 mapType.setOpacity($checkbox[0].checked ? $slider[0].value / 100.0 : 0);
#             }
#
#             var $checkbox = $('<input type="checkbox">')
#                 .prop('checked', visible)
#                 .change(updateOpacity);
#
#             var $slider = $('<input type="range" />')
#                 .prop('min', 0)
#                 .prop('max', maxSlider)
#                 .prop('value', maxSlider)
#                 .css('width', '60px')
#                 .on('input', updateOpacity);
#
#             // If user doesn't specify a layer name, create a default
#             if (name === null) {
#                 name = 'Layer ' + this.map.overlayMapTypes.length;
#             }
#
#             var $row = $('<tr />');
#             $('<td align="left" />').append($checkbox).append(name).appendTo($row);
#             $('<td />').append($slider).appendTo($row);
#
#             this.layersControl.$controlTable.append($row);
#         }
#     });
#
#     // Register the GoogleMapsView with the widget manager.
#     WidgetManager.register_widget_view('GoogleMapsView', GoogleMapsView);
# });

# %% [markdown]
# ## Filter the Landsat 5 Collection

# %%
import datetime
collection = 'LT5_L1T_SR' 
inYear = 2009
startDate = datetime.datetime(inYear, 7, 1); 
endDate = datetime.datetime(inYear,12,31);
path = 6
row = 63 
CC = 1
collectionSpec = ee.ImageCollection(collection)
collectionSpec = (collectionSpec
    .filterDate(startDate, endDate)
    .filterMetadata('default:WRS_PATH', 'EQUALS', path)
    .filterMetadata('default:WRS_ROW', 'EQUALS', row)
    .filterMetadata('CLOUD_COVER','less_than',CC)) 

imageBest = ee.Image(collectionSpec.sort('CLOUD_COVER').first())
imageWorst = ee.Image(collectionSpec.sort('CLOUD_COVER',False).first())

# %%
map = GoogleMapsWidget(lat=-3.75, lng=-73.5, zoom=9)
display(map) 

visParamsSR =  {'min': '0, 0, 0', 'max': '3000, 4000, 1000', 'bands': 'B5,B4,B3'};#Add layers 
map.addLayer(image=collectionSpec, vis_params=visParamsSR, name="CollectionSpec")
map.addLayer(image=imageBest, vis_params=visParamsSR, name="Best")
map.addLayer(image=imageWorst, vis_params=visParamsSR, name="Worst")

# %% [markdown]
# ## Inspect the metadata of the filtered collection

# %%
import datetime
collection = 'LT5_L1T_SR' 
inYear = 2009
startDate = datetime.datetime(inYear, 7, 1); 
endDate = datetime.datetime(inYear,12,31);
path = 6
row = 63 
CC = 1
collectionSpec = ee.ImageCollection(collection)
collectionSpec = (collectionSpec
    .filterDate(startDate, endDate)
    .filterMetadata('default:WRS_PATH', 'EQUALS', path)
    .filterMetadata('default:WRS_ROW', 'EQUALS', row)
    .filterMetadata('CLOUD_COVER','less_than',CC)) 

imageFirst = ee.Image(collectionSpec.sort('system:time_start').first())
imageLast = ee.Image(collectionSpec.sort('system:time_start',False).first())

map = GoogleMapsWidget(lat=-3.75, lng=-73.5, zoom=9)
display(map) 

visParamsSR =  {'min': '0, 0, 0', 'max': '3000, 4000, 1000', 'bands': 'B5,B4,B3'};#Add layers 
map.addLayer(image=imageFirst, vis_params=visParamsSR, name="First")
map.addLayer(image=imageLast, vis_params=visParamsSR, name="Last")

# %%
##image_object = ee.ImageCollection(collection)
##[method for method in dir(image_object) if not method.startswith('_')]

# %%
imageLast.getInfo()

# %% [markdown]
# ## testing the cloud and shadow thresholds

# %%
"""shadowMask = imageLast.expression(
  "b('B1')<200& b('B2')<400& b('B3')<300& b('B4')<2000& b('B5')<700& b('B7')<300"
  ).eq(0);
shadowBuffer = shadowMask.reduceNeighborhood(ee.call('Reducer.allNonZero'),ee.call('Kernel.circle',0.5)).focal_min(5);
cloudMask = imageLast.expression(
  "b('B1')>380& b('B2')>499 &b('B3')>375 & b('B4')>2850& b('B5')>1200& b('B7')>500"
  ).eq(0);
cloudBuffer = cloudMask.reduceNeighborhood(ee.call('Reducer.allNonZero'),ee.call('Kernel.circle',0.5)).focal_min(5);
combinedMask = shadowBuffer.And(cloudBuffer).neq(0);  
imageLast = imageLast.mask(combinedMask)"""

# %% [markdown]
# ## Define the Cloud & Shadow mask function

# %%
def applyCSmask(image): 
    shadowMask = image.expression("b('B1')<200& b('B2')<400& b('B3')<300& b('B4')<2000& b('B5')<700& b('B7')<300").eq(0);
    shadowBuffer = shadowMask.reduceNeighborhood(ee.call('Reducer.allNonZero'),ee.call('Kernel.circle',0.5)).focal_min(5);
    cloudMask = image.expression("b('B1')>380& b('B2')>499 &b('B3')>375 & b('B4')>2850& b('B5')>1200& b('B7')>500").eq(0);
    cloudBuffer = cloudMask.reduceNeighborhood(ee.call('Reducer.allNonZero'),ee.call('Kernel.circle',0.5)).focal_min(5);
    combinedMask = shadowBuffer.And(cloudBuffer).neq(0);  
    image = image.mask(combinedMask)
    return image

# %% [markdown]
# ## Define a Smoothed Version of the Hansen No-data mask [TESTING]

# %%
def applyHansenMask(image):
    hansenDataMask = ee.Image('UMD/hansen/global_forest_change_2013').select('datamask');
    hansenMaskSmooth = hansenDataMask.reduceNeighborhood('max',ee.call('Kernel.euclidean',3)).focal_max(iterations=1).focal_min(iterations=3).focal_max().eq(1);

    forestMask = ee.Image("MCD12Q1/MCD12Q1_005_2009_01_01").select('Land_Cover_Type_1').eq(2).focal_min(radius=3, iterations=2);
          
    ##necessary to combine masks, otherwise applying one mask will disregard previously applied masks
    combinedMask = image.mask().And(hansenMaskSmooth).And(forestMask);  
    image = image.mask(combinedMask);

    return image;

# %% [markdown]
# ## Define the Soil Mask - testing

# %%
def applySoilMask(image):
    imageMasked = image.And(image.mask(image.select('B7').gte(1550).focal_min(5))); #remove soil dominated pixels
    soil = image.expression("b('B7')>1550").eq(0).focal_min(5);
    combinedMask = image.mask().And(soil);
    image = image.mask(combinedMask);
    return image;

# %% [markdown]
# ## Define the Anomalous Pixel Mask - testing

# %%
def applyAnomPixelMask(image):
    imageMasked = image.mask().And(image.mask(image.select(['B5']).lte(4000).focal_min(20)));
    anoms = image.expression(" b('B5')>3000").eq(0);
    combinedMask = image.mask().And(anoms);
    image = image.mask(combinedMask);
    return image;

# %% [markdown]
# ## Define the Apply Water Mask - testing

# %%
def applyWaterMask(image):
    water = image.expression(" b('B4')<1750").eq(0).focal_min(3);
    combinedMask = image.mask().And(water);
    image = image.mask(combinedMask);
    return image;

# %%
masked = applyCSmask(imageLast);
masked = applyHansenMask(masked);
masked = applySoilMask(masked); 
masked = applyAnomPixelMask(masked);
masked = applyWaterMask(masked);

# %%
map = GoogleMapsWidget(lat=-3.75, lng=-73.5, zoom=9)
display(map) 
#imageFirst = csMask(imageFirst);
#imageLast = csMask(imageLast);
visParamsSR =  {'min': '0, 0, 0', 'max': '3000, 4000, 1000', 'bands': 'B5,B4,B3'};#Add layers 
map.addLayer(image=imageLast, vis_params=visParamsSR, name="Last", visible=False)
map.addLayer(image=imageFirst, vis_params=visParamsSR, name="First", visible=False)
map.addLayer(image=masked, vis_params=visParamsSR, name="masked", visible=True)

# %% [markdown]
# ## Apply the anthro mask

# %%
# anthroPoly = ee.FeatureCollection('ft:1rJT6SWmCN6hNJxhroEVYdbXv3NWX9nJk0stZR1Zh'); #old 
anthroPoly = ee.FeatureCollection('ft:1hi1BbXYlFceof3MbQEZwnSTLThADQbSGw68dCmJa'); #old 

#Start with a black image.
image1 = ee.Image(1).toByte();
#Fill and outline the polygons in two colors
image2 = image1.paint(anthroPoly, 0);
combinedMask = masked.mask().And(image2)
total = masked.mask(combinedMask);
##total = masked.And(masked.mask(image2.neq(2)));

map = GoogleMapsWidget(lat=-3.75, lng=-73.5, zoom=9)
display(map) 
map.addLayer(image=anthroPoly, name="anthro mask")
visParamsSR =  {'min': '0, 0, 0', 'max': '3000, 4000, 1000', 'bands': 'B5,B4,B3'};#Add layers 
map.addLayer(image=masked, vis_params=visParamsSR, name="TM", visible=False)
map.addLayer(image=total,  vis_params=visParamsSR, name="TM w/anthroMask")

# %% [markdown]
# ## Apply the SMA

# %%
##******* SMA ******************
toUnmix = total.select(['B1','B2','B3','B4','B5','B7']);
#Define Endmembers 
bdEM = [514, 803, 772, 2309, 2481, 1433]; 
soilEM = [484, 661, 775, 1720, 2664, 1880];
forestEM = [200, 445, 254, 3213, 1404, 464]; 
forestSecEM = [237, 481, 283, 4938, 1918, 637];
shadowEM = [296, 402, 307, 466, 68, 49];  
waterEM = [687, 1198, 1520, 1501, 68, 83]; 
forestHazeEM = [424, 648, 498, 3131, 1417, 606];
wetlandSoilEM = [293, 608, 470, 2611, 1783, 743];

## Apply SMA 
unmixBD = toUnmix.unmix([bdEM, forestEM, soilEM, forestHazeEM]);
unmixForest = toUnmix.unmix([bdEM, forestEM, forestSecEM]);
unmixSoils = toUnmix.unmix([bdEM, wetlandSoilEM, soilEM]);
unmixHaze = toUnmix.unmix([forestHazeEM,forestEM,forestSecEM]);

# %% [markdown]
# ## Decision tree of SMA's

# %%
bdReal = unmixBD.select(['band_0']).gte(0.2).And(unmixHaze.select(['band_0']).lte(0.05)).And(unmixBD.select(['band_2']).lte(0.8)).And(unmixForest.select(['band_0']).gte(0.2)); 
bdRealSmooth = bdReal.focal_max(2).focal_mode(2).eq(1);
blank = ee.Image(0); 
blank = blank.And(bdRealSmooth.eq(1)); 

output = ee.Image(0).where(bdRealSmooth.eq(1),1)

# %%
map = GoogleMapsWidget(lat=-3.75, lng=-73.5, zoom=9)
display(map) 
visParamsSMA =  {'bands': 'band_0,band_1,band_2'};#Add layers 
map.addLayer(image=unmixBD, vis_params=visParamsSMA, name="SMA-BD", visible=False)
map.addLayer(image=bdRealSmooth, name="BD-on/off", visible=True)
map.addLayer(image=total, vis_params=visParamsSR, name="SR masked", visible=True)
map.addLayer(image=output, name='Output');

# %% [markdown]
# ## Converting the Blowdown layer to vectors

# %%
#defining a region to limit the number of polygons returned; otherwise errors occur
region = ee.Geometry.Rectangle(-74.0698, -3.4284, -72.6251, -4.5025);

#Arguments(image, reducer, geometry, scale, geometryType, eightConnected, labelProperty, crs, 
#       crsTransform, bestEffort, maxPixels, tileScale, geometryInNativeProjection);
bdLab = ee.Image.reduceToVectors(output, geometry=region, maxPixels=30000000, eightConnected=True, scale=90)

# %%
map = GoogleMapsWidget(lat=-3.75, lng=-73.5, zoom=9)
display(map) 
map.addLayer(image=bdRealSmooth, name="BD-on/off")
map.addLayer(image=total, vis_params=visParamsSR, name="SR masked")
map.addLayer(bdLab, name="BD-redToVec")

# %%
##image_object = ee.Image(bdRealSmooth)
##[method for method in dir(image_object) if not method.startswith('_')]

# %%
bdLab.getInfo()
# Out:
# {u'columns': {u'count': u'Long',
#   u'geometry': u'Geometry',
#   u'label': u'Byte',
#   u'system:index': u'String'},
#  u'features': [{u'geometry': {u'coordinates': [[[-72.62528729145525,
#        -4.502446035535454],
#       [-73.6981452352792, -4.502446035535454],
#       [-73.6981452352792, -4.501637551779746],
#       [-73.6989537190349, -4.501637551779746],
#       [-73.6989537190349, -4.500829068024038],
#       [-73.70137917030202, -4.500829068024038],
#       [-73.70137917030202, -4.502446035535454],
#       [-73.70542158908056, -4.502446035535454],
#       [-73.70542158908056, -4.500829068024038],
#       [-73.70784704034769, -4.500829068024038],
#       [-73.70784704034769, -4.502446035535454],
#       [-74.07004776290468, -4.502446035535454],
#       [-74.07004776290468, -3.4287796079558017],
#       [-72.62528729145525, -3.4287796079558017],
#       [-72.62528729145525, -4.502446035535454]],
#      [[-73.06671942207159, -3.6680907996452423],
#       [-73.0691448733387, -3.6680907996452423],
#       [-73.0691448733387, -3.6705162509123648],
#       [-73.06671942207159, -3.6705162509123648],
#       [-73.06671942207159, -3.6680907996452423]],
#      [[-73.00204072161497, -3.658388994576751],
#       [-73.00527465663781, -3.658388994576751],
#       [-73.00527465663781, -3.660814445843874],
#       [-73.0044661728821, -3.660814445843874],
#       [-73.0044661728821, -3.6616229295995817],
#       [-73.00204072161497, -3.6616229295995817],
#       [-73.00204072161497, -3.658388994576751]],
#      [[-73.1103775448798, -3.595327261631561],
#       [-73.11361147990262, -3.595327261631561],
#       [-73.11361147990262, -3.5977527128986835],
#       [-73.11441996365832, -3.5977527128986835],
#       [-73.11441996365832, -3.598561196654391],
#       [-73.1119945123912, -3.598561196654391],
#       [-73.1119945123912, -3.5977527128986835],
#       [-73.1103775448798, -3.5977527128986835],
#       [-73.1103775448798, -3.595327261631561]],
#      [[-73.05054974695743, -3.595327261631561],
#       [-73.05297519822456, -3.595327261631561],
#       [-73.05297519822456, -3.5977527128986835],
#       [-73.05054974695743, -3.5977527128986835],
#       [-73.05054974695743, -3.595327261631561]],
#      [[-73.0481242956903, -3.5912848428530233],
#       [-73.05054974695743, -3.5912848428530233],
#       [-73.05054974695743, -3.5937102941201458],
#       [-73.0481242956903, -3.5937102941201458],
#       [-73.0481242956903, -3.5912848428530233]],
#      [[-73.04165642564465, -3.5904763590973157],
#       [-73.04489036066748, -3.5904763590973157],
#       [-73.04489036066748, -3.592901810364438],
#       [-73.04327339315606, -3.592901810364438],
#       [-73.04327339315606, -3.5937102941201458],
#       [-73.04003945813324, -3.5937102941201458],
#       [-73.04003945813324, -3.5912848428530233],
#       [-73.04165642564465, -3.5912848428530233],
#       [-73.04165642564465, -3.5904763590973157]],
#      [[-73.01416797795059, -3.567030330181796],
#       [-73.0165934292177, -3.567030330181796],
#       [-73.0165934292177, -3.5718812327160414],
#       [-73.01416797795059, -3.5718812327160414],
#       [-73.01416797795059, -3.567030330181796]],
#      [[-73.72725065048466, -3.664048380866704],
#       [-73.72967610175179, -3.664048380866704],
#       [-73.72967610175179, -3.666473832133827],
#       [-73.72725065048466, -3.666473832133827],
#       [-73.72725065048466, -3.664048380866704]],
#      [[-73.38202808679753, -3.6567720270653363],
#       [-73.38445353806466, -3.6567720270653363],
#       [-73.38445353806466, -3.659197478332459],
#       [-73.38202808679753, -3.659197478332459],
#       [-73.38202808679753, -3.6567720270653363]],
#      [[-73.92856310565585, -3.647878705752553],
#       [-73.93098855692297, -3.647878705752553],
#       [-73.93098855692297, -3.6503041570196757],
#       [-73.92856310565585, -3.6503041570196757],
#       [-73.92856310565585, -3.647878705752553]],
#      [[-73.4208353070715, -3.632517514394109],
#       [-73.42326075833861, -3.632517514394109],
#       [-73.42326075833861, -3.634942965661232],
#       [-73.4208353070715, -3.634942965661232],
#       [-73.4208353070715, -3.632517514394109]],
#      [[-73.49036491006235, -3.629283579371279],
#       [-73.49279036132947, -3.629283579371279],
#       [-73.49279036132947, -3.6317090306384014],
#       [-73.49036491006235, -3.6317090306384014],
#       [-73.49036491006235, -3.629283579371279]],
#      [[-73.39011292435461, -3.619581774302788],
#       [-73.39253837562173, -3.619581774302788],
#       [-73.39253837562173, -3.6220072255699107],
#       [-73.39011292435461, -3.6220072255699107],
#       [-73.39011292435461, -3.619581774302788]],
#      [[-73.37717718426329, -3.6074545179671746],
#       [-73.3796026355304, -3.6074545179671746],
#       [-73.3796026355304, -3.609879969234297],
#       [-73.37717718426329, -3.609879969234297],
#       [-73.37717718426329, -3.6074545179671746]],
#      [[-73.42487772585004, -3.6058375504557594],
#       [-73.42730317711715, -3.6058375504557594],
#       [-73.42730317711715, -3.6082630017228823],
#       [-73.42487772585004, -3.6082630017228823],
#       [-73.42487772585004, -3.6058375504557594]],
#      [[-73.39172989186602, -3.5678388139375037],
#       [-73.39415534313315, -3.5678388139375037],
#       [-73.39415534313315, -3.570264265204626],
#       [-73.39172989186602, -3.570264265204626],
#       [-73.39172989186602, -3.5678388139375037]],
#      [[-73.53321454911485, -3.548435203800522],
#       [-73.53564000038197, -3.548435203800522],
#       [-73.53564000038197, -3.5508606550676447],
#       [-73.53321454911485, -3.5508606550676447],
#       [-73.53321454911485, -3.548435203800522]],
#      [[-73.76605787075863, -3.533074012442078],
#       [-73.76848332202574, -3.533074012442078],
#       [-73.76848332202574, -3.535499463709201],
#       [-73.76605787075863, -3.535499463709201],
#       [-73.76605787075863, -3.533074012442078]],
#      [[-73.40789956698018, -3.533074012442078],
#       [-73.40870805073588, -3.533074012442078],
#       [-73.40870805073588, -3.5338824961977857],
#       [-73.41113350200301, -3.5338824961977857],
#       [-73.41113350200301, -3.537116431220616],
#       [-73.40870805073588, -3.537116431220616],
#       [-73.40870805073588, -3.535499463709201],
#       [-73.40789956698018, -3.535499463709201],
#       [-73.40789956698018, -3.533074012442078]],
#      [[-73.34402935027927, -3.5282231099078327],
#       [-73.34483783403499, -3.5282231099078327],
#       [-73.34483783403499, -3.5290315936635404],
#       [-73.34402935027927, -3.5290315936635404],
#       [-73.34402935027927, -3.5282231099078327]],
#      [[-73.4216437908272, -3.52579765864071],
#       [-73.42406924209433, -3.52579765864071],
#       [-73.42406924209433, -3.5282231099078327],
#       [-73.4216437908272, -3.5282231099078327],
#       [-73.4216437908272, -3.52579765864071]],
#      [[-73.25671310466286, -3.52579765864071],
#       [-73.25913855592998, -3.52579765864071],
#       [-73.25913855592998, -3.5282231099078327],
#       [-73.25671310466286, -3.5282231099078327],
#       [-73.25671310466286, -3.52579765864071]],
#      [[-73.34322086652357, -3.524180691129295],
#       [-73.3456463177907, -3.524180691129295],
#       [-73.3456463177907, -3.5266061423964175],
#       [-73.3464548015464, -3.5266061423964175],
#       [-73.3464548015464, -3.527414626152125],
#       [-73.3456463177907, -3.527414626152125],
#       [-73.3456463177907, -3.5282231099078327],
#       [-73.34483783403499, -3.5282231099078327],
#       [-73.34483783403499, -3.527414626152125],
#       [-73.34402935027927, -3.527414626152125],
#       [-73.34402935027927, -3.5266061423964175],
#       [-73.34322086652357, -3.5266061423964175],
#       [-73.34322086652357, -3.524180691129295]],
#      [[-73.77414270831571, -3.4966922434352377],
#       [-73.77656815958282, -3.4966922434352377],
#       [-73.77656815958282, -3.49911769470236],
#       [-73.77414270831571, -3.49911769470236],
#       [-73.77414270831571, -3.4966922434352377]],
#      [[-73.77414270831571, -3.4805225683210863],
#       [-73.77656815958282, -3.4805225683210863],
#       [-73.77656815958282, -3.4829480195882088],
#       [-73.77414270831571, -3.4829480195882088],
#       [-73.77414270831571, -3.4805225683210863]],
#      [[-73.75959000071296, -3.4772886332982558],
#       [-73.76201545198009, -3.4772886332982558],
#       [-73.76201545198009, -3.4797140845653787],
#       [-73.75959000071296, -3.4797140845653787],
#       [-73.75959000071296, -3.4772886332982558]],
#      [[-72.85166274305337, -4.449086107658754],
#       [-72.8540881943205, -4.449086107658754],
#       [-72.8540881943205, -4.451511558925877],
#       [-72.85166274305337, -4.451511558925877],
#       [-72.85166274305337, -4.449086107658754]],
#      [[-72.72149685838446, -4.346408670683893],
#       [-72.72392230965157, -4.346408670683893],
#       [-72.72392230965157, -4.348834121951016],
#       [-72.72149685838446, -4.348834121951016],
#       [-72.72149685838446, -4.346408670683893]],
#      [[-72.89370389835017, -4.052120583606338],
#       [-72.89612934961728, -4.052120583606338],
#       [-72.89612934961728, -4.0553545186291675],
#       [-72.89532086586158, -4.0553545186291675],
#       [-72.89532086586158, -4.056971486140583],
#       [-72.89451238210587, -4.056971486140583],
#       [-72.89451238210587, -4.062630872430536],
#       [-72.89370389835017, -4.062630872430536],
#       [-72.89370389835017, -4.065056323697659],
#       [-72.89612934961728, -4.065056323697659],
#       [-72.89612934961728, -4.0642478399419515],
#       [-72.89936328464012, -4.0642478399419515],
#       [-72.89936328464012, -4.065056323697659],
#       [-72.90017176839582, -4.065056323697659],
#       [-72.90017176839582, -4.069098742476196],
#       [-72.89936328464012, -4.069098742476196],
#       [-72.89936328464012, -4.071524193743319],
#       [-72.89855480088441, -4.071524193743319],
#       [-72.89855480088441, -4.073141161254735],
#       [-72.89289541459445, -4.073141161254735],
#       [-72.89289541459445, -4.069907226231904],
#       [-72.89370389835017, -4.069907226231904],
#       [-72.89370389835017, -4.069098742476196],
#       [-72.89451238210587, -4.069098742476196],
#       [-72.89451238210587, -4.0666732912090735],
#       [-72.89127844708304, -4.0666732912090735],
#       [-72.89127844708304, -4.067481774964781],
#       [-72.89046996332733, -4.067481774964781],
#       [-72.89046996332733, -4.070715709987612],
#       [-72.8880445120602, -4.070715709987612],
#       [-72.8880445120602, -4.068290258720489],
#       [-72.88885299581591, -4.068290258720489],
#       [-72.88885299581591, -4.0666732912090735],
#       [-72.8880445120602, -4.0666732912090735],
#       [-72.8880445120602, -4.065056323697659],
#       [-72.8872360283045, -4.065056323697659],
#       [-72.8872360283045, -4.061822388674829],
#       [-72.88966147957163, -4.061822388674829],
#       [-72.88966147957163, -4.061013904919121],
#       [-72.89046996332733, -4.061013904919121],
#       [-72.89046996332733, -4.058588453651998],
#       [-72.89127844708304, -4.058588453651998],
#       [-72.89127844708304, -4.05777996989629],
#       [-72.89208693083874, -4.05777996989629],
#       [-72.89208693083874, -4.056163002384875],
#       [-72.89289541459445, -4.056163002384875],
#       [-72.89289541459445, -4.0529290673620455],
#       [-72.89370389835017, -4.0529290673620455],
#       [-72.89370389835017, -4.052120583606338]],
#      [[-72.88400209328167, -4.052120583606338],
#       [-72.88481057703738, -4.052120583606338],
#       [-72.88481057703738, -4.0529290673620455],
#       [-72.88400209328167, -4.0529290673620455],
#       [-72.88400209328167, -4.052120583606338]],
#      [[-72.8880445120602, -4.047269681072092],
#       [-72.89046996332733, -4.047269681072092],
#       [-72.89046996332733, -4.050503616094923],
#       [-72.88966147957163, -4.050503616094923],
#       [-72.88966147957163, -4.05131209985063],
#       [-72.88885299581591, -4.05131209985063],
#       [-72.88885299581591, -4.052120583606338],
#       [-72.8880445120602, -4.052120583606338],
#       [-72.8880445120602, -4.0529290673620455],
#       [-72.88561906079309, -4.0529290673620455],
#       [-72.88561906079309, -4.052120583606338],
#       [-72.88481057703738, -4.052120583606338],
#       [-72.88481057703738, -4.05131209985063],
#       [-72.88561906079309, -4.05131209985063],
#       [-72.88561906079309, -4.050503616094923],
#       [-72.8864275445488, -4.050503616094923],
#       [-72.8864275445488, -4.049695132339215],
#       [-72.8872360283045, -4.049695132339215],
#       [-72.8872360283045, -4.048886648583507],
#       [-72.8880445120602, -4.048886648583507],
#       [-72.8880445120602, -4.047269681072092]],
#      [[-73.23569252701446, -3.967229789257043],
#       [-73.23811797828158, -3.967229789257043],
#       [-73.23811797828158, -3.9696552405241654],
#       [-73.23569252701446, -3.9696552405241654],
#       [-73.23569252701446, -3.967229789257043]],
#      [[-73.05459216573597, -3.9494431466314763],
#       [-73.05701761700308, -3.9494431466314763],
#       [-73.05701761700308, -3.9526770816543064],
#       [-73.05459216573597, -3.9526770816543064],
#       [-73.05459216573597, -3.9494431466314763]],
#      [[-72.85651364558761, -3.9413583090744004],
#       [-72.86055606436615, -3.9413583090744004],
#       [-72.86055606436615, -3.9437837603415233],
#       [-72.85813061309902, -3.9437837603415233],
#       [-72.85813061309902, -3.9429752765858157],
#       [-72.85732212934332, -3.9429752765858157],
#       [-72.85732212934332, -3.9437837603415233],
#       [-72.85651364558761, -3.9437837603415233],
#       [-72.85651364558761, -3.9429752765858157],
#       [-72.8557051618319, -3.9429752765858157],
#       [-72.8557051618319, -3.942166792830108],
#       [-72.85651364558761, -3.942166792830108],
#       [-72.85651364558761, -3.9413583090744004]],
#      [[-73.05459216573597, -3.8952747349990693],
#       [-73.0578261007588, -3.8952747349990693],
#       [-73.0578261007588, -3.8985086700218994],
#       [-73.05540064949167, -3.8985086700218994],
#       [-73.05540064949167, -3.8977001862661917],
#       [-73.05459216573597, -3.8977001862661917],
#       [-73.05459216573597, -3.8952747349990693]],
#      [[-72.96889288763097, -3.862126901015059],
#       [-72.97131833889809, -3.862126901015059],
#       [-72.97131833889809, -3.8645523522821814],
#       [-72.96889288763097, -3.8645523522821814],
#       [-72.96889288763097, -3.862126901015059]],
#      [[-73.13382357379531, -3.8039160706041137],
#       [-73.13624902506243, -3.8039160706041137],
#       [-73.13624902506243, -3.8063415218712366],
#       [-73.13382357379531, -3.8063415218712366],
#       [-73.13382357379531, -3.8039160706041137]],
#      [[-73.13139812252818, -3.796639716802746],
#       [-73.13382357379531, -3.796639716802746],
#       [-73.13382357379531, -3.7990651680698684],
#       [-73.13139812252818, -3.7990651680698684],
#       [-73.13139812252818, -3.796639716802746]],
#      [[-73.11280299614691, -3.7562155290173673],
#       [-73.11522844741404, -3.7562155290173673],
#       [-73.11522844741404, -3.760257947795905],
#       [-73.11280299614691, -3.760257947795905],
#       [-73.11280299614691, -3.7610664315516127],
#       [-73.1119945123912, -3.7610664315516127],
#       [-73.1119945123912, -3.7618749153073203],
#       [-73.10956906112408, -3.7618749153073203],
#       [-73.10956906112408, -3.762683399063028],
#       [-73.10876057736837, -3.762683399063028],
#       [-73.10876057736837, -3.7634918828187356],
#       [-73.10633512610126, -3.7634918828187356],
#       [-73.10633512610126, -3.7610664315516127],
#       [-73.10714360985696, -3.7610664315516127],
#       [-73.10714360985696, -3.760257947795905],
#       [-73.10795209361267, -3.760257947795905],
#       [-73.10795209361267, -3.7594494640401974],
#       [-73.10876057736837, -3.7594494640401974],
#       [-73.10876057736837, -3.75864098028449],
#       [-73.1111860286355, -3.75864098028449],
#       [-73.1111860286355, -3.7578324965287826],
#       [-73.1119945123912, -3.7578324965287826],
#       [-73.1119945123912, -3.757024012773075],
#       [-73.11280299614691, -3.757024012773075],
#       [-73.11280299614691, -3.7562155290173673]],
#      [[-72.92200082979993, -3.754598561505952],
#       [-72.92442628106704, -3.754598561505952],
#       [-72.92442628106704, -3.7578324965287826],
#       [-72.92200082979993, -3.7578324965287826],
#       [-72.92200082979993, -3.754598561505952]],
#      [[-73.1435253788638, -3.7521731102388296],
#       [-73.1443338626195, -3.7521731102388296],
#       [-73.1443338626195, -3.752981593994537],
#       [-73.1435253788638, -3.752981593994537],
#       [-73.1435253788638, -3.7521731102388296]],
#      [[-73.13948296008526, -3.751364626483122],
#       [-73.14190841135239, -3.751364626483122],
#       [-73.14190841135239, -3.7521731102388296],
#       [-73.1427168951081, -3.7521731102388296],
#       [-73.1427168951081, -3.752981593994537],
#       [-73.14190841135239, -3.752981593994537],
#       [-73.14190841135239, -3.7537900777502444],
#       [-73.13948296008526, -3.7537900777502444],
#       [-73.13948296008526, -3.751364626483122]],
#      [[-72.94706382622687, -3.7368119188803854],
#       [-72.94948927749398, -3.7368119188803854],
#       [-72.94948927749398, -3.737620402636093],
#       [-72.95029776124969, -3.737620402636093],
#       [-72.95029776124969, -3.740045853903216],
#       [-72.94948927749398, -3.740045853903216],
#       [-72.94948927749398, -3.7408543376589236],
#       [-72.94706382622687, -3.7408543376589236],
#       [-72.94706382622687, -3.740045853903216],
#       [-72.94625534247115, -3.740045853903216],
#       [-72.94625534247115, -3.737620402636093],
#       [-72.94706382622687, -3.737620402636093],
#       [-72.94706382622687, -3.7368119188803854]],
#      [[-73.09744180478847, -3.7141743737205735],
#       [-73.09986725605559, -3.7141743737205735],
#       [-73.09986725605559, -3.7165998249876964],
#       [-73.09744180478847, -3.7165998249876964],
#       [-73.09744180478847, -3.7141743737205735]],
#      [[-72.99557285156932, -3.7052810524077904],
#       [-72.99880678659214, -3.7052810524077904],
#       [-72.99880678659214, -3.7077065036749133],
#       [-72.99557285156932, -3.7077065036749133],
#       [-72.99557285156932, -3.7052810524077904]],
#      [[-72.9834455952337, -3.694770763583592],
#       [-72.98587104650082, -3.694770763583592],
#       [-72.98587104650082, -3.6971962148507145],
#       [-72.9834455952337, -3.6971962148507145],
#       [-72.9834455952337, -3.694770763583592]],
#      [[-73.06106003578162, -3.6842604747593937],
#       [-73.06186851953734, -3.6842604747593937],
#       [-73.06186851953734, -3.6850689585151013],
#       [-73.06267700329305, -3.6850689585151013],
#       [-73.06267700329305, -3.685877442270809],
#       [-73.06348548704875, -3.685877442270809],
#       [-73.06348548704875, -3.6874944097822238],
#       [-73.06267700329305, -3.6874944097822238],
#       [-73.06267700329305, -3.6883028935379314],
#       [-73.06186851953734, -3.6883028935379314],
#       [-73.06186851953734, -3.689111377293639],
#       [-73.05944306827021, -3.689111377293639],
#       [-73.05944306827021, -3.685877442270809],
#       [-73.06025155202592, -3.685877442270809],
#       [-73.06025155202592, -3.6850689585151013],
#       [-73.06106003578162, -3.6850689585151013],
#       [-73.06106003578162, -3.6842604747593937]],
#      [[-73.12088783370399, -3.6761756372023178],
#       [-73.1233132849711, -3.6761756372023178],
#       [-73.1233132849711, -3.6786010884694407],
#       [-73.12088783370399, -3.6786010884694407],
#       [-73.12088783370399, -3.6761756372023178]],
#      [[-73.66499740129518, -4.496786649245501],
#       [-73.66742285256231, -4.496786649245501],
#       [-73.66742285256231, -4.499212100512623],
#       [-73.66499740129518, -4.499212100512623],
#       [-73.66499740129518, -4.496786649245501]],
#      [[-73.52189577653495, -4.491127262955548],
#       [-73.52270426029065, -4.491127262955548],
#       [-73.52270426029065, -4.491935746711255],
#       [-73.52351274404636, -4.491935746711255],
#       [-73.52351274404636, -4.494361197978378],
#       [-73.52108729277923, -4.494361197978378],
#       [-73.52108729277923, -4.491935746711255],
#       [-73.52189577653495, -4.491935746711255],
#       [-73.52189577653495, -4.491127262955548]],
#      [[-73.52189577653495, -4.489510295444132],
#       [-73.52270426029065, -4.489510295444132],
#       [-73.52270426029065, -4.49031877919984],
#       [-73.52189577653495, -4.49031877919984],
#       [-73.52189577653495, -4.489510295444132]],
#      [[-73.37232628172904, -4.489510295444132],
#       [-73.37313476548475, -4.489510295444132],
#       [-73.37313476548475, -4.49031877919984],
#       [-73.37394324924045, -4.49031877919984],
#       [-73.37394324924045, -4.491127262955548],
#       [-73.37475173299616, -4.491127262955548],
#       [-73.37475173299616, -4.4935527142226706],
#       [-73.37232628172904, -4.4935527142226706],
#       [-73.37232628172904, -4.492744230466963],
#       [-73.37151779797334, -4.492744230466963],
#       [-73.37151779797334, -4.49031877919984],
#       [-73.37232628172904, -4.49031877919984],
#       [-73.37232628172904, -4.489510295444132]],
#      [[-73.37313476548475, -4.488701811688425],
#       [-73.37394324924045, -4.488701811688425],
#       [-73.37394324924045, -4.489510295444132],
#       [-73.37313476548475, -4.489510295444132],
#       [-73.37313476548475, -4.488701811688425]],
#      [[-73.37232628172904, -4.487893327932717],
#       [-73.37313476548475, -4.487893327932717],
#       [-73.37313476548475, -4.488701811688425],
#       [-73.37232628172904, -4.488701811688425],
#       [-73.37232628172904, -4.487893327932717]],
#      [[-73.66661436880659, -4.486276360421303],
#       [-73.66903982007372, -4.486276360421303],
#       [-73.66903982007372, -4.488701811688425],
#       [-73.66661436880659, -4.488701811688425],
#       [-73.66661436880659, -4.486276360421303]],
#      [[-73.38364505430894, -4.4846593929098875],
#       [-73.38607050557607, -4.4846593929098875],
#       [-73.38607050557607, -4.48708484417701],
#       [-73.38364505430894, -4.48708484417701],
#       [-73.38364505430894, -4.4846593929098875]],
#      [[-73.65852953124953, -4.483042425398472],
#       [-73.66176346627235, -4.483042425398472],
#       [-73.66176346627235, -4.48385090915418],
#       [-73.66257195002807, -4.48385090915418],
#       [-73.66257195002807, -4.486276360421303],
#       [-73.66338043378377, -4.486276360421303],
#       [-73.66338043378377, -4.48708484417701],
#       [-73.66418891753948, -4.48708484417701],
#       [-73.66418891753948, -4.489510295444132],
#       [-73.66338043378377, -4.489510295444132],
#       [-73.66338043378377, -4.49031877919984],
#       [-73.66176346627235, -4.49031877919984],
#       [-73.66176346627235, -4.491127262955548],
#       [-73.65933801500523, -4.491127262955548],
#       [-73.65933801500523, -4.49031877919984],
#       [-73.65852953124953, -4.49031877919984],
#       [-73.65852953124953, -4.487893327932717],
#       [-73.65933801500523, -4.487893327932717],
#       [-73.65933801500523, -4.48385090915418],
#       [-73.65852953124953, -4.48385090915418],
#       [-73.65852953124953, -4.483042425398472]],
#      [[-73.98919938733391, -4.470106685307151],
#       [-73.99162483860104, -4.470106685307151],
#       [-73.99162483860104, -4.472532136574274],
#       [-73.99081635484534, -4.472532136574274],
#       [-73.99081635484534, -4.4733406203299815],
#       [-73.99000787108963, -4.4733406203299815],
#       [-73.99000787108963, -4.474149104085689],
#       [-73.98919938733391, -4.474149104085689],
#       [-73.98919938733391, -4.4733406203299815],
#       [-73.9883909035782, -4.4733406203299815],
#       [-73.9883909035782, -4.471723652818566],
#       [-73.98919938733391, -4.471723652818566],
#       [-73.98919938733391, -4.470106685307151]],
#      [[-73.66338043378377, -4.467681234040028],
#       [-73.66580588505089, -4.467681234040028],
#       [-73.66580588505089, -4.470106685307151],
#       [-73.66338043378377, -4.470106685307151],
#       [-73.66338043378377, -4.467681234040028]],
#      [[-73.67469920636367, -4.466064266528613],
#       [-73.6771246576308, -4.466064266528613],
#       [-73.6771246576308, -4.46687275028432],
#       [-73.6779331413865, -4.46687275028432],
#       [-73.6779331413865, -4.470106685307151],
#       [-73.67550769011937, -4.470106685307151],
#       [-73.67550769011937, -4.469298201551443],
#       [-73.67469920636367, -4.469298201551443],
#       [-73.67469920636367, -4.466064266528613]],
#      [[-73.66661436880659, -4.459596396482953],
#       [-73.67146527134085, -4.459596396482953],
#       [-73.67146527134085, -4.4620218477500755],
#       [-73.66984830382943, -4.4620218477500755],
#       [-73.66984830382943, -4.462830331505783],
#       [-73.66823133631802, -4.462830331505783],
#       [-73.66823133631802, -4.463638815261491],
#       [-73.66742285256231, -4.463638815261491],
#       [-73.66742285256231, -4.464447299017198],
#       [-73.66661436880659, -4.464447299017198],
#       [-73.66661436880659, -4.465255782772906],
#       [-73.66418891753948, -4.465255782772906],
#       [-73.66418891753948, -4.462830331505783],
#       [-73.66499740129518, -4.462830331505783],
#       [-73.66499740129518, -4.4620218477500755],
#       [-73.66580588505089, -4.4620218477500755],
#       [-73.66580588505089, -4.461213363994368],
#       [-73.66661436880659, -4.461213363994368],
#       [-73.66661436880659, -4.459596396482953]],
#      [[-74.01668783502798, -4.4507030751701695],
#       [-74.0191132862951, -4.4507030751701695],
#       [-74.0191132862951, -4.453128526437292],
#       [-74.01668783502798, -4.453128526437292],
#       [-74.01668783502798, -4.4507030751701695]],
#      [[-73.81941779863533, -4.4393843025902635],
#       [-73.82184324990246, -4.4393843025902635],
#       [-73.82184324990246, -4.443426721368801],
#       [-73.81941779863533, -4.443426721368801],
#       [-73.81941779863533, -4.4393843025902635]],
#      [[-73.69410281650066, -4.419172208697574],
#       [-73.69733675152348, -4.419172208697574],
#       [-73.69733675152348, -4.424023111231819],
#       [-73.69652826776777, -4.424023111231819],
#       [-73.69652826776777, -4.424831594987527],
#       [-73.69410281650066, -4.424831594987527],
#       [-73.69410281650066, -4.424023111231819],
#       [-73.69329433274494, -4.424023111231819],
#       [-73.69329433274494, -4.422406143720404],
#       [-73.69248584898924, -4.422406143720404],
#       [-73.69248584898924, -4.419980692453282],
#       [-73.69410281650066, -4.419980692453282],
#       [-73.69410281650066, -4.419172208697574]],
#      [[-73.85014018135222, -4.4102788873847905],
#       [-73.85256563261933, -4.4102788873847905],
#       [-73.85256563261933, -4.412704338651913],
#       [-73.85014018135222, -4.412704338651913],
#       [-73.85014018135222, -4.4102788873847905]],
#      [[-73.58980841201438, -4.403002533583423],
#       [-73.5922338632815, -4.403002533583423],
#       [-73.5922338632815, -4.4054279848505455],
#       [-73.58980841201438, -4.4054279848505455],
#       [-73.58980841201438, -4.403002533583423]],
#      [[-73.85499108388646, -4.3989601148048845],
#       [-73.85660805139787, -4.3989601148048845],
#       [-73.85660805139787, -4.399768598560592],
#       [-73.86145895393213, -4.399768598560592],
#       [-73.86145895393213, -4.4005770823163],
#       [-73.86469288895495, -4.4005770823163],
#       [-73.86469288895495, -4.401385566072007],
#       [-73.86550137271065, -4.401385566072007],
#       [-73.86550137271065, -4.402194049827715],
#       [-73.86630985646637, -4.402194049827715],
#       [-73.86630985646637, -4.403002533583423],
#       [-73.86711834022208, -4.403002533583423],
#       [-73.86711834022208, -4.40381101733913],
#       [-73.86792682397778, -4.40381101733913],
#       [-73.86792682397778, -4.404619501094838],
#       [-73.86873530773349, -4.404619501094838],
#       [-73.86873530773349, -4.4078534361176684],
#       [-73.86792682397778, -4.4078534361176684],
#       [-73.86792682397778, -4.408661919873376],
#       [-73.86711834022208, -4.408661919873376],
#       [-73.86711834022208, -4.409470403629084],
#       [-73.86388440519924, -4.409470403629084],
#       [-73.86388440519924, -4.4102788873847905],
#       [-73.85579956764217, -4.4102788873847905],
#       [-73.85579956764217, -4.409470403629084],
#       [-73.85499108388646, -4.409470403629084],
#       [-73.85499108388646, -4.4078534361176684],
#       [-73.85418260013076, -4.4078534361176684],
#       [-73.85418260013076, -4.4054279848505455],
#       [-73.85337411637505, -4.4054279848505455],
#       [-73.85337411637505, -4.403002533583423],
#       [-73.85256563261933, -4.403002533583423],
#       [-73.85256563261933, -4.4005770823163],
#       [-73.85337411637505, -4.4005770823163],
#       [-73.85337411637505, -4.399768598560592],
#       [-73.85499108388646, -4.399768598560592],
#       [-73.85499108388646, -4.3989601148048845]],
#      [[-74.06519686037043, -4.386024374713564],
#       [-74.06762231163755, -4.386024374713564],
#       [-74.06762231163755, -4.388449825980686],
#       [-74.06519686037043, -4.388449825980686],
#       [-74.06519686037043, -4.386024374713564]],
#      [[-73.59627628206005, -4.382790439690734],
#       [-73.59870173332716, -4.382790439690734],
#       [-73.59870173332716, -4.383598923446441],
#       [-73.59951021708287, -4.383598923446441],
#       [-73.59951021708287, -4.3852158909578565],
#       [-73.60112718459429, -4.3852158909578565],
#       [-73.60112718459429, -4.386024374713564],
#       [-73.60436111961711, -4.386024374713564],
#       [-73.60436111961711, -4.386832858469272],
#       [-73.60678657088424, -4.386832858469272],
#       [-73.60678657088424, -4.387641342224979],
#       [-73.60759505463994, -4.387641342224979],
#       [-73.60759505463994, -4.390066793492101],
#       [-73.60678657088424, -4.390066793492101],
#       [-73.60678657088424, -4.3941092122706396],
#       [-73.60597808712853, -4.3941092122706396],
#       [-73.60597808712853, -4.394917696026347],
#       [-73.60516960337283, -4.394917696026347],
#       [-73.60516960337283, -4.395726179782055],
#       [-73.6035526358614, -4.395726179782055],
#       [-73.6035526358614, -4.3965346635377625],
#       [-73.5922338632815, -4.3965346635377625],
#       [-73.5922338632815, -4.395726179782055],
#       [-73.59142537952579, -4.395726179782055],
#       [-73.59142537952579, -4.394917696026347],
#       [-73.59061689577008, -4.394917696026347],
#       [-73.59061689577008, -4.390875277247809],
#       [-73.59142537952579, -4.390875277247809],
#       [-73.59142537952579, -4.388449825980686],
#       [-73.59385083079292, -4.388449825980686],
#       [-73.59385083079292, -4.387641342224979],
#       [-73.59546779830433, -4.387641342224979],
#       [-73.59546779830433, -4.388449825980686],
#       [-73.59627628206005, -4.388449825980686],
#       [-73.59627628206005, -4.382790439690734]],
#      [[-73.69167736523353, -4.381981955935026],
#       [-73.69491130025636, -4.381981955935026],
#       [-73.69491130025636, -4.382790439690734],
#       [-73.69733675152348, -4.382790439690734],
#       [-73.69733675152348, -4.3852158909578565],
#       [-73.69652826776777, -4.3852158909578565],
#       [-73.69652826776777, -4.386024374713564],
#       [-73.69571978401207, -4.386024374713564],
#       [-73.69571978401207, -4.386832858469272],
#       [-73.69491130025636, -4.386832858469272],
#       [-73.69491130025636, -4.387641342224979],
#       [-73.69329433274494, -4.387641342224979],
#       [-73.69329433274494, -4.388449825980686],
#       [-73.69248584898924, -4.388449825980686],
#       [-73.69248584898924, -4.390875277247809],
#       [-73.69167736523353, -4.390875277247809],
#       [-73.69167736523353, -4.391683761003517],
#       [-73.69086888147783, -4.391683761003517],
#       [-73.69086888147783, -4.3941092122706396],
#       [-73.69006039772212, -4.3941092122706396],
#       [-73.69006039772212, -4.394917696026347],
#       [-73.68925191396642, -4.394917696026347],
#       [-73.68925191396642, -4.395726179782055],
#       [-73.68763494645499, -4.395726179782055],
#       [-73.68763494645499, -4.3965346635377625],
#       [-73.68601797894358, -4.3965346635377625],
#       [-73.68601797894358, -4.39734314729347],
#       [-73.68440101143216, -4.39734314729347],
#       [-73.68440101143216, -4.398151631049178],
#       [-73.68035859265363, -4.398151631049178],
#       [-73.68035859265363, -4.3965346635377625],
#       [-73.67955010889791, -4.3965346635377625],
#       [-73.67955010889791, -4.395726179782055],
#       [-73.6779331413865, -4.395726179782055],
#       [-73.6779331413865, -4.394917696026347],
#       [-73.6771246576308, -4.394917696026347],
#       [-73.6771246576308, -4.391683761003517],
#       [-73.6779331413865, -4.391683761003517],
#       [-73.6779331413865, -4.390875277247809],
#       [-73.67955010889791, -4.390875277247809],
#       [-73.67955010889791, -4.389258309736394],
#       [-73.68035859265363, -4.389258309736394],
#       [-73.68035859265363, -4.386832858469272],
#       [-73.68116707640934, -4.386832858469272],
#       [-73.68116707640934, -4.386024374713564],
#       [-73.68197556016504, -4.386024374713564],
#       [-73.68197556016504, -4.3852158909578565],
#       [-73.68278404392075, -4.3852158909578565],
#       [-73.68278404392075, -4.384407407202149],
#       [-73.68440101143216, -4.384407407202149],
#       [-73.68440101143216, -4.383598923446441],
#       [-73.68682646269929, -4.383598923446441],
#       [-73.68682646269929, -4.384407407202149],
#       [-73.68925191396642, -4.384407407202149],
#       [-73.68925191396642, -4.3852158909578565],
#       [-73.69006039772212, -4.3852158909578565],
#       [-73.69006039772212, -4.384407407202149],
#       [-73.69167736523353, -4.384407407202149],
#       [-73.69167736523353, -4.381981955935026]],
#      [[-73.84690624632938, -4.374705602133658],
#       [-73.84933169759651, -4.374705602133658],
#       [-73.84933169759651, -4.37713105340078],
#       [-73.84690624632938, -4.37713105340078],
#       [-73.84690624632938, -4.374705602133658]],
#      [[-73.73371852053033, -4.368237732087997],
#       [-73.73614397179745, -4.368237732087997],
#       [-73.73614397179745, -4.37066318335512],
#       [-73.73371852053033, -4.37066318335512],
#       [-73.73371852053033, -4.368237732087997]],
#      [[-73.85014018135222, -4.357727443263799],
#       [-73.85256563261933, -4.357727443263799],
#       [-73.85256563261933, -4.360152894530922],
#       [-73.85014018135222, -4.360152894530922],
#       [-73.85014018135222, -4.357727443263799]],
#      [[-73.63993440486824, -4.355301991996676],
#       [-73.64235985613537, -4.355301991996676],
#       [-73.64235985613537, -4.357727443263799],
#       [-73.63993440486824, -4.357727443263799],
#       [-73.63993440486824, -4.355301991996676]],
#      [[-73.7094640078591, -4.352876540729554],
#       [-73.71188945912623, -4.352876540729554],
#       [-73.71188945912623, -4.356110475752383],
#       [-73.71269794288193, -4.356110475752383],
#       [-73.71269794288193, -4.356918959508091],
#       [-73.71512339414905, -4.356918959508091],
#       [-73.71512339414905, -4.357727443263799],
#       [-73.71916581292759, -4.357727443263799],
#       [-73.71916581292759, -4.360152894530922],
#       [-73.71997429668329, -4.360152894530922],
#       [-73.71997429668329, -4.363386829553752],
#       [-73.71754884541618, -4.363386829553752],
#       [-73.71754884541618, -4.3625783457980445],
#       [-73.71593187790477, -4.3625783457980445],
#       [-73.71593187790477, -4.361769862042337],
#       [-73.71350642663764, -4.361769862042337],
#       [-73.71350642663764, -4.360961378286629],
#       [-73.71188945912623, -4.360961378286629],
#       [-73.71188945912623, -4.360152894530922],
#       [-73.7110809753705, -4.360152894530922],
#       [-73.7110809753705, -4.359344410775214],
#       [-73.7102724916148, -4.359344410775214],
#       [-73.7102724916148, -4.358535927019506],
#       [-73.7094640078591, -4.358535927019506],
#       [-73.7094640078591, -4.352876540729554]],
#      [[-73.635083502334, -4.342366251905355],
#       [-73.63993440486824, -4.342366251905355],
#       [-73.63993440486824, -4.344791703172477],
#       [-73.63912592111254, -4.344791703172477],
#       [-73.63912592111254, -4.345600186928185],
#       [-73.63831743735683, -4.345600186928185],
#       [-73.63831743735683, -4.346408670683893],
#       [-73.6358919860897, -4.346408670683893],
#       [-73.6358919860897, -4.345600186928185],
#       [-73.635083502334, -4.345600186928185],
#       [-73.635083502334, -4.344791703172477],
#       [-73.6342750185783, -4.344791703172477],
#       [-73.6342750185783, -4.34398321941677],
#       [-73.635083502334, -4.34398321941677],
#       [-73.635083502334, -4.342366251905355]],
#      [[-73.62861563228834, -4.3399408006382325],
#       [-73.63184956731118, -4.3399408006382325],
#       [-73.63184956731118, -4.341557768149648],
#       [-73.63265805106688, -4.341557768149648],
#       [-73.63265805106688, -4.34398321941677],
#       [-73.63346653482259, -4.34398321941677],
#       [-73.63346653482259, -4.346408670683893],
#       [-73.63104108355546, -4.346408670683893],
#       [-73.63104108355546, -4.34398321941677],
#       [-73.63023259979975, -4.34398321941677],
#       [-73.63023259979975, -4.343174735661063],
#       [-73.62942411604405, -4.343174735661063],
#       [-73.62942411604405, -4.342366251905355],
#       [-73.62861563228834, -4.342366251905355],
#       [-73.62861563228834, -4.3399408006382325]],
#      [[-73.61729685970843, -4.335089898103987],
#       [-73.61972231097556, -4.335089898103987],
#       [-73.61972231097556, -4.33751534937111],
#       [-73.61729685970843, -4.33751534937111],
#       [-73.61729685970843, -4.335089898103987]],
#      [[-73.62861563228834, -4.330238995569742],
#       [-73.63104108355546, -4.330238995569742],
#       [-73.63104108355546, -4.332664446836864],
#       [-73.62861563228834, -4.332664446836864],
#       [-73.62861563228834, -4.330238995569742]],
#      [[-73.6358919860897, -4.329430511814034],
#       [-73.63912592111254, -4.329430511814034],
#       [-73.63912592111254, -4.331855963081157],
#       [-73.63750895360113, -4.331855963081157],
#       [-73.63750895360113, -4.335089898103987],
#       [-73.63831743735683, -4.335089898103987],
#       [-73.63831743735683, -4.336706865615402],
#       [-73.63750895360113, -4.336706865615402],
#       [-73.63750895360113, -4.338323833126817],
#       [-73.635083502334, -4.338323833126817],
#       [-73.635083502334, -4.336706865615402],
#       [-73.6342750185783, -4.336706865615402],
#       [-73.6342750185783, -4.335089898103987],
#       [-73.635083502334, -4.335089898103987],
#       [-73.635083502334, -4.333472930592571],
#       [-73.6342750185783, -4.333472930592571],
#       [-73.6342750185783, -4.330238995569742],
#       [-73.6358919860897, -4.330238995569742],
#       [-73.6358919860897, -4.329430511814034]],
#      [[-73.82426870116957, -4.3221541580126654],
#       [-73.8266941524367, -4.3221541580126654],
#       [-73.8266941524367, -4.324579609279788],
#       [-73.82426870116957, -4.324579609279788],
#       [-73.82426870116957, -4.3221541580126654]],
#      [[-73.5170448740007, -4.313260836699882],
#       [-73.51785335775641, -4.313260836699882],
#       [-73.51785335775641, -4.31406932045559],
#       [-73.51866184151211, -4.31406932045559],
#       [-73.51866184151211, -4.314877804211298],
#       [-73.51947032526782, -4.314877804211298],
#       [-73.51947032526782, -4.315686287967005],
#       [-73.52027880902352, -4.315686287967005],
#       [-73.52027880902352, -4.316494771722713],
#       [-73.51785335775641, -4.316494771722713],
#       [-73.51785335775641, -4.3173032554784205],
#       [-73.51542790648928, -4.3173032554784205],
#       [-73.51542790648928, -4.314877804211298],
#       [-73.51623639024498, -4.314877804211298],
#       [-73.51623639024498, -4.31406932045559],
#       [-73.5170448740007, -4.31406932045559],
#       [-73.5170448740007, -4.313260836699882]],
#      [[-73.41194198575872, -4.311643869188467],
#       [-73.41517592078155, -4.311643869188467],
#       [-73.41517592078155, -4.31406932045559],
#       [-73.41194198575872, -4.31406932045559],
#       [-73.41194198575872, -4.311643869188467]],
#      [[-73.75716454944585, -4.298708129097147],
#       [-73.75797303320155, -4.298708129097147],
#       [-73.75797303320155, -4.2995166128528535],
#       [-73.75716454944585, -4.2995166128528535],
#       [-73.75716454944585, -4.298708129097147]],
#      [[-73.75716454944585, -4.295474194074316],
#       [-73.75959000071296, -4.295474194074316],
#       [-73.75959000071296, -4.297899645341439],
#       [-73.75878151695726, -4.297899645341439],
#       [-73.75878151695726, -4.298708129097147],
#       [-73.75797303320155, -4.298708129097147],
#       [-73.75797303320155, -4.297899645341439],
#       [-73.75716454944585, -4.297899645341439],
#       [-73.75716454944585, -4.295474194074316]],
#      [[-73.64074288862396, -4.295474194074316],
#       [-73.64155137237967, -4.295474194074316],
#       [-73.64155137237967, -4.296282677830024],
#       [-73.64235985613537, -4.296282677830024],
#       [-73.64235985613537, -4.298708129097147],
#       [-73.63993440486824, -4.298708129097147],
#       [-73.63993440486824, -4.296282677830024],
#       [-73.64074288862396, -4.296282677830024],
#       [-73.64074288862396, -4.295474194074316]],
#      [[-73.63912592111254, -4.292240259051486],
#       [-73.64155137237967, -4.292240259051486],
#       [-73.64155137237967, -4.2946657103186086],
#       [-73.64074288862396, -4.2946657103186086],
#       [-73.64074288862396, -4.295474194074316],
#       [-73.63993440486824, -4.295474194074316],
#       [-73.63993440486824, -4.2946657103186086],
#       [-73.63912592111254, -4.2946657103186086],
#       [-73.63912592111254, -4.292240259051486]],
#      [[-73.74099487433169, -4.291431775295778],
#       [-73.74342032559882, -4.291431775295778],
#       [-73.74342032559882, -4.292240259051486],
#       [-73.74422880935452, -4.292240259051486],
#       [-73.74422880935452, -4.2946657103186086],
#       [-73.74342032559882, -4.2946657103186086],
#       [-73.74342032559882, -4.295474194074316],
#       [-73.73937790682028, -4.295474194074316],
#       [-73.73937790682028, -4.293048742807193],
#       [-73.74018639057599, -4.293048742807193],
#       [-73.74018639057599, -4.292240259051486],
#       [-73.74099487433169, -4.292240259051486],
#       [-73.74099487433169, -4.291431775295778]],
#      [[-73.61648837595273, -4.291431775295778],
#       [-73.61891382721986, -4.291431775295778],
#       [-73.61891382721986, -4.293857226562901],
#       [-73.61648837595273, -4.293857226562901],
#       [-73.61648837595273, -4.291431775295778]],
#      [[-73.71269794288193, -4.281729970227287],
#       [-73.71350642663764, -4.281729970227287],
#       [-73.71350642663764, -4.282538453982995],
#       [-73.71269794288193, -4.282538453982995],
#       [-73.71269794288193, -4.281729970227287]],
#      [[-73.75716454944585, -4.28092148647158],
#       [-73.75797303320155, -4.28092148647158],
#       [-73.75797303320155, -4.281729970227287],
#       [-73.76039848446868, -4.281729970227287],
#       [-73.76039848446868, -4.282538453982995],
#       [-73.76120696822439, -4.282538453982995],
#       [-73.76120696822439, -4.284963905250118],
#       [-73.75473909817872, -4.284963905250118],
#       [-73.75473909817872, -4.281729970227287],
#       [-73.75716454944585, -4.281729970227287],
#       [-73.75716454944585, -4.28092148647158]],
#      [[-73.71593187790477, -4.278496035204457],
#       [-73.71674036166047, -4.278496035204457],
#       [-73.71674036166047, -4.28092148647158],
#       [-73.71754884541618, -4.28092148647158],
#       [-73.71754884541618, -4.283346937738703],
#       [-73.71512339414905, -4.283346937738703],
#       [-73.71512339414905, -4.282538453982995],
#       [-73.71431491039334, -4.282538453982995],
#       [-73.71431491039334, -4.281729970227287],
#       [-73.71350642663764, -4.281729970227287],
#       [-73.71350642663764, -4.28092148647158],
#       [-73.71431491039334, -4.28092148647158],
#       [-73.71431491039334, -4.280113002715872],
#       [-73.71512339414905, -4.280113002715872],
#       [-73.71512339414905, -4.279304518960164],
#       [-73.71593187790477, -4.279304518960164],
#       [-73.71593187790477, -4.278496035204457]],
#      [[-73.53806545164909, -4.277687551448749],
#       [-73.54129938667192, -4.277687551448749],
#       [-73.54129938667192, -4.278496035204457],
#       [-73.54210787042763, -4.278496035204457],
#       [-73.54210787042763, -4.281729970227287],
#       [-73.54129938667192, -4.281729970227287],
#       [-73.54129938667192, -4.282538453982995],
#       [-73.53968241916051, -4.282538453982995],
#       [-73.53968241916051, -4.281729970227287],
#       [-73.53806545164909, -4.281729970227287],
#       [-73.53806545164909, -4.28092148647158],
#       [-73.53725696789338, -4.28092148647158],
#       [-73.53725696789338, -4.280113002715872],
#       [-73.53644848413768, -4.280113002715872],
#       [-73.53644848413768, -4.278496035204457],
#       [-73.53806545164909, -4.278496035204457],
#       [-73.53806545164909, -4.277687551448749]],
#      [[-73.60112718459429, -4.2113918834807285],
#       [-73.6035526358614, -4.2113918834807285],
#       [-73.6035526358614, -4.213817334747851],
#       [-73.6027441521057, -4.213817334747851],
#       [-73.6027441521057, -4.214625818503559],
#       [-73.60193566835, -4.214625818503559],
#       [-73.60193566835, -4.215434302259267],
#       [-73.60112718459429, -4.215434302259267],
#       [-73.60112718459429, -4.216242786014974],
#       [-73.59870173332716, -4.216242786014974],
#       [-73.59870173332716, -4.213008850992144],
#       [-73.59951021708287, -4.213008850992144],
#       [-73.59951021708287, -4.212200367236436],
#       [-73.60112718459429, -4.212200367236436],
#       [-73.60112718459429, -4.2113918834807285]],
#      [[-73.3998147294231, -4.205732497190776],
#       [-73.40304866444593, -4.205732497190776],
#       [-73.40304866444593, -4.208157948457899],
#       [-73.3998147294231, -4.208157948457899],
#       [-73.3998147294231, -4.205732497190776]],
#      [[-73.63104108355546, -4.179052533252426],
#       [-73.63346653482259, -4.179052533252426],
#       [-73.63346653482259, -4.181477984519549],
#       [-73.63104108355546, -4.181477984519549],
#       [-73.63104108355546, -4.179052533252426]],
#      [[-73.65852953124953, -4.13135199166568],
#       [-73.66095498251664, -4.13135199166568],
#       [-73.66095498251664, -4.133777442932802],
#       [-73.65852953124953, -4.133777442932802],
#       [-73.65852953124953, -4.13135199166568]],
#      [[-73.79031238342985, -4.042418778537847],
#       [-73.79516328596411, -4.042418778537847],
#       [-73.79516328596411, -4.043227262293555],
#       [-73.79758873723122, -4.043227262293555],
#       [-73.79758873723122, -4.046461197316384],
#       [-73.79678025347552, -4.046461197316384],
#       [-73.79678025347552, -4.047269681072092],
#       [-73.79273783469698, -4.047269681072092],
#       [-73.79273783469698, -4.046461197316384],
#       [-73.79031238342985, -4.046461197316384],
#       [-73.79031238342985, -4.042418778537847]],
#      [[-73.78303602962849, -4.040801811026432],
#       [-73.7854614808956, -4.040801811026432],
#       [-73.7854614808956, -4.043227262293555],
#       [-73.78303602962849, -4.043227262293555],
#       [-73.78303602962849, -4.040801811026432]],
#      [[-73.77575967582712, -4.037567876003601],
#       [-73.77818512709425, -4.037567876003601],
#       [-73.77818512709425, -4.039993327270724],
#       [-73.77737664333853, -4.039993327270724],
#       [-73.77737664333853, -4.0416102947821395],
#       [-73.77818512709425, -4.0416102947821395],
#       [-73.77818512709425, -4.044844229804969],
#       [-73.77575967582712, -4.044844229804969],
#       [-73.77575967582712, -4.0416102947821395],
#       [-73.77656815958282, -4.0416102947821395],
#       [-73.77656815958282, -4.039993327270724],
#       [-73.77575967582712, -4.039993327270724],
#       [-73.77575967582712, -4.037567876003601]],
#      [[-73.2502452346172, -4.015738814599497],
#       [-73.25267068588433, -4.015738814599497],
#       [-73.25267068588433, -4.01816426586662],
#       [-73.2502452346172, -4.01816426586662],
#       [-73.2502452346172, -4.015738814599497]],
#      [[-73.26156400719711, -4.014121847088082],
#       [-73.26560642597565, -4.014121847088082],
#       [-73.26560642597565, -4.014930330843789],
#       [-73.26641490973135, -4.014930330843789],
#       [-73.26641490973135, -4.01816426586662],
#       [-73.2607555234414, -4.01816426586662],
#       [-73.2607555234414, -4.0189727496223275],
#       [-73.25752158841857, -4.0189727496223275],
#       [-73.25752158841857, -4.016547298355205],
#       [-73.25913855592998, -4.016547298355205],
#       [-73.25913855592998, -4.015738814599497],
#       [-73.2607555234414, -4.015738814599497],
#       [-73.2607555234414, -4.014930330843789],
#       [-73.26156400719711, -4.014930330843789],
#       [-73.26156400719711, -4.014121847088082]],
#      [[-73.33513602896649, -3.9963352044625156],
#       [-73.33836996398932, -3.9963352044625156],
#       [-73.33836996398932, -3.998760655729638],
#       [-73.33513602896649, -3.998760655729638],
# ...
#       [-73.71431491039334, -4.281729970227287],
#       [-73.71431491039334, -4.282538453982995],
#       [-73.71512339414905, -4.282538453982995],
#       [-73.71512339414905, -4.283346937738703],
#       [-73.71754884541618, -4.283346937738703],
#       [-73.71754884541618, -4.28092148647158],
#       [-73.71674036166047, -4.28092148647158],
#       [-73.71674036166047, -4.278496035204457]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91179-5293',
#    u'properties': {u'count': 19, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.72967610175179, -3.664048380866704],
#       [-73.72725065048466, -3.664048380866704],
#       [-73.72725065048466, -3.666473832133827],
#       [-73.72967610175179, -3.666473832133827],
#       [-73.72967610175179, -3.664048380866704]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91193-4533',
#    u'properties': {u'count': 9, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.7304845855075, -3.7133658899648663],
#       [-73.72805913424037, -3.7133658899648663],
#       [-73.72805913424037, -3.7157913412319887],
#       [-73.7304845855075, -3.7157913412319887],
#       [-73.7304845855075, -3.7133658899648663]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91194-4594',
#    u'properties': {u'count': 9, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.73614397179745, -4.368237732087997],
#       [-73.73371852053033, -4.368237732087997],
#       [-73.73371852053033, -4.37066318335512],
#       [-73.73614397179745, -4.37066318335512],
#       [-73.73614397179745, -4.368237732087997]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91201-5404',
#    u'properties': {u'count': 9, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.74342032559882, -4.291431775295778],
#       [-73.74099487433169, -4.291431775295778],
#       [-73.74099487433169, -4.292240259051486],
#       [-73.74018639057599, -4.292240259051486],
#       [-73.74018639057599, -4.293048742807193],
#       [-73.73937790682028, -4.293048742807193],
#       [-73.73937790682028, -4.295474194074316],
#       [-73.74342032559882, -4.295474194074316],
#       [-73.74342032559882, -4.2946657103186086],
#       [-73.74422880935452, -4.2946657103186086],
#       [-73.74422880935452, -4.292240259051486],
#       [-73.74342032559882, -4.292240259051486],
#       [-73.74342032559882, -4.291431775295778]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91210-5309',
#    u'properties': {u'count': 25, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.7515051631559, -3.7311525325904324],
#       [-73.74907971188877, -3.7311525325904324],
#       [-73.74907971188877, -3.7335779838575553],
#       [-73.7515051631559, -3.7335779838575553],
#       [-73.7515051631559, -3.7311525325904324]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91220-4616',
#    u'properties': {u'count': 9, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.75797303320155, -4.28092148647158],
#       [-73.75716454944585, -4.28092148647158],
#       [-73.75716454944585, -4.281729970227287],
#       [-73.75473909817872, -4.281729970227287],
#       [-73.75473909817872, -4.284963905250118],
#       [-73.76120696822439, -4.284963905250118],
#       [-73.76120696822439, -4.282538453982995],
#       [-73.76039848446868, -4.282538453982995],
#       [-73.76039848446868, -4.281729970227287],
#       [-73.75797303320155, -4.281729970227287],
#       [-73.75797303320155, -4.28092148647158]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91230-5296',
#    u'properties': {u'count': 32, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.75959000071296, -4.295474194074316],
#       [-73.75716454944585, -4.295474194074316],
#       [-73.75716454944585, -4.297899645341439],
#       [-73.75797303320155, -4.297899645341439],
#       [-73.75797303320155, -4.298708129097147],
#       [-73.75716454944585, -4.298708129097147],
#       [-73.75716454944585, -4.2995166128528535],
#       [-73.75797303320155, -4.2995166128528535],
#       [-73.75797303320155, -4.298708129097147],
#       [-73.75878151695726, -4.298708129097147],
#       [-73.75878151695726, -4.297899645341439],
#       [-73.75959000071296, -4.297899645341439],
#       [-73.75959000071296, -4.295474194074316]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91230-5314',
#    u'properties': {u'count': 11, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.76201545198009, -3.4772886332982558],
#       [-73.75959000071296, -3.4772886332982558],
#       [-73.75959000071296, -3.4797140845653787],
#       [-73.76201545198009, -3.4797140845653787],
#       [-73.76201545198009, -3.4772886332982558]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91233-4302',
#    u'properties': {u'count': 9, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.76848332202574, -3.533074012442078],
#       [-73.76605787075863, -3.533074012442078],
#       [-73.76605787075863, -3.535499463709201],
#       [-73.76848332202574, -3.535499463709201],
#       [-73.76848332202574, -3.533074012442078]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91241-4371',
#    u'properties': {u'count': 9, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.77656815958282, -3.4805225683210863],
#       [-73.77414270831571, -3.4805225683210863],
#       [-73.77414270831571, -3.4829480195882088],
#       [-73.77656815958282, -3.4829480195882088],
#       [-73.77656815958282, -3.4805225683210863]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91251-4306',
#    u'properties': {u'count': 9, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.77656815958282, -3.4966922434352377],
#       [-73.77414270831571, -3.4966922434352377],
#       [-73.77414270831571, -3.49911769470236],
#       [-73.77656815958282, -3.49911769470236],
#       [-73.77656815958282, -3.4966922434352377]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91251-4326',
#    u'properties': {u'count': 9, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.77818512709425, -4.037567876003601],
#       [-73.77575967582712, -4.037567876003601],
#       [-73.77575967582712, -4.039993327270724],
#       [-73.77656815958282, -4.039993327270724],
#       [-73.77656815958282, -4.0416102947821395],
#       [-73.77575967582712, -4.0416102947821395],
#       [-73.77575967582712, -4.044844229804969],
#       [-73.77818512709425, -4.044844229804969],
#       [-73.77818512709425, -4.0416102947821395],
#       [-73.77737664333853, -4.0416102947821395],
#       [-73.77737664333853, -4.039993327270724],
#       [-73.77818512709425, -4.039993327270724],
#       [-73.77818512709425, -4.037567876003601]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91253-4995',
#    u'properties': {u'count': 23, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.7854614808956, -4.040801811026432],
#       [-73.78303602962849, -4.040801811026432],
#       [-73.78303602962849, -4.043227262293555],
#       [-73.7854614808956, -4.043227262293555],
#       [-73.7854614808956, -4.040801811026432]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91262-4999',
#    u'properties': {u'count': 9, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.79516328596411, -4.042418778537847],
#       [-73.79031238342985, -4.042418778537847],
#       [-73.79031238342985, -4.046461197316384],
#       [-73.79273783469698, -4.046461197316384],
#       [-73.79273783469698, -4.047269681072092],
#       [-73.79678025347552, -4.047269681072092],
#       [-73.79678025347552, -4.046461197316384],
#       [-73.79758873723122, -4.046461197316384],
#       [-73.79758873723122, -4.043227262293555],
#       [-73.79516328596411, -4.043227262293555],
#       [-73.79516328596411, -4.042418778537847]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91271-5001',
#    u'properties': {u'count': 47, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.82184324990246, -4.4393843025902635],
#       [-73.81941779863533, -4.4393843025902635],
#       [-73.81941779863533, -4.443426721368801],
#       [-73.82184324990246, -4.443426721368801],
#       [-73.82184324990246, -4.4393843025902635]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91307-5492',
#    u'properties': {u'count': 15, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.82265173365816, -3.96157040296709],
#       [-73.82022628239103, -3.96157040296709],
#       [-73.82022628239103, -3.9639958542342124],
#       [-73.82265173365816, -3.9639958542342124],
#       [-73.82265173365816, -3.96157040296709]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91308-4901',
#    u'properties': {u'count': 9, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.8266941524367, -4.3221541580126654],
#       [-73.82426870116957, -4.3221541580126654],
#       [-73.82426870116957, -4.324579609279788],
#       [-73.8266941524367, -4.324579609279788],
#       [-73.8266941524367, -4.3221541580126654]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91313-5347',
#    u'properties': {u'count': 9, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.84933169759651, -4.374705602133658],
#       [-73.84690624632938, -4.374705602133658],
#       [-73.84690624632938, -4.37713105340078],
#       [-73.84933169759651, -4.37713105340078],
#       [-73.84933169759651, -4.374705602133658]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91341-5412',
#    u'properties': {u'count': 9, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.85256563261933, -4.357727443263799],
#       [-73.85014018135222, -4.357727443263799],
#       [-73.85014018135222, -4.360152894530922],
#       [-73.85256563261933, -4.360152894530922],
#       [-73.85256563261933, -4.357727443263799]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91345-5391',
#    u'properties': {u'count': 9, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.85256563261933, -4.4102788873847905],
#       [-73.85014018135222, -4.4102788873847905],
#       [-73.85014018135222, -4.412704338651913],
#       [-73.85256563261933, -4.412704338651913],
#       [-73.85256563261933, -4.4102788873847905]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91345-5456',
#    u'properties': {u'count': 9, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.85660805139787, -4.3989601148048845],
#       [-73.85499108388646, -4.3989601148048845],
#       [-73.85499108388646, -4.399768598560592],
#       [-73.85337411637505, -4.399768598560592],
#       [-73.85337411637505, -4.4005770823163],
#       [-73.85256563261933, -4.4005770823163],
#       [-73.85256563261933, -4.403002533583423],
#       [-73.85337411637505, -4.403002533583423],
#       [-73.85337411637505, -4.4054279848505455],
#       [-73.85418260013076, -4.4054279848505455],
#       [-73.85418260013076, -4.4078534361176684],
#       [-73.85499108388646, -4.4078534361176684],
#       [-73.85499108388646, -4.409470403629084],
#       [-73.85579956764217, -4.409470403629084],
#       [-73.85579956764217, -4.4102788873847905],
#       [-73.86388440519924, -4.4102788873847905],
#       [-73.86388440519924, -4.409470403629084],
#       [-73.86711834022208, -4.409470403629084],
#       [-73.86711834022208, -4.408661919873376],
#       [-73.86792682397778, -4.408661919873376],
#       [-73.86792682397778, -4.4078534361176684],
#       [-73.86873530773349, -4.4078534361176684],
#       [-73.86873530773349, -4.404619501094838],
#       [-73.86792682397778, -4.404619501094838],
#       [-73.86792682397778, -4.40381101733913],
#       [-73.86711834022208, -4.40381101733913],
#       [-73.86711834022208, -4.403002533583423],
#       [-73.86630985646637, -4.403002533583423],
#       [-73.86630985646637, -4.402194049827715],
#       [-73.86550137271065, -4.402194049827715],
#       [-73.86550137271065, -4.401385566072007],
#       [-73.86469288895495, -4.401385566072007],
#       [-73.86469288895495, -4.4005770823163],
#       [-73.86145895393213, -4.4005770823163],
#       [-73.86145895393213, -4.399768598560592],
#       [-73.85660805139787, -4.399768598560592],
#       [-73.85660805139787, -4.3989601148048845]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91351-5442',
#    u'properties': {u'count': 209, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.9132019142974, -3.8928492837319464],
#       [-73.91077646303029, -3.8928492837319464],
#       [-73.91077646303029, -3.8952747349990693],
#       [-73.9132019142974, -3.8952747349990693],
#       [-73.9132019142974, -3.8928492837319464]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91420-4816',
#    u'properties': {u'count': 9, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.92209523561019, -3.893657767487654],
#       [-73.91966978434307, -3.893657767487654],
#       [-73.91966978434307, -3.896083218754777],
#       [-73.92209523561019, -3.896083218754777],
#       [-73.92209523561019, -3.893657767487654]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91431-4817',
#    u'properties': {u'count': 9, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.93098855692297, -3.647878705752553],
#       [-73.92856310565585, -3.647878705752553],
#       [-73.92856310565585, -3.6503041570196757],
#       [-73.93098855692297, -3.6503041570196757],
#       [-73.93098855692297, -3.647878705752553]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91442-4513',
#    u'properties': {u'count': 9, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.93745642696864, -3.927614085227372],
#       [-73.93503097570151, -3.927614085227372],
#       [-73.93503097570151, -3.9300395364944944],
#       [-73.93745642696864, -3.9300395364944944],
#       [-73.93745642696864, -3.927614085227372]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91450-4859',
#    u'properties': {u'count': 9, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-73.99162483860104, -4.470106685307151],
#       [-73.98919938733391, -4.470106685307151],
#       [-73.98919938733391, -4.471723652818566],
#       [-73.9883909035782, -4.471723652818566],
#       [-73.9883909035782, -4.4733406203299815],
#       [-73.98919938733391, -4.4733406203299815],
#       [-73.98919938733391, -4.474149104085689],
#       [-73.99000787108963, -4.474149104085689],
#       [-73.99000787108963, -4.4733406203299815],
#       [-73.99081635484534, -4.4733406203299815],
#       [-73.99081635484534, -4.472532136574274],
#       [-73.99162483860104, -4.472532136574274],
#       [-73.99162483860104, -4.470106685307151]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91517-5530',
#    u'properties': {u'count': 14, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-74.0191132862951, -4.4507030751701695],
#       [-74.01668783502798, -4.4507030751701695],
#       [-74.01668783502798, -4.453128526437292],
#       [-74.0191132862951, -4.453128526437292],
#       [-74.0191132862951, -4.4507030751701695]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91551-5506',
#    u'properties': {u'count': 9, u'label': 1},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [[[-74.06762231163755, -4.386024374713564],
#       [-74.06519686037043, -4.386024374713564],
#       [-74.06519686037043, -4.388449825980686],
#       [-74.06762231163755, -4.388449825980686],
#       [-74.06762231163755, -4.386024374713564]]],
#     u'geodesic': False,
#     u'type': u'Polygon'},
#    u'id': u'-91611-5426',
#    u'properties': {u'count': 9, u'label': 1},
#    u'type': u'Feature'}],
#  u'geo_column': u'geometry',
#  u'type': u'FeatureCollection'}
